# %% [markdown]
# # Solve the NN driven model in more DFs

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
import time
from datetime import datetime

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-12-08 17:17:48.019800: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
processed_flag = 'post'
merged_df, dflist = load_dataset(dir_name, processed_flag)

# %%
dataset = dflist[7:9]

print(f"In this dataset we have {np.sum([d.shape[0] for d in dataset])} scenes")
# Out:
# In this dataset we have 30 scenes

# %% [markdown]
# ## Get $v_{0}$ mean over each df looping on dflist

# %%
# Create the model
doe = [1,2,1] #Design of experiment

# %%
# params
v0 = 30
NUM_ITER = 500
LEARNING_RATE_v0 = 0.5
test=0.33
plot_flag = True

# Save the plot
flag_save = True

# %%
info_dataset, model_trained = solve_nn_dataset(dataset, doe, v0, processed_flag,
                                               NUM_ITER, LEARNING_RATE_v0, test, plot_flag)
# Out:
# ----------------------------------------------------------------------------------------------------
# Analyzing 2 dfs. NN structure: 1-2-1
# ****************************************************************************************************
# Analyzing 1/2 dfs.
# In DataFrame n.8 we have 21 scenes.
#     To train the model we use 14 scenes, the remaining 7 to test the model.
#
# Training step. (14 scenes)
# ====================================================================================================
# DataFrame n.8. Scene n.1/14
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [108.84,109.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/14:
#         * After LR finder: LR_NN=0.001 with mse=6.030217133170846 at it=24
#         * v0 = 20.549015112613134
#         * MSE = 0.13530223811937248
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.2/14
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [522.64,523.04]
# ----------------------------------------------------------------------------------------------------
#         For scene 2/14:
#         * After LR finder: LR_NN=0.0005 with mse=0.9002866729851421 at it=24
#         * v0 = 25.15597288259528
#         * MSE = 3.3338926794544186
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.3/14
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [414.44,414.84]
# ----------------------------------------------------------------------------------------------------
#         For scene 3/14:
#         * After LR finder: LR_NN=0.0001 with mse=6.100280898883952 at it=24
#         * v0 = 14.740231690534392
#         * MSE = 23.43921127700581
#         * iterations = 450
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.4/14
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [290.84,291.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 4/14:
#         * After LR finder: LR_NN=0.0005 with mse=2.2999631374861256 at it=24
#         * v0 = 25.37825024103332
#         * MSE = 26.167182844226087
#         * iterations = 400
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.5/14
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [102.24,103.04]
# ----------------------------------------------------------------------------------------------------
#         For scene 5/14:
#         * After LR finder: LR_NN=0.001 with mse=11.795979837002916 at it=24
#         * v0 = 31.34829198332158
#         * MSE = 1.7250906170577591
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.6/14
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [237.64,238.04]
# ----------------------------------------------------------------------------------------------------
#         For scene 6/14:
#         * After LR finder: LR_NN=0.0001 with mse=0.432046573484395 at it=24
#         * v0 = 29.702967492374658
#         * MSE = 0.7803851070511701
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.7/14
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [256.44,257.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 7/14:
#         * After LR finder: LR_NN=0.001 with mse=17.803029382155476 at it=24
#         * v0 = 17.104258674665953
#         * MSE = 3.487323527068175
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.8/14
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [130.04,130.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 8/14:
#         * After LR finder: LR_NN=0.0005 with mse=9.639882218306958 at it=24
#         * v0 = 41.05562230485235
#         * MSE = 0.4020499214682922
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.9/14
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [251.64,252.64]
# ----------------------------------------------------------------------------------------------------
#         For scene 9/14:
#         * After LR finder: LR_NN=0.001 with mse=36.976465959793025 at it=24
#         * v0 = 19.824906088024314
#         * MSE = 26.637184720024166
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.10/14
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [225.24,226.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 10/14:
#         * After LR finder: LR_NN=1e-05 with mse=51.15019270909074 at it=24
#         * v0 = 13.143683398703345
#         * MSE = 4.7554473592687545
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.11/14
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [239.84,240.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 11/14:
#         * After LR finder: LR_NN=0.0001 with mse=4.414838918043416 at it=24
#         * v0 = 30.131239538598884
#         * MSE = 5.172281470470173
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.12/14
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [350.64,351.64]
# ----------------------------------------------------------------------------------------------------
#         For scene 12/14:
#         * After LR finder: LR_NN=0.001 with mse=13.339410193628503 at it=24
#         * v0 = 24.017556031658028
#         * MSE = 1.6487311512733223
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.13/14
# ----------------------------------------------------------------------------------------------------
# We have 7 time intervals inside [593.04,594.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 13/14:
#         * After LR finder: LR_NN=0.001 with mse=30.02028320431729 at it=24
#         * v0 = 20.297836048725625
#         * MSE = 4.566540500866039
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.14/14
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [222.64,223.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 14/14:
#         * After LR finder: LR_NN=0.0005 with mse=25.185673993033642 at it=24
#         * v0 = 12.428538122911196
#         * MSE = 2.0160461423985967
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 7.447619253982295
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (7 scenes)
# ====================================================================================================
# DataFrame n.8. Scene n.1/7
#         For scene 1/7:
#         * MSE = 1.6093238322097687
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.2/7
#         For scene 2/7:
#         * MSE = 3.9413807080462715
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.3/7
#         For scene 3/7:
#         * MSE = 2.2159612922635623
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.4/7
#         For scene 4/7:
#         * MSE = 4.728256849080197
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.5/7
#         For scene 5/7:
#         * MSE = 1.614248191702641
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.6/7
#         For scene 6/7:
#         * MSE = 5.3038336477597126
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.7/7
#         For scene 7/7:
#         * MSE = 2.4016107073080093
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 3.1163736040528804
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 7.447619253982295
#           * MSE test: 3.1163736040528804
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#
#
#
# Analyzing 2/2 dfs.
# In DataFrame n.9 we have 9 scenes.
#     To train the model we use 6 scenes, the remaining 3 to test the model.
#
# Training step. (6 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/6
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [5.40,6.00]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/6:
#         * After LR finder: LR_NN=1e-05 with mse=47.8743707367637 at it=24
#         * v0 = 29.081107080157135
#         * MSE = 4.3910695257988515
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [205.80,206.20]
# ----------------------------------------------------------------------------------------------------
#         For scene 2/6:
#         * After LR finder: LR_NN=0.0001 with mse=1.329426479466408 at it=24
#         * v0 = 23.158651176007034
#         * MSE = 0.5411590963060217
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/6
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside [37.80,39.00]
# ----------------------------------------------------------------------------------------------------
#         For scene 3/6:
#         * After LR finder: LR_NN=5e-05 with mse=46.623057789136396 at it=24
#         * v0 = 23.639051069298038
#         * MSE = 0.6679916646445316
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.4/6
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [117.80,118.40]
# ----------------------------------------------------------------------------------------------------
#         For scene 4/6:
#         * After LR finder: LR_NN=0.0001 with mse=7.341597946740017 at it=24
#         * v0 = 32.94782563350095
#         * MSE = 0.37374555139725435
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.5/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [44.40,44.80]
# ----------------------------------------------------------------------------------------------------
#         For scene 5/6:
#         * After LR finder: LR_NN=0.0001 with mse=5.443091035077905 at it=24
#         * v0 = 18.016106720508347
#         * MSE = 0.14152166954182885
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.6/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [120.20,120.60]
# ----------------------------------------------------------------------------------------------------
#         For scene 6/6:
#         * After LR finder: LR_NN=5e-05 with mse=1.5918189277047714 at it=24
#         * v0 = 27.348987307571587
#         * MSE = 0.1888999966889887
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 1.0507312507295794
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (3 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/3
#         For scene 1/3:
#         * MSE = 0.27524048091885733
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/3
#         For scene 2/3:
#         * MSE = 0.8174618738011068
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/3
#         For scene 3/3:
#         * MSE = 0.1192962049883386
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 0.40399951990276756
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 1.0507312507295794
#           * MSE test: 0.40399951990276756
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -

# %% [markdown]
# ## Plot

# %%
# Initialize the fig
nrow, ncol = 1, 3
width, height = 7, 5 # single subplot
fig, axes = plt.subplots(nrow,ncol,figsize=(width*ncol*.75,height*.75))

ms2kmh = 3.6

info_train = info_dataset[info_dataset["type"] == "train"]
info_test = info_dataset[info_dataset["type"] == "test"]
info_grouped = info_dataset.groupby(['N. file', 'type']).mean(numeric_only=True)
info_grouped2 = info_dataset.groupby(['N. file']).mean(numeric_only=True)
info_avg = info_dataset.groupby(['type']).mean(numeric_only=True)

# For each scene, plot v0 mean
for _, scn in info_train.iterrows():
    axes[0].scatter(scn['N. file'], scn['v0']*ms2kmh, alpha = .2, color = 'darkblue');
    
for _, scn in info_test.iterrows():
    axes[1].scatter(scn['N. file'], scn['v0']*ms2kmh, alpha = .2, color = 'darkblue');

# Avg value
for (nf,typef), infof in info_grouped.iterrows():
    
    if typef == "train":
        axes[0].plot(nf, infof['v0']*ms2kmh, color = 'r', marker="x")
        
    if typef == "test":
        axes[1].plot(nf, infof['v0']*ms2kmh, color = 'r', marker="x")

# For each scene, plot v0 mean
for _, scn in info_dataset.iterrows():
    axes[2].scatter(scn['N. file'], scn['v0']*ms2kmh, alpha = .2, color = 'darkblue');

# For a dataset, plot v0 mean (averaging v0 mean in all the scenes)
for nf, p in info_grouped2.iterrows():
    axes[2].plot(nf, p['v0']*ms2kmh, color = 'r', marker="x")

# Plot v0 mean over all dfs
alldfs = [a for a, _ in info_dataset.groupby('N. file')]
v0_mean = np.mean([ infof['v0']*ms2kmh for _, infof in info_grouped.iterrows()])
axes[0].plot(alldfs, [info_avg['v0']['train']*ms2kmh]*len(alldfs), color = 'r')  
axes[1].plot(alldfs, [info_avg['v0']['test']*ms2kmh]*len(alldfs), color = 'r')  
axes[2].plot(alldfs, [v0_mean]*len(alldfs), color = 'r')  

# labeling     
axes[0].set_title(fr"$Train$",fontsize=12)
axes[1].set_title(fr"$Test$",fontsize=12)
axes[2].set_title(fr"$All$",fontsize=12)
fig.supxlabel(r"$data set$",fontsize=14, y=0.0005)
fig.supylabel(r"$v_{0}\ [km/h]$",fontsize=14, x = 0.075)
plt.suptitle(fr"$Velocities\ v_{0}\ of\ the\ leading\ car\ -\ with\ NN\ structure\ {str(doe)}$",
             fontsize=18, y=1)

# Setting the values for all axes.
custom_xlim = (0.75,10.25)
custom_xticks = range(1,11)
plt.setp(axes, xlim=custom_xlim, xticks=custom_xticks)

axes[0].grid(color='grey', linestyle='-', linewidth=0.5);
axes[1].grid(color='grey', linestyle='-', linewidth=0.5);
axes[2].grid(color='grey', linestyle='-', linewidth=0.5);

plt.show()

# %% [markdown]
# > **WARNING**: The maximal km speed allowed on the highway is 100 h

# %% [markdown]
# ### Initialize the output dir

# %%
# Prepare the directory..
if flag_save:
    
    df_seen = [df['N. file'][0] for df in dataset]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}_{NUM_ITER}it_{test}ts")
    
    path = 'out/' + d
    os.mkdir(path)

# %%
# Save figure
if flag_save:
    
    ext = ".svg"
    
    title = f"/v0_df{df_seen_str}_{NUM_ITER}it"
    
    fig.savefig(path+title+ext, bbox_inches='tight')

# %% [markdown]
# ### Store data in .txt

# %%
# Save the solution in a file
if flag_save:
    
    namefile = '/info_dataset.txt'

    with open(path + namefile, 'w') as output:
        info_dataset.to_csv(path + namefile, sep=',', index=False)
