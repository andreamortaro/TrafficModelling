# %% [markdown]
# # Writing a training loop from scratch
# https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-09-11 10:51:15.520168: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
merged_df, dflist = load_dataset(dir_name, 'post')

# %% [markdown]
# ## Create the model NN

# %%
# Create the model
DOE =[[1,2,1]] #Design of experiment

# %%
# Create the dataset using scene
df = dflist[8]
len(df)
# Out:
# 9

# %%
## FOR NN
v0 = 30
NUM_ITER=500
LEARNING_RATE_v0 = 0.5

# %%
info_df = solve_nn_df(df, DOE[0], v0, NUM_ITER, LEARNING_RATE_v0=0.5)
# Out:
# df n.9, scene n.0/9
# ====================================================================================================
#     We have 3 time intervals inside [5.40,6.00]
#             - Time interval n.0: [5.40, 5.60]
#                 * y_true: [17.46255149 32.38946228]
#                 * v_ann: [25.22081756591797, 27.024213790893555, 29.081107080157107]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [5.60, 5.80]
#                 * y_true: [27.89361325 30.52270411]
#                 * v_ann: [27.11741828918457, 26.853918075561523, 29.081107080157107]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [5.80, 6.00]
#                 * y_true: [26.75613901 28.6867411 ]
#                 * v_ann: [29.51318359375, 27.827728271484375, 29.081107080157107]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 1.4426330552061974
#     * Learning rate NN = 0.0002952449722215533
#     * diff = 0.0023905234624983507
#         For scene 0/9
#         * use LR_NN=0.0005 with err=32.29843439028582 at it=24
#         * v0_scn_mean = 29.13624061409139
#         * MAE = 1.257207329016917
#
# ====================================================================================================
#
#
# df n.9, scene n.1/9
# ====================================================================================================
#     We have 2 time intervals inside [20.80,21.20]
#             - Time interval n.0: [20.80, 21.00]
#                 * y_true: [29.01888251 26.46522664]
#                 * v_ann: [27.705659866333008, 27.209997177124023, 32.733311571962865]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [21.00, 21.20]
#                 * y_true: [29.93697896 25.84808908]
#                 * v_ann: [27.94130516052246, 28.407827377319336, 32.733311571962865]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.14192676615434105
#     * Learning rate NN = 0.00036449998151510954
#     * diff = 0.0002561607013581435
#         For scene 1/9
#         * use LR_NN=0.0005 with err=13.703614156412256 at it=24
#         * v0_scn_mean = 32.56931300036488
#         * MAE = 0.13828281410392046
#
# ====================================================================================================
#
#
# df n.9, scene n.2/9
# ====================================================================================================
#     We have 6 time intervals inside [37.80,39.00]
#             - Time interval n.0: [37.80, 38.00]
#                 * y_true: [21.35828745 27.25004814]
#                 * v_ann: [21.25226402282715, 21.66852378845215, 23.639051069298016]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [38.00, 38.20]
#                 * y_true: [19.23626153 17.91519282]
#                 * v_ann: [22.816455841064453, 22.697307586669922, 23.639051069298016]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [38.20, 38.40]
#                 * y_true: [24.96063116 28.62771944]
#                 * v_ann: [21.525787353515625, 21.05706024169922, 23.639051069298016]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.3: [38.40, 38.60]
#                 * y_true: [24.1844348  25.71934895]
#                 * v_ann: [23.552989959716797, 22.573097229003906, 23.639051069298016]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.4: [38.60, 38.80]
#                 * y_true: [26.26418379 21.80127307]
#                 * v_ann: [24.359590530395508, 23.40102195739746, 23.639051069298016]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.5: [38.80, 39.00]
#                 * y_true: [15.9216195  19.51476921]
#                 * v_ann: [23.799030303955078, 23.439170837402344, 23.639051069298016]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.8503978107524928
#     * Learning rate NN = 0.00015690525469835848
#     * diff = 0.03170612789550298
#         For scene 2/9
#         * use LR_NN=0.0005 with err=42.578285209974155 at it=24
#         * v0_scn_mean = 24.020707719547254
#         * MAE = 0.840309067812798
#
# ====================================================================================================
#
#
# df n.9, scene n.3/9
# ====================================================================================================
#     We have 2 time intervals inside [44.40,44.80]
#             - Time interval n.0: [44.40, 44.60]
#                 * y_true: [24.95803839 22.94664651]
#                 * v_ann: [26.949363708496094, 27.559419631958008, 18.0161067205083]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [44.60, 44.80]
#                 * y_true: [22.38974011 30.85088397]
#                 * v_ann: [21.768413543701172, 23.578298568725586, 18.0161067205083]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.16557346230329958
#     * Learning rate NN = 0.00036449998151510954
#     * diff = 0.0003706964340427221
#         For scene 3/9
#         * use LR_NN=0.0005 with err=5.656277654889567 at it=24
#         * v0_scn_mean = 18.735139779226905
#         * MAE = 0.14922792189800507
#
# ====================================================================================================
#
#
# df n.9, scene n.4/9
# ====================================================================================================
#     We have 3 time intervals inside [117.80,118.40]
#             - Time interval n.0: [117.80, 118.00]
#                 * y_true: [26.21501314 26.51617559]
#                 * v_ann: [25.73366928100586, 24.870281219482422, 32.94782563350118]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [118.00, 118.20]
#                 * y_true: [24.27291409 32.45579962]
#                 * v_ann: [25.925418853759766, 26.057025909423828, 32.94782563350118]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [118.20, 118.40]
#                 * y_true: [21.96072195 23.86482679]
#                 * v_ann: [25.648025512695312, 26.59052085876465, 32.94782563350118]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.469939752948513
#     * Learning rate NN = 5.904899080633186e-05
#     * diff = 0.000217476302580899
#         For scene 4/9
#         * use LR_NN=0.0001 with err=7.24087039381239 at it=24
#         * v0_scn_mean = 32.770956227842014
#         * MAE = 0.42708082913601936
#
# ====================================================================================================
#
#
# df n.9, scene n.5/9
# ====================================================================================================
#     We have 2 time intervals inside [119.20,119.60]
#             - Time interval n.0: [119.20, 119.40]
#                 * y_true: [23.20444186 22.52067771]
#                 * v_ann: [25.70152473449707, 24.014663696289062, 26.73458983053842]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [119.40, 119.60]
#                 * y_true: [27.39348249 26.5570173 ]
#                 * v_ann: [25.296661376953125, 24.62902069091797, 26.73458983053842]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.04038236220424817
#     * Learning rate NN = 7.289998757187277e-05
#     * diff = 9.381386618105558e-05
#         For scene 5/9
#         * use LR_NN=0.0001 with err=0.2975685308471308 at it=24
#         * v0_scn_mean = 26.930514294096255
#         * MAE = 0.039631317442723996
#
# ====================================================================================================
#
#
# df n.9, scene n.6/9
# ====================================================================================================
#     We have 2 time intervals inside [120.20,120.60]
#             - Time interval n.0: [120.20, 120.40]
#                 * y_true: [30.48045094 26.16776015]
#                 * v_ann: [25.264862060546875, 26.841684341430664, 27.3489873075713]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [120.40, 120.60]
#                 * y_true: [26.23623075 25.12734403]
#                 * v_ann: [27.392255783081055, 28.19791603088379, 27.3489873075713]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.289721379450196
#     * Learning rate NN = 7.289998757187277e-05
#     * diff = 0.00012600561848852276
#         For scene 6/9
#         * use LR_NN=0.0001 with err=1.6679187688852883 at it=24
#         * v0_scn_mean = 27.50804795009231
#         * MAE = 0.289721379450196
#
# ====================================================================================================
#
#
# df n.9, scene n.7/9
# ====================================================================================================
#     We have 3 time intervals inside [121.40,122.00]
#             - Time interval n.0: [121.40, 121.60]
#                 * y_true: [23.88369588 31.34452269]
#                 * v_ann: [27.201078414916992, 25.756851196289062, 28.657528434578015]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [121.60, 121.80]
#                 * y_true: [22.66516063 24.1738881 ]
#                 * v_ann: [25.581485748291016, 26.99150276184082, 28.657528434578015]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [121.80, 122.00]
#                 * y_true: [27.39865086 24.79107704]
#                 * v_ann: [24.312124252319336, 24.248071670532227, 28.657528434578015]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.37978577665916063
#     * Learning rate NN = 0.0005904899444431067
#     * diff = 0.0008408652530974559
#         For scene 7/9
#         * use LR_NN=0.001 with err=16.448369972534714 at it=24
#         * v0_scn_mean = 28.738076668229088
#         * MAE = 0.2672814819712288
#
# ====================================================================================================
#
#
# df n.9, scene n.8/9
# ====================================================================================================
#     We have 2 time intervals inside [205.80,206.20]
#             - Time interval n.0: [205.80, 206.00]
#                 * y_true: [16.81767795  9.52209489]
#                 * v_ann: [12.144136428833008, 12.535358428955078, 23.15865117600718]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [206.00, 206.20]
#                 * y_true: [13.65726133  9.1692133 ]
#                 * v_ann: [12.267495155334473, 12.222195625305176, 23.15865117600718]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.4663235087985471
#     * Learning rate NN = 7.289998757187277e-05
#     * diff = 0.0020672114386560136
#         For scene 8/9
#         * use LR_NN=0.0001 with err=1.3234502970307973 at it=24
#         * v0_scn_mean = 23.56913179828478
#         * MAE = 0.35964898592320277
#
# ====================================================================================================

# %%
for nscn, scn in info_df.iterrows():
    print(f"Scene n.{str(nscn).zfill(2)}: v0 mean is {'{0:0f}'.format(scn['v0_scn_mean'])}")
print(f"\nThe mean over all the scenes is {info_df['v0_scn_mean'].mean()}")
# Out:
# Scene n.00: v0 mean is 29.136241
# Scene n.01: v0 mean is 32.569313
# Scene n.02: v0 mean is 24.020708
# Scene n.03: v0 mean is 18.735140
# Scene n.04: v0 mean is 32.770956
# Scene n.05: v0 mean is 26.930514
# Scene n.06: v0 mean is 27.508048
# Scene n.07: v0 mean is 28.738077
# Scene n.08: v0 mean is 23.569132
#
# The mean over all the scenes is 27.108680894641655
