# %% [markdown]
# # Writing a training loop from scratch
# https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-09-27 19:58:35.709382: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
merged_df, dflist = load_dataset(dir_name, 'post')

# %% [markdown]
# ## Create the model NN

# %%
# Create the model
DOE =[[1,2,1]] #Design of experiment

# %%
# Create the dataset using scene
df = dflist[8]
len(df)
# Out:
# 9

# %%
## FOR NN
v0 = 30
NUM_ITER=500
LEARNING_RATE_v0 = 0.5

# %%
info_df = solve_nn_df(df, DOE[0], v0, NUM_ITER, LEARNING_RATE_v0=0.5)
# Out:
# df n.9, scene n.0/9
# ====================================================================================================
#     We have 3 time intervals inside [5.40,6.00]
#             - Time interval n.0: [5.40, 5.60]
#                 * y_true: [17.46255149 32.38946228]
#                 * v_ann: [24.602262496948242, 27.028278350830078, 29.08110708015712]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [5.60, 5.80]
#                 * y_true: [27.89361325 30.52270411]
#                 * v_ann: [27.23552131652832, 26.84336280822754, 29.08110708015712]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [5.80, 6.00]
#                 * y_true: [26.75613901 28.6867411 ]
#                 * v_ann: [29.877931594848633, 27.929967880249023, 29.08110708015712]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 1.374667654811647
#     * Learning rate NN = 0.0005904899444431067
#     * diff = 0.01585809473465294
#         For scene 0/9
#         * use LR_NN=0.001 with err=28.598775214646267 at it=24
#         * v0_scn_mean = 29.13624061409139
#         * MAE = 1.374667654811647
#
# ====================================================================================================
#
#
# df n.9, scene n.1/9
# ====================================================================================================
#     We have 2 time intervals inside [20.80,21.20]
#             - Time interval n.0: [20.80, 21.00]
#                 * y_true: [29.01888251 26.46522664]
#                 * v_ann: [27.60849952697754, 26.914432525634766, 32.73331157196294]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [21.00, 21.20]
#                 * y_true: [29.93697896 25.84808908]
#                 * v_ann: [28.025850296020508, 28.683887481689453, 32.73331157196294]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.14133497816827537
#     * Learning rate NN = 0.0007289999630302191
#     * diff = 0.00018963446857883648
#         For scene 1/9
#         * use LR_NN=0.001 with err=14.436327859057442 at it=24
#         * v0_scn_mean = 32.56931300036488
#         * MAE = 0.1358130962694898
#
# ====================================================================================================
#
#
# df n.9, scene n.2/9
# ====================================================================================================
#     We have 6 time intervals inside [37.80,39.00]
#             - Time interval n.0: [37.80, 38.00]
#                 * y_true: [21.35828745 27.25004814]
#                 * v_ann: [20.312089920043945, 21.18225860595703, 23.63905106929799]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [38.00, 38.20]
#                 * y_true: [19.23626153 17.91519282]
#                 * v_ann: [22.77635955810547, 22.57674789428711, 23.63905106929799]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [38.20, 38.40]
#                 * y_true: [24.96063116 28.62771944]
#                 * v_ann: [20.892900466918945, 20.684722900390625, 23.63905106929799]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.3: [38.40, 38.60]
#                 * y_true: [24.1844348  25.71934895]
#                 * v_ann: [24.069477081298828, 22.76400375366211, 23.63905106929799]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.4: [38.60, 38.80]
#                 * y_true: [26.26418379 21.80127307]
#                 * v_ann: [25.044832229614258, 23.52027702331543, 23.63905106929799]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.5: [38.80, 39.00]
#                 * y_true: [15.9216195  19.51476921]
#                 * v_ann: [24.040943145751953, 23.4334716796875, 23.63905106929799]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.976159906905454
#     * Learning rate NN = 0.00031381050939671695
#     * diff = 0.04626933646278275
#         For scene 2/9
#         * use LR_NN=0.001 with err=36.84876881133204 at it=24
#         * v0_scn_mean = 24.020707719547303
#         * MAE = 0.9591928363587399
#
# ====================================================================================================
#
#
# df n.9, scene n.3/9
# ====================================================================================================
#     We have 2 time intervals inside [44.40,44.80]
#             - Time interval n.0: [44.40, 44.60]
#                 * y_true: [24.95803839 22.94664651]
#                 * v_ann: [25.121143341064453, 25.715482711791992, 18.0161067205083]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [44.60, 44.80]
#                 * y_true: [22.38974011 30.85088397]
#                 * v_ann: [24.853771209716797, 25.144317626953125, 18.0161067205083]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.11682061356975354
#     * Learning rate NN = 3.6449993785936385e-05
#     * diff = 0.001630036869688753
#         For scene 3/9
#         * use LR_NN=5e-05 with err=5.423218911483943 at it=24
#         * v0_scn_mean = 18.735139779226927
#         * MAE = 0.09962487309069883
#
# ====================================================================================================
#
#
# df n.9, scene n.4/9
# ====================================================================================================
#     We have 3 time intervals inside [117.80,118.40]
#             - Time interval n.0: [117.80, 118.00]
#                 * y_true: [26.21501314 26.51617559]
#                 * v_ann: [25.315967559814453, 24.886058807373047, 32.94782563350115]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [118.00, 118.20]
#                 * y_true: [24.27291409 32.45579962]
#                 * v_ann: [25.600860595703125, 26.02950096130371, 32.94782563350115]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [118.20, 118.40]
#                 * y_true: [21.96072195 23.86482679]
#                 * v_ann: [25.8949031829834, 26.75209617614746, 32.94782563350115]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.44789569363114823
#     * Learning rate NN = 5.904899080633186e-05
#     * diff = 0.0025222789662781575
#         For scene 4/9
#         * use LR_NN=0.0001 with err=8.149203287137658 at it=24
#         * v0_scn_mean = 32.77095622784192
#         * MAE = 0.38226588799027644
#
# ====================================================================================================
#
#
# df n.9, scene n.5/9
# ====================================================================================================
#     We have 2 time intervals inside [119.20,119.60]
#             - Time interval n.0: [119.20, 119.40]
#                 * y_true: [23.20444186 22.52067771]
#                 * v_ann: [25.54401397705078, 25.651729583740234, 26.734589830538468]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [119.40, 119.60]
#                 * y_true: [27.39348249 26.5570173 ]
#                 * v_ann: [24.200410842895508, 24.27400016784668, 26.734589830538468]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.07553221185195494
#     * Learning rate NN = 7.289998757187277e-05
#     * diff = 0.0006446505427403632
#         For scene 5/9
#         * use LR_NN=0.0001 with err=0.3210341262555307 at it=24
#         * v0_scn_mean = 26.93051429409627
#         * MAE = 0.07442865315238927
#
# ====================================================================================================
#
#
# df n.9, scene n.6/9
# ====================================================================================================
#     We have 2 time intervals inside [120.20,120.60]
#             - Time interval n.0: [120.20, 120.40]
#                 * y_true: [30.48045094 26.16776015]
#                 * v_ann: [25.269954681396484, 26.798410415649414, 27.3489873075715]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [120.40, 120.60]
#                 * y_true: [26.23623075 25.12734403]
#                 * v_ann: [27.14461898803711, 28.399938583374023, 27.3489873075715]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.30364401513020706
#     * Learning rate NN = 7.289998757187277e-05
#     * diff = 0.0005832857640867273
#         For scene 6/9
#         * use LR_NN=0.0001 with err=1.5625551184938808 at it=24
#         * v0_scn_mean = 27.50804795009236
#         * MAE = 0.30364401513020706
#
# ====================================================================================================
#
#
# df n.9, scene n.7/9
# ====================================================================================================
#     We have 3 time intervals inside [121.40,122.00]
#             - Time interval n.0: [121.40, 121.60]
#                 * y_true: [23.88369588 31.34452269]
#                 * v_ann: [27.22449493408203, 25.708234786987305, 28.657528434577824]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [121.60, 121.80]
#                 * y_true: [22.66516063 24.1738881 ]
#                 * v_ann: [25.46486473083496, 26.931156158447266, 28.657528434577824]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.2: [121.80, 122.00]
#                 * y_true: [27.39865086 24.79107704]
#                 * v_ann: [24.4140567779541, 24.36631202697754, 28.657528434577824]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.3803104937315873
#     * Learning rate NN = 0.0005904899444431067
#     * diff = 0.0008550990140503978
#         For scene 7/9
#         * use LR_NN=0.001 with err=13.043042486380712 at it=24
#         * v0_scn_mean = 28.7380766682291
#         * MAE = 0.23249978741885471
#
# ====================================================================================================
#
#
# df n.9, scene n.8/9
# ====================================================================================================
#     We have 2 time intervals inside [205.80,206.20]
#             - Time interval n.0: [205.80, 206.00]
#                 * y_true: [16.81767795  9.52209489]
#                 * v_ann: [11.994449615478516, 12.071198463439941, 23.15865117600664]
#
# ----------------------------------------------------------------------------------------------------
#             - Time interval n.1: [206.00, 206.20]
#                 * y_true: [13.65726133  9.1692133 ]
#                 * v_ann: [12.494924545288086, 12.508294105529785, 23.15865117600664]
#
# ----------------------------------------------------------------------------------------------------
#     * err= 0.4475429713301902
#     * Learning rate NN = 0.00036449998151510954
#     * diff = 0.00010300007324676175
#         For scene 8/9
#         * use LR_NN=0.0005 with err=1.339934670226401 at it=24
#         * v0_scn_mean = 23.569131798284904
#         * MAE = 0.43111189548908885
#
# ====================================================================================================

# %%
for nscn, scn in info_df.iterrows():
    print(f"Scene n.{str(nscn).zfill(2)}: v0 mean is {'{0:0f}'.format(scn['v0_scn_mean'])}")
print(f"\nThe mean over all the scenes is {info_df['v0_scn_mean'].mean()}")
# Out:
# Scene n.00: v0 mean is 29.136241
# Scene n.01: v0 mean is 32.569313
# Scene n.02: v0 mean is 24.020708
# Scene n.03: v0 mean is 18.735140
# Scene n.04: v0 mean is 32.770956
# Scene n.05: v0 mean is 26.930514
# Scene n.06: v0 mean is 27.508048
# Scene n.07: v0 mean is 28.738077
# Scene n.08: v0 mean is 23.569132
#
# The mean over all the scenes is 27.108680894641672
