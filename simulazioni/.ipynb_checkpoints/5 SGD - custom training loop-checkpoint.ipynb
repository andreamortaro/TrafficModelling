# %% [markdown]
# # Writing a training loop from scratch
# https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_models import *
from ipynb.fs.full.myfun_nn import *
from ipynb.fs.full.myfun_opt import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-08-27 09:12:59.503252: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
merged_df, dflist = load_dataset(dir_name, 'post')

# %% [markdown]
# ## Create the model NN

# %%
# Create the model
DOE =[[1,2,1]] #Design of experiment
model = create_model(DOE[0])

# %% [markdown]
# ### What do trainable variables and trainable weights mean?

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-Layer-1 (Dense)      (None, 2)                 4
#
#  Output-Layer (Dense)        (None, 1)                 3
#
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables), len(model.trainable_weights)
# Out:
# (4, 4)

# %%
for var in model.trainable_variables:
    print(f"{var.name}:\t {var.numpy().flatten()}")
# Out:
# Hidden-Layer-1/kernel:0:	 [-0.7134054  -0.10313654]
# Hidden-Layer-1/bias:0:	 [-0.32015252 -0.06451344]
# Output-Layer/kernel:0:	 [ 0.99099994 -0.90536094]
# Output-Layer/bias:0:	 [-0.32161975]

# %% [markdown]
# ## Training loop

# %%
NUM_EPOCHS = 100
step_upd = 5
LEARNING_RATE = 0.01
deltat = 0.05
v0 = 30

# %%
# Create the dataset using scene
df = dflist[0]
scn_list = seq2scn(df)
scn_train, scn_test = train_test_split(scn_list, test_size=0.8, random_state=42)

# %%
len(scn_train)
# Out:
# 6

# %%
for step, scn in enumerate(scn_train):
    print(f"\nStep n. {step}")
    print("=="*50)
    
    N, tstamps = scn['N. vehicles'], scn['Tarr']
    x_list, t_list, v_list = [[i] for i in scn['Xarr'][:,0]], [scn['Tarr'][0]], []

    X_arr, y_arr = create_data_ann_scene(scn)
    formatter = '{0:.02f}'

    print("--"*50)
    print(f"Scene n. {scn.name}, time interval: [{formatter.format(tstamps[0])},{formatter.format(tstamps[-1])}]")
#     print(f"We have {len(tstamps)-1} time intervals inside\
#     [{formatter.format(tstamps[0])},{formatter.format(tstamps[-1])}]\n")
    
    for i in range(0,len(tstamps)-1):

#       print("--"*50)
#       print(f"Time interval n.{i}: [{formatter.format(scn['Tarr'][i])}, {formatter.format(scn['Tarr'][i+1])}]\n")

        ## STEP 1: Create the dataset and train the nn model
        X, y = X_arr[:,i], y_arr[:,i]

        # TRAINING
        loss_value, grads = custom_training(model, X, y, NUM_EPOCHS, step_upd, LEARNING_RATE)
        print_grads(model, grads) # plot the last grads wrt trainable vars
    
        # Predict the rhs of the TD_ANN_model
        y_pred = model(X)
        v_list.append(np.append(y_pred.numpy().flatten().tolist(),v0).tolist())
        
        ## STEP 2: Solve the ODE sys in this time interval
        x0 = [l[-1] for l in np.vstack(x_list).tolist()]  # last values computed
        t0, tend = scn['Tarr'][i], scn['Tarr'][i+1]
        v_ann = v_list[i]
        tspan_ann, sol_ann = odesolver_ann(x0, v_ann, t0, tend, deltat)

        ## STEP 3: Update x_ann_list, t_ann_list
        x_ann = sol_ann.tolist()
        t_ann = tspan_ann[1:] # avoid the first recording

        # add sol to the correct veh
        for j in range(0,N):
            tmp = x_ann[j][1:] # avoid the first recording
            x_list[j] = np.concatenate([x_list[j],tmp])
        t_list = np.concatenate([t_list,t_ann]).tolist()
#             print("--"*50)


    # plot function
    t_ann_matched, trajs_ann_matched = match_timestamps_scene(t_list, x_list)
    tscale = 1+(tstamps[-1]-tstamps[0])/10000
    title = f"{step} - Scene n. {scn.name}"
    plot_scn(scn, trajs_ann_matched, title, xbal=0.01, ybal=0.05, scale=tscale)

    print("--"*50)
# Out:
# Step n. 0
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# Scene n. 20, time interval: [363.44,364.04]
# Training acc over 100 epoch: 4782.0674
# Time taken: 0.01s
# Grads
# Hidden-Layer-1/kernel:0:	 [0.         0.63226175]
# Hidden-Layer-1/bias:0:	 [0.         0.11508537]
# Output-Layer/kernel:0:	 [ 0.         -0.15600136]
# Output-Layer/bias:0:	 [-43.77579]
# Training acc over 100 epoch: 2623.0381
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0.         0.17539209]
# Hidden-Layer-1/bias:0:	 [0.         0.02709215]
# Output-Layer/kernel:0:	 [ 0.         -0.03718843]
# Output-Layer/bias:0:	 [-34.42951]
# Training acc over 100 epoch: 1816.3475
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0.         0.03498154]
# Hidden-Layer-1/bias:0:	 [0.         0.00440673]
# Output-Layer/kernel:0:	 [ 0.         -0.00605702]
# Output-Layer/bias:0:	 [-23.105824]
# ----------------------------------------------------------------------------------------------------
#
# Step n. 1
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# Scene n. 33, time interval: [313.44,313.84]
# Training acc over 100 epoch: 192378.1875
# Time taken: 0.01s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [253.51291]
# Training acc over 100 epoch: 153904.6406
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [4.3436975]
# ----------------------------------------------------------------------------------------------------
#
# Step n. 2
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# Scene n. 7, time interval: [161.64,162.04]
# Training acc over 100 epoch: 128255.2031
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [1.318119]
# Training acc over 100 epoch: 109933.0312
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [0.9465523]
# ----------------------------------------------------------------------------------------------------
#
# Step n. 3
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# Scene n. 10, time interval: [216.64,217.04]
# Training acc over 100 epoch: 96195.5781
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [-8.97488]
# Training acc over 100 epoch: 85510.4453
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [-7.320759]
# ----------------------------------------------------------------------------------------------------
#
# Step n. 4
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# Scene n. 14, time interval: [262.64,263.64]
# Training acc over 100 epoch: 76960.1719
# Time taken: 0.01s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [-3.338585]
# Training acc over 100 epoch: 69970.7891
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [8.392721]
# Training acc over 100 epoch: 64145.2266
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [-0.29921913]
# Training acc over 100 epoch: 59211.5938
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [2.924183]
# Training acc over 100 epoch: 54994.1953
# Time taken: 0.01s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [0.86305237]
# ----------------------------------------------------------------------------------------------------
#
# Step n. 5
# ====================================================================================================
# ----------------------------------------------------------------------------------------------------
# Scene n. 28, time interval: [500.64,501.04]
# Training acc over 100 epoch: 51337.8945
# Time taken: 0.00s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [19.849724]
# Training acc over 100 epoch: 48131.8984
# Time taken: 0.01s
# Grads
# Hidden-Layer-1/kernel:0:	 [0. 0.]
# Hidden-Layer-1/bias:0:	 [0. 0.]
# Output-Layer/kernel:0:	 [0. 0.]
# Output-Layer/bias:0:	 [10.42094]
# ----------------------------------------------------------------------------------------------------
