# %% [markdown]
# # Writing a training loop from scratch
# https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_models import *
from ipynb.fs.full.myfun_nn import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-09-05 17:36:30.891774: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
merged_df, dflist = load_dataset(dir_name, 'post')

# %% [markdown]
# ## Create the model NN

# %%
# Create the model
DOE =[[1,2,1]] #Design of experiment
model = create_model(DOE[0])

# %% [markdown]
# ## Training loop

# %%
# Create the dataset using scene
df = dflist[0]
dataset = df[:5]
len(dataset)
# Out:
# 5

# %%
## FOR NN
v0_guess = 30
NUM_ITER=250
LEARNING_RATE_v0 = 0.5

# %%
## FOR OPTIMIZING v0
loss_objective = tf.keras.losses.MeanSquaredError()
LEARNING_RATE_v0 = 0.5

# %%
info_df = solve_nn_df(df, model, v0_guess, NUM_ITER, LEARNING_RATE_v0, flag_print=True)
# Out:
# ====================================================================================================
#         For scene 0/28
#         * use LR_NN=1e-07 with err=34.54141526244562 at it=24
#         * v0_scn_mean = 27.91986564628255
# ====================================================================================================
#         For scene 1/28
#         * use LR_NN=1e-07 with err=168.2476412091253 at it=24
#         * v0_scn_mean = 31.042319784474813
# ====================================================================================================
#         For scene 2/28
#         * use LR_NN=1e-07 with err=198.5361569650006 at it=24
#         * v0_scn_mean = 28.460766265790017
# ====================================================================================================
#         For scene 3/28
#         * use LR_NN=1e-07 with err=67.51295779234067 at it=24
#         * v0_scn_mean = 29.555029049037877
# ====================================================================================================
#         For scene 4/28
#         * use LR_NN=1e-07 with err=20.97489327433196 at it=24
#         * v0_scn_mean = 28.62970655035291
# ====================================================================================================
#         For scene 5/28
#         * use LR_NN=1e-07 with err=30.74301237560637 at it=24
#         * v0_scn_mean = 27.90699830343552
# ====================================================================================================
#         For scene 6/28
#         * use LR_NN=1e-07 with err=61.07986428497778 at it=24
#         * v0_scn_mean = 34.14651547207753
# ====================================================================================================
#         For scene 7/28
#         * use LR_NN=1e-07 with err=217.1737824798378 at it=24
#         * v0_scn_mean = 32.14096981011879
# ====================================================================================================
#         For scene 8/28
#         * use LR_NN=1e-07 with err=70.7673199071623 at it=24
#         * v0_scn_mean = 36.58591263039685
# ====================================================================================================
#         For scene 9/28
#         * use LR_NN=1e-07 with err=88.8213898220621 at it=24
#         * v0_scn_mean = 34.269727704503616
# ====================================================================================================
#         For scene 10/28
#         * use LR_NN=1e-07 with err=16.894279965827554 at it=24
#         * v0_scn_mean = 32.94348129408412
# ====================================================================================================
#         For scene 11/28
#         * use LR_NN=1e-07 with err=9.25543958622022 at it=24
#         * v0_scn_mean = 27.77783074238292
# ====================================================================================================
#         For scene 12/28
#         * use LR_NN=1e-07 with err=242.60542163968282 at it=24
#         * v0_scn_mean = 35.21951439428849
# ====================================================================================================
#         For scene 13/28
#         * use LR_NN=1e-07 with err=103.41303238115573 at it=24
#         * v0_scn_mean = 30.81512133150285
# ====================================================================================================
#         For scene 14/28
#         * use LR_NN=1e-07 with err=349.7835960224009 at it=24
#         * v0_scn_mean = 29.827544841127807
# ====================================================================================================
#         For scene 15/28
#         * use LR_NN=1e-07 with err=89.25076692843184 at it=24
#         * v0_scn_mean = 32.37036702311962
# ====================================================================================================
#         For scene 16/28
#         * use LR_NN=1e-07 with err=82.677040470603 at it=24
#         * v0_scn_mean = 37.85289876996364
# ====================================================================================================
#         For scene 17/28
#         * use LR_NN=1e-07 with err=145.90464491602285 at it=24
#         * v0_scn_mean = 38.22480239988609
# ====================================================================================================
#         For scene 18/28
#         * use LR_NN=1e-07 with err=74.58361041449548 at it=24
#         * v0_scn_mean = 30.074064349287834
# ====================================================================================================
#         For scene 19/28
#         * use LR_NN=1e-07 with err=17.64131484311739 at it=24
#         * v0_scn_mean = 29.60788653616247
# ====================================================================================================
#         For scene 20/28
#         * use LR_NN=1e-07 with err=101.5779017407222 at it=24
#         * v0_scn_mean = 32.27474162716476
# ====================================================================================================
#         For scene 21/28
#         * use LR_NN=1e-07 with err=16.78861227255912 at it=24
#         * v0_scn_mean = 24.335360936155418
# ====================================================================================================
#         For scene 22/28
#         * use LR_NN=1e-07 with err=58.35986029361185 at it=24
#         * v0_scn_mean = 24.43034084383508
# ====================================================================================================
#         For scene 23/28
#         * use LR_NN=1e-07 with err=29.611548241797166 at it=24
#         * v0_scn_mean = 19.29199891817705
# ====================================================================================================
#         For scene 24/28
#         * use LR_NN=1e-07 with err=22.394171909796274 at it=24
#         * v0_scn_mean = 14.477563694580505
# ====================================================================================================
#         For scene 25/28
#         * use LR_NN=1e-07 with err=102.6254895120915 at it=24
#         * v0_scn_mean = 17.310933316125787
# ====================================================================================================
#         For scene 26/28
#         * use LR_NN=1e-07 with err=15.592774388232753 at it=24
#         * v0_scn_mean = 29.783058296131756
# ====================================================================================================
#         For scene 27/28
#         * use LR_NN=1e-07 with err=67.91571501531708 at it=24
#         * v0_scn_mean = 11.81755544345724

# %%
for nscn, v0_scn_mean in info_df:
    print(f"Scene n.{nscn}: v0 mean is {v0_scn_mean}")
# Out:
# Scene n.0: v0 mean is 27.91986564628255
# Scene n.1: v0 mean is 31.042319784474813
# Scene n.2: v0 mean is 28.460766265790017
# Scene n.3: v0 mean is 29.555029049037877
# Scene n.4: v0 mean is 28.62970655035291
# Scene n.5: v0 mean is 27.90699830343552
# Scene n.6: v0 mean is 34.14651547207753
# Scene n.7: v0 mean is 32.14096981011879
# Scene n.8: v0 mean is 36.58591263039685
# Scene n.9: v0 mean is 34.269727704503616
# Scene n.10: v0 mean is 32.94348129408412
# Scene n.11: v0 mean is 27.77783074238292
# Scene n.12: v0 mean is 35.21951439428849
# Scene n.13: v0 mean is 30.81512133150285
# Scene n.14: v0 mean is 29.827544841127807
# Scene n.15: v0 mean is 32.37036702311962
# Scene n.16: v0 mean is 37.85289876996364
# Scene n.17: v0 mean is 38.22480239988609
# Scene n.18: v0 mean is 30.074064349287834
# Scene n.19: v0 mean is 29.60788653616247
# Scene n.20: v0 mean is 32.27474162716476
# Scene n.21: v0 mean is 24.335360936155418
# Scene n.22: v0 mean is 24.43034084383508
# Scene n.23: v0 mean is 19.29199891817705
# Scene n.24: v0 mean is 14.477563694580505
# Scene n.25: v0 mean is 17.310933316125787
# Scene n.26: v0 mean is 29.783058296131756
# Scene n.27: v0 mean is 11.81755544345724

# %%
v0_list = [l[1] for l in info_df]
np.array(v0_list).mean()
# Out:
# 28.896174141925137
