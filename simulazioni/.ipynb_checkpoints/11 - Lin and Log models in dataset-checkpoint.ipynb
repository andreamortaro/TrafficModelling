# %%
## Libraries
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from datetime import datetime

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.defs.myfun_models import *
# Out:
# 2023-09-09 17:33:50.647452: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
flag_processed = 'pre'
merged_df, dflist = load_dataset(dir_name, flag_processed) # we have 10 pandas dataframe, one for each couple(camera,sequence)

# %% [markdown]
# ## Solve Lin/Log models in a df

# %%
flag_save = False

# %%
info_alldataset = solve_TD_LWR_dataset(dflist, TD_LWR_model, v0=30, L=5, deltat=0.05, tol=1e-8, pplot=False)
# Out:
# ====================================================================================================
# df n.1 - Scene n.0/28
# ----------------------------------------------------------------------------------------------------
# Scene n.0.
#     Initial mse: 13.540570745869223
#
# After optimizing, new params: v0 = 31.037310071241993, L = 2.0
#
# Initial mse: 4.587983170060341
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [14.24,14.64]
# Time interval n.0: [14.24, 14.44]
# Time interval n.1: [14.44, 14.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.1/28
# ----------------------------------------------------------------------------------------------------
# Scene n.1.
#     Initial mse: 20.183806606457683
#
# After optimizing, new params: v0 = 32.04956330054356, L = 2.0
#
# Initial mse: 1.5766292627943745
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [23.64,24.64]
# Time interval n.0: [23.64, 23.84]
# Time interval n.1: [23.84, 24.04]
# Time interval n.2: [24.04, 24.24]
# Time interval n.3: [24.24, 24.44]
# Time interval n.4: [24.44, 24.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.2/28
# ----------------------------------------------------------------------------------------------------
# Scene n.2.
#     Initial mse: 4.276017483475244
#
# After optimizing, new params: v0 = 29.781073452468735, L = 2.0
#
# Initial mse: 0.9248830043237571
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [72.44,73.44]
# Time interval n.0: [72.44, 72.64]
# Time interval n.1: [72.64, 72.84]
# Time interval n.2: [72.84, 73.04]
# Time interval n.3: [73.04, 73.24]
# Time interval n.4: [73.24, 73.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.3/28
# ----------------------------------------------------------------------------------------------------
# Scene n.3.
#     Initial mse: 6.454500080061598
#
# After optimizing, new params: v0 = 29.870876877928193, L = 2.0
#
# Initial mse: 1.4613919105282338
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [84.24,84.84]
# Time interval n.0: [84.24, 84.44]
# Time interval n.1: [84.44, 84.64]
# Time interval n.2: [84.64, 84.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.4/28
# ----------------------------------------------------------------------------------------------------
# Scene n.4.
#     Initial mse: 14.069766507549742
#
# After optimizing, new params: v0 = 33.298908266151656, L = 2.0
#
# Initial mse: 3.6872257876355086
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [131.64,132.04]
# Time interval n.0: [131.64, 131.84]
# Time interval n.1: [131.84, 132.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.5/28
# ----------------------------------------------------------------------------------------------------
# Scene n.5.
#     Initial mse: 2.431135761822535
#
# After optimizing, new params: v0 = 29.26483858086897, L = 2.0
#
# Initial mse: 0.5656514468432187
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [148.04,148.44]
# Time interval n.0: [148.04, 148.24]
# Time interval n.1: [148.24, 148.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.6/28
# ----------------------------------------------------------------------------------------------------
# Scene n.6.
#     Initial mse: 6.831473374711273
#
# After optimizing, new params: v0 = 33.64079194261417, L = 2.0
#
# Initial mse: 1.2658382975981166
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [161.64,162.04]
# Time interval n.0: [161.64, 161.84]
# Time interval n.1: [161.84, 162.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.7/28
# ----------------------------------------------------------------------------------------------------
# Scene n.7.
#     Initial mse: 2.106932288431277
#
# After optimizing, new params: v0 = 32.83587801159743, L = 4.05537400827859
#
# Initial mse: 0.6952154627246843
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [164.04,164.64]
# Time interval n.0: [164.04, 164.24]
# Time interval n.1: [164.24, 164.44]
# Time interval n.2: [164.44, 164.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.8/28
# ----------------------------------------------------------------------------------------------------
# Scene n.8.
#     Initial mse: 3.54254460516298
#
# After optimizing, new params: v0 = 37.994126155798895, L = 4.979344234324688
#
# Initial mse: 0.1394656164383653
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [215.64,216.04]
# Time interval n.0: [215.64, 215.84]
# Time interval n.1: [215.84, 216.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.9/28
# ----------------------------------------------------------------------------------------------------
# Scene n.9.
#     Initial mse: 9.56229487850577
#
# After optimizing, new params: v0 = 37.82752539738231, L = 2.0
#
# Initial mse: 1.1515558593454416
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [216.64,217.04]
# Time interval n.0: [216.64, 216.84]
# Time interval n.1: [216.84, 217.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.10/28
# ----------------------------------------------------------------------------------------------------
# Scene n.10.
#     Initial mse: 4.347189941818935
#
# After optimizing, new params: v0 = 33.74355513790046, L = 2.0
#
# Initial mse: 0.2314640641805122
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [240.64,241.04]
# Time interval n.0: [240.64, 240.84]
# Time interval n.1: [240.84, 241.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.11/28
# ----------------------------------------------------------------------------------------------------
# Scene n.11.
#     Initial mse: 2.074402530978387
#
# After optimizing, new params: v0 = 30.884364679504454, L = 2.0
#
# Initial mse: 0.449803788894838
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [253.64,254.04]
# Time interval n.0: [253.64, 253.84]
# Time interval n.1: [253.84, 254.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.12/28
# ----------------------------------------------------------------------------------------------------
# Scene n.12.
#     Initial mse: 57.34085350009472
#
# After optimizing, new params: v0 = 37.40425629887192, L = 2.0
#
# Initial mse: 2.9592710783494383
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [262.64,263.64]
# Time interval n.0: [262.64, 262.84]
# Time interval n.1: [262.84, 263.04]
# Time interval n.2: [263.04, 263.24]
# Time interval n.3: [263.24, 263.44]
# Time interval n.4: [263.44, 263.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.13/28
# ----------------------------------------------------------------------------------------------------
# Scene n.13.
#     Initial mse: 8.28305037526711
#
# After optimizing, new params: v0 = 32.49009383419833, L = 2.0
#
# Initial mse: 1.5177295695193067
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [314.84,315.64]
# Time interval n.0: [314.84, 315.04]
# Time interval n.1: [315.04, 315.24]
# Time interval n.2: [315.24, 315.44]
# Time interval n.3: [315.44, 315.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.14/28
# ----------------------------------------------------------------------------------------------------
# Scene n.14.
#     Initial mse: 63.27620723452171
#
# After optimizing, new params: v0 = 34.047146161140894, L = 2.0
#
# Initial mse: 7.0040554077349
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [325.24,326.44]
# Time interval n.0: [325.24, 325.44]
# Time interval n.1: [325.44, 325.64]
# Time interval n.2: [325.64, 325.84]
# Time interval n.3: [325.84, 326.04]
# Time interval n.4: [326.04, 326.24]
# Time interval n.5: [326.24, 326.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.15/28
# ----------------------------------------------------------------------------------------------------
# Scene n.15.
#     Initial mse: 35.548720572631126
#
# After optimizing, new params: v0 = 36.68933281990027, L = 2.0
#
# Initial mse: 7.189954189362296
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [354.04,354.64]
# Time interval n.0: [354.04, 354.24]
# Time interval n.1: [354.24, 354.44]
# Time interval n.2: [354.44, 354.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.16/28
# ----------------------------------------------------------------------------------------------------
# Scene n.16.
#     Initial mse: 11.780456667023834
# After optimizing, new params: v0 = 35.804789625969875, L = 2.269626067737699
#
# Initial mse: 0.9660301482174517
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [363.44,364.04]
# Time interval n.0: [363.44, 363.64]
# Time interval n.1: [363.64, 363.84]
# Time interval n.2: [363.84, 364.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.17/28
# ----------------------------------------------------------------------------------------------------
# Scene n.17.
#     Initial mse: 64.09766313435416
#
# After optimizing, new params: v0 = 41.567504168086636, L = 2.0
#
# Initial mse: 3.2705923047018444
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [386.64,387.44]
# Time interval n.0: [386.64, 386.84]
# Time interval n.1: [386.84, 387.04]
# Time interval n.2: [387.04, 387.24]
# Time interval n.3: [387.24, 387.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.18/28
# ----------------------------------------------------------------------------------------------------
# Scene n.18.
#     Initial mse: 4.912927092127705
#
# After optimizing, new params: v0 = 33.55032842007861, L = 2.0
#
# Initial mse: 1.0644683067232383
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [431.84,432.24]
# Time interval n.0: [431.84, 432.04]
# Time interval n.1: [432.04, 432.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.19/28
# ----------------------------------------------------------------------------------------------------
# Scene n.19.
#     Initial mse: 2.679762316230849
#
# After optimizing, new params: v0 = 29.43081896086186, L = 2.0
#
# Initial mse: 0.36045051351050933
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [446.24,446.84]
# Time interval n.0: [446.24, 446.44]
# Time interval n.1: [446.44, 446.64]
# Time interval n.2: [446.64, 446.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.20/28
# ----------------------------------------------------------------------------------------------------
# Scene n.20.
#     Initial mse: 25.655367267721125
#
# After optimizing, new params: v0 = 35.04626205837499, L = 2.0
#
# Initial mse: 4.763790702355296
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [447.44,448.04]
# Time interval n.0: [447.44, 447.64]
# Time interval n.1: [447.64, 447.84]
# Time interval n.2: [447.84, 448.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.21/28
# ----------------------------------------------------------------------------------------------------
# Scene n.21.
#     Initial mse: 0.9641995743028077
#
# After optimizing, new params: v0 = 24.673351934255145, L = 2.990929165551886
#
# Initial mse: 0.07371623088864364
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [495.84,496.24]
# Time interval n.0: [495.84, 496.04]
# Time interval n.1: [496.04, 496.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.22/28
# ----------------------------------------------------------------------------------------------------
# Scene n.22.
#     Initial mse: 6.5879120100009825
#
# After optimizing, new params: v0 = 22.292401109843027, L = 2.0
#
# Initial mse: 1.2054822680367134
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [496.84,497.64]
# Time interval n.0: [496.84, 497.04]
# Time interval n.1: [497.04, 497.24]
# Time interval n.2: [497.24, 497.44]
# Time interval n.3: [497.44, 497.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.23/28
# ----------------------------------------------------------------------------------------------------
# Scene n.23.
#     Initial mse: 3.7094220787236374
#
# After optimizing, new params: v0 = 22.095500635160356, L = 2.0
#
# Initial mse: 1.0544141308965365
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [499.04,499.44]
# Time interval n.0: [499.04, 499.24]
# Time interval n.1: [499.24, 499.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.24/28
# ----------------------------------------------------------------------------------------------------
# Scene n.24.
#     Initial mse: 9.163900189199277
#
# After optimizing, new params: v0 = 16.848349245079824, L = 2.0
#
# Initial mse: 1.1118417867522987
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [500.64,501.04]
# Time interval n.0: [500.64, 500.84]
# Time interval n.1: [500.84, 501.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.25/28
# ----------------------------------------------------------------------------------------------------
# Scene n.25.
#     Initial mse: 30.150456236203787
#
# After optimizing, new params: v0 = 18.547527733400674, L = 2.0
#
# Initial mse: 5.766485308769471
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [502.24,503.04]
# Time interval n.0: [502.24, 502.44]
# Time interval n.1: [502.44, 502.64]
# Time interval n.2: [502.64, 502.84]
# Time interval n.3: [502.84, 503.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.26/28
# ----------------------------------------------------------------------------------------------------
# Scene n.26.
#     Initial mse: 0.30421257997703893
#
# After optimizing, new params: v0 = 29.940332329396966, L = 5.81607387643368
#
# Initial mse: 0.16979785127791858
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [534.84,535.24]
# Time interval n.0: [534.84, 535.04]
# Time interval n.1: [535.04, 535.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.27/28
# ----------------------------------------------------------------------------------------------------
# Scene n.27.
#     Initial mse: 26.85978671721749
# After optimizing, new params: v0 = 13.500163784087583, L = 2.0
#
# Initial mse: 1.9037289857096482
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [573.84,574.44]
# Time interval n.0: [573.84, 574.04]
# Time interval n.1: [574.04, 574.24]
# Time interval n.2: [574.24, 574.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.0/28
# ----------------------------------------------------------------------------------------------------
# Scene n.0.
#     Initial mse: 12.352854461317223
#
# After optimizing, new params: v0 = 18.937040474240142, L = 2.463865462887221
#
# Initial mse: 9.284749269390543
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [14.24,14.64]
# Time interval n.0: [14.24, 14.44]
# Time interval n.1: [14.44, 14.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.1/28
# ----------------------------------------------------------------------------------------------------
# Scene n.1.
#     Initial mse: 11.381946841101518
#
# After optimizing, new params: v0 = 28.399336339796896, L = 5.447717021480639
#
# Initial mse: 8.283137067116124
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [23.64,24.64]
# Time interval n.0: [23.64, 23.84]
# Time interval n.1: [23.84, 24.04]
# Time interval n.2: [24.04, 24.24]
# Time interval n.3: [24.24, 24.44]
# Time interval n.4: [24.44, 24.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.2/28
# ----------------------------------------------------------------------------------------------------
# Scene n.2.
#     Initial mse: 86.26311136222817
#
# After optimizing, new params: v0 = 27.41302315942726, L = 9.808519532643537
#
# Initial mse: 1.0640137516909869
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [72.44,73.44]
# Time interval n.0: [72.44, 72.64]
# Time interval n.1: [72.64, 72.84]
# Time interval n.2: [72.84, 73.04]
# Time interval n.3: [73.04, 73.24]
# Time interval n.4: [73.24, 73.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.3/28
# ----------------------------------------------------------------------------------------------------
# Scene n.3.
#     Initial mse: 49.16155207333813
#
# After optimizing, new params: v0 = 20.480695552067253, L = 5.954015520831456
#
# Initial mse: 15.172241848699997
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [84.24,84.84]
# Time interval n.0: [84.24, 84.44]
# Time interval n.1: [84.44, 84.64]
# Time interval n.2: [84.64, 84.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.4/28
# ----------------------------------------------------------------------------------------------------
# Scene n.4.
#     Initial mse: 18.845444710484795
#
# After optimizing, new params: v0 = 15.029076109613957, L = 2.0
#
# Initial mse: 10.669016028532303
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [131.64,132.04]
# Time interval n.0: [131.64, 131.84]
# Time interval n.1: [131.84, 132.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.5/28
# ----------------------------------------------------------------------------------------------------
# Scene n.5.
#     Initial mse: 0.8890844713665724
#
# After optimizing, new params: v0 = 28.72697561417648, L = 5.400104564158416
#
# Initial mse: 0.4459483386765999
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [148.04,148.44]
# Time interval n.0: [148.04, 148.24]
# Time interval n.1: [148.24, 148.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.6/28
# ----------------------------------------------------------------------------------------------------
# Scene n.6.
#     Initial mse: 13.90247657138721
#
# After optimizing, new params: v0 = 24.980974802776416, L = 5.52524052748674
#
# Initial mse: 9.857905170028443
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [161.64,162.04]
# Time interval n.0: [161.64, 161.84]
# Time interval n.1: [161.84, 162.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.7/28
# ----------------------------------------------------------------------------------------------------
# Scene n.7.
#     Initial mse: 62.12929838950659
#
# After optimizing, new params: v0 = 31.57937426644517, L = 13.732330900784937
#
# Initial mse: 1.0133687950637162
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [164.04,164.64]
# Time interval n.0: [164.04, 164.24]
# Time interval n.1: [164.24, 164.44]
# Time interval n.2: [164.44, 164.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.8/28
# ----------------------------------------------------------------------------------------------------
# Scene n.8.
#     Initial mse: 17.78017687344089
#
# After optimizing, new params: v0 = 37.059817733247606, L = 12.654184749502743
#
# Initial mse: 0.08704787955451104
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [215.64,216.04]
# Time interval n.0: [215.64, 215.84]
# Time interval n.1: [215.84, 216.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.9/28
# ----------------------------------------------------------------------------------------------------
# Scene n.9.
#     Initial mse: 6.50239371462969
#
# After optimizing, new params: v0 = 29.68836853238778, L = 6.338103481559219
#
# Initial mse: 4.476823938643637
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [216.64,217.04]
# Time interval n.0: [216.64, 216.84]
# Time interval n.1: [216.84, 217.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.10/28
# ----------------------------------------------------------------------------------------------------
# Scene n.10.
#     Initial mse: 12.618958341022832
#
# After optimizing, new params: v0 = 29.776058028027148, L = 7.403622205792275
#
# Initial mse: 8.133658164419758
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [240.64,241.04]
# Time interval n.0: [240.64, 240.84]
# Time interval n.1: [240.84, 241.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.11/28
# ----------------------------------------------------------------------------------------------------
# Scene n.11.
#     Initial mse: 10.014602281970705
#
# After optimizing, new params: v0 = 26.498184703334335, L = 7.371831719471101
#
# Initial mse: 0.5717456783364305
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [253.64,254.04]
# Time interval n.0: [253.64, 253.84]
# Time interval n.1: [253.84, 254.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.12/28
# ----------------------------------------------------------------------------------------------------
# Scene n.12.
#     Initial mse: 17.593221640210356
#
# After optimizing, new params: v0 = 33.29960231559492, L = 4.101119281472052
#
# Initial mse: 4.813350051180817
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [262.64,263.64]
# Time interval n.0: [262.64, 262.84]
# Time interval n.1: [262.84, 263.04]
# Time interval n.2: [263.04, 263.24]
# Time interval n.3: [263.24, 263.44]
# Time interval n.4: [263.44, 263.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.13/28
# ----------------------------------------------------------------------------------------------------
# Scene n.13.
#     Initial mse: 48.15169767356494
#
# After optimizing, new params: v0 = 33.00028246678378, L = 10.685295001743459
#
# Initial mse: 10.013471915998629
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [314.84,315.64]
# Time interval n.0: [314.84, 315.04]
# Time interval n.1: [315.04, 315.24]
# Time interval n.2: [315.24, 315.44]
# Time interval n.3: [315.44, 315.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.14/28
# ----------------------------------------------------------------------------------------------------
# Scene n.14.
#     Initial mse: 20.426867744626946
#
# After optimizing, new params: v0 = 29.113434677936777, L = 2.8674572557086826
#
# Initial mse: 1.3576090235844323
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [325.24,326.44]
# Time interval n.0: [325.24, 325.44]
# Time interval n.1: [325.44, 325.64]
# Time interval n.2: [325.64, 325.84]
# Time interval n.3: [325.84, 326.04]
# Time interval n.4: [326.04, 326.24]
# Time interval n.5: [326.24, 326.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.15/28
# ----------------------------------------------------------------------------------------------------
# Scene n.15.
#     Initial mse: 17.60507401760849
#
# After optimizing, new params: v0 = 26.83649824389714, L = 2.8780032545628185
#
# Initial mse: 10.772057028285197
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [354.04,354.64]
# Time interval n.0: [354.04, 354.24]
# Time interval n.1: [354.24, 354.44]
# Time interval n.2: [354.44, 354.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.16/28
# ----------------------------------------------------------------------------------------------------
# Scene n.16.
#     Initial mse: 43.913236438353564
#
# After optimizing, new params: v0 = 28.375514022987527, L = 8.444074824912738
#
# Initial mse: 20.660581197468957
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [363.44,364.04]
# Time interval n.0: [363.44, 363.64]
# Time interval n.1: [363.64, 363.84]
# Time interval n.2: [363.84, 364.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.17/28
# ----------------------------------------------------------------------------------------------------
# Scene n.17.
#     Initial mse: 20.540132480416247
# After optimizing, new params: v0 = 34.69313367452418, L = 4.7124785587876215
#
# Initial mse: 12.291516627821622
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [386.64,387.44]
# Time interval n.0: [386.64, 386.84]
# Time interval n.1: [386.84, 387.04]
# Time interval n.2: [387.04, 387.24]
# Time interval n.3: [387.24, 387.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.18/28
# ----------------------------------------------------------------------------------------------------
# Scene n.18.
#     Initial mse: 10.342387279877576
#
# After optimizing, new params: v0 = 26.446577030943004, L = 6.521848524721134
#
# Initial mse: 4.197215032298833
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [431.84,432.24]
# Time interval n.0: [431.84, 432.04]
# Time interval n.1: [432.04, 432.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.19/28
# ----------------------------------------------------------------------------------------------------
# Scene n.19.
#     Initial mse: 33.21575522200337
#
# After optimizing, new params: v0 = 25.14439289462114, L = 7.6978709664742135
#
# Initial mse: 7.028517122143096
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [446.24,446.84]
# Time interval n.0: [446.24, 446.44]
# Time interval n.1: [446.44, 446.64]
# Time interval n.2: [446.64, 446.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.20/28
# ----------------------------------------------------------------------------------------------------
# Scene n.20.
#     Initial mse: 13.53551940927262
#
# After optimizing, new params: v0 = 28.437051007164015, L = 3.212755008634969
#
# Initial mse: 7.942129643076988
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [447.44,448.04]
# Time interval n.0: [447.44, 447.64]
# Time interval n.1: [447.64, 447.84]
# Time interval n.2: [447.84, 448.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.21/28
# ----------------------------------------------------------------------------------------------------
# Scene n.21.
#     Initial mse: 14.769368375511464
#
# After optimizing, new params: v0 = 20.4409166400848, L = 6.372420342045843
#
# Initial mse: 2.7976997683440157
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [495.84,496.24]
# Time interval n.0: [495.84, 496.04]
# Time interval n.1: [496.04, 496.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.22/28
# ----------------------------------------------------------------------------------------------------
# Scene n.22.
#     Initial mse: 24.795859629264204
#
# After optimizing, new params: v0 = 24.057384323870885, L = 6.511045215595989
#
# Initial mse: 5.975368124937488
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [496.84,497.64]
# Time interval n.0: [496.84, 497.04]
# Time interval n.1: [497.04, 497.24]
# Time interval n.2: [497.24, 497.44]
# Time interval n.3: [497.44, 497.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ...
#
# Initial mse: 19.99164672985605
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 8 time intervals inside     [201.52,203.12]
# Time interval n.0: [201.52, 201.72]
# Time interval n.1: [201.72, 201.92]
# Time interval n.2: [201.92, 202.12]
# Time interval n.3: [202.12, 202.32]
# Time interval n.4: [202.32, 202.52]
# Time interval n.5: [202.52, 202.72]
# Time interval n.6: [202.72, 202.92]
# Time interval n.7: [202.92, 203.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.6/22
# ----------------------------------------------------------------------------------------------------
# Scene n.6.
#     Initial mse: 18.26977797303874
#
# After optimizing, new params: v0 = 23.18202568233956, L = 7.939699367227558
#
# Initial mse: 0.9779712870521914
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [210.12,210.52]
# Time interval n.0: [210.12, 210.32]
# Time interval n.1: [210.32, 210.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.7/22
# ----------------------------------------------------------------------------------------------------
# Scene n.7.
#     Initial mse: 10.356157504680972
#
# After optimizing, new params: v0 = 25.47181671984447, L = 5.7184989398649675
#
# Initial mse: 5.3240492485998985
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [236.52,237.12]
# Time interval n.0: [236.52, 236.72]
# Time interval n.1: [236.72, 236.92]
# Time interval n.2: [236.92, 237.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.8/22
# ----------------------------------------------------------------------------------------------------
# Scene n.8.
#     Initial mse: 2.0516803070239136
#
# After optimizing, new params: v0 = 24.258352822624403, L = 3.370762959219456
#
# Initial mse: 0.6661577176156287
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [237.72,238.12]
# Time interval n.0: [237.72, 237.92]
# Time interval n.1: [237.92, 238.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.9/22
# ----------------------------------------------------------------------------------------------------
# Scene n.9.
#     Initial mse: 244.88069214354906
#
# After optimizing, new params: v0 = 6.032483327295795, L = 2.0
#
# Initial mse: 2.489820149829227
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [317.32,318.52]
# Time interval n.0: [317.32, 317.52]
# Time interval n.1: [317.52, 317.72]
# Time interval n.2: [317.72, 317.92]
# Time interval n.3: [317.92, 318.12]
# Time interval n.4: [318.12, 318.32]
# Time interval n.5: [318.32, 318.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.10/22
# ----------------------------------------------------------------------------------------------------
# Scene n.10.
#     Initial mse: 45.19838879712788
#
# After optimizing, new params: v0 = 24.568619109670742, L = 8.490162858750324
#
# Initial mse: 1.604974760814524
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [321.12,321.92]
# Time interval n.0: [321.12, 321.32]
# Time interval n.1: [321.32, 321.52]
# Time interval n.2: [321.52, 321.72]
# Time interval n.3: [321.72, 321.92]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.11/22
# ----------------------------------------------------------------------------------------------------
# Scene n.11.
#     Initial mse: 168.46977533303397
#
# After optimizing, new params: v0 = 13.966838473448696, L = 9.693491047074293
#
# Initial mse: 0.2542793298900651
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [323.12,323.92]
# Time interval n.0: [323.12, 323.32]
# Time interval n.1: [323.32, 323.52]
# Time interval n.2: [323.52, 323.72]
# Time interval n.3: [323.72, 323.92]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.12/22
# ----------------------------------------------------------------------------------------------------
# Scene n.12.
#     Initial mse: 41.65899868781642
#
# After optimizing, new params: v0 = 17.928583505488398, L = 7.2082323237088195
#
# Initial mse: 2.5451536117637232
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [337.72,338.32]
# Time interval n.0: [337.72, 337.92]
# Time interval n.1: [337.92, 338.12]
# Time interval n.2: [338.12, 338.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.13/22
# ----------------------------------------------------------------------------------------------------
# Scene n.13.
#     Initial mse: 6.821548351907007
#
# After optimizing, new params: v0 = 20.386774998944176, L = 4.211655454808129
#
# Initial mse: 0.32103516396961324
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [369.32,369.92]
# Time interval n.0: [369.32, 369.52]
# Time interval n.1: [369.52, 369.72]
# Time interval n.2: [369.72, 369.92]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.14/22
# ----------------------------------------------------------------------------------------------------
# Scene n.14.
#     Initial mse: 146.4006707576339
#
# After optimizing, new params: v0 = 20.76372475353401, L = 9.549113187220899
#
# Initial mse: 23.28639585258537
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [370.92,372.12]
# Time interval n.0: [370.92, 371.12]
# Time interval n.1: [371.12, 371.32]
# Time interval n.2: [371.32, 371.52]
# Time interval n.3: [371.52, 371.72]
# Time interval n.4: [371.72, 371.92]
# Time interval n.5: [371.92, 372.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.15/22
# ----------------------------------------------------------------------------------------------------
# Scene n.15.
#     Initial mse: 75.95812699378176
# After optimizing, new params: v0 = 9.257695860855932, L = 5.033263288163
#
# Initial mse: 4.974237698603272
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [376.92,377.52]
# Time interval n.0: [376.92, 377.12]
# Time interval n.1: [377.12, 377.32]
# Time interval n.2: [377.32, 377.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.16/22
# ----------------------------------------------------------------------------------------------------
# Scene n.16.
#     Initial mse: 15.442135835757227
#
# After optimizing, new params: v0 = 21.973509691816115, L = 5.642676469726672
#
# Initial mse: 2.1340551694594403
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [433.52,434.12]
# Time interval n.0: [433.52, 433.72]
# Time interval n.1: [433.72, 433.92]
# Time interval n.2: [433.92, 434.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.17/22
# ----------------------------------------------------------------------------------------------------
# Scene n.17.
#     Initial mse: 10.139662390419195
#
# After optimizing, new params: v0 = 20.56297155183027, L = 6.152107617224828
#
# Initial mse: 2.983594507794717
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [483.92,484.32]
# Time interval n.0: [483.92, 484.12]
# Time interval n.1: [484.12, 484.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.18/22
# ----------------------------------------------------------------------------------------------------
# Scene n.18.
#     Initial mse: 42.3012885383888
#
# After optimizing, new params: v0 = 16.686215283231828, L = 7.865684909938597
#
# Initial mse: 5.002276635625728
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [531.72,532.32]
# Time interval n.0: [531.72, 531.92]
# Time interval n.1: [531.92, 532.12]
# Time interval n.2: [532.12, 532.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.19/22
# ----------------------------------------------------------------------------------------------------
# Scene n.19.
#     Initial mse: 15.733763987435255
#
# After optimizing, new params: v0 = 16.839340690484672, L = 2.052664220585549
#
# Initial mse: 7.514003863731551
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [202.52,203.12]
# Time interval n.0: [202.52, 202.72]
# Time interval n.1: [202.72, 202.92]
# Time interval n.2: [202.92, 203.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.20/22
# ----------------------------------------------------------------------------------------------------
# Scene n.20.
#     Initial mse: 16.802571166470077
#
# Optimization not succeed
#
# Initial mse: 16.802571166470077
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [342.92,343.32]
# Time interval n.0: [342.92, 343.12]
# Time interval n.1: [343.12, 343.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.21/22
# ----------------------------------------------------------------------------------------------------
# Scene n.21.
#     Initial mse: 24.035641589682346
#
# After optimizing, new params: v0 = 10.228177525117312, L = 2.777909719092581
#
# Initial mse: 2.6495048827419927
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [441.12,441.52]
# Time interval n.0: [441.12, 441.32]
# Time interval n.1: [441.32, 441.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================

# %%
info_alldataset.groupby(['LWR_flag','N. file']).mean(numeric_only=True).T
# Out:
# LWR_flag        Lin                                                         \
# N. file          1          2          3          4          5          6
# v0_scn    30.577035  23.340979  30.623632  25.698348  28.130744  24.226456
# L_scn      2.361120   2.894284   2.663449   3.269818   2.764611   2.000000
# n_scn     13.500000   8.500000  27.000000  14.500000   6.500000   1.000000
#
# LWR_flag                                                    Log             \
# N. file          7          8          9          10         1          2
# v0_scn    29.090322  22.525565  28.912984  21.467565  24.804920  19.721127
# L_scn      3.723358   3.914273   2.860306   3.035423   5.994624   5.813484
# n_scn      3.500000  10.000000   4.000000  10.500000  13.500000   8.500000
#
# LWR_flag                                                                    \
# N. file          3          4          5          6          7          8
# v0_scn    25.706179  21.753653  26.002800  19.529429  24.192645  18.975957
# L_scn      6.890729   6.844067   6.240198   3.917348   5.630006   7.003790
# n_scn     27.000000  14.500000   6.500000   1.000000   3.500000  10.000000
#
# LWR_flag
# N. file          9          10
# v0_scn    24.680061  19.467734
# L_scn      6.265641   5.644614
# n_scn      4.000000  10.500000

# %% [markdown]
# ## Prepare the out dir

# %%
# Create the directory..
if flag_save:
    
    ext = ".svg"
    
    df_seen = [df['N. file'][0] for df in dflist]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}-LINLOG-{flag_processed}")
    
    path = 'out/' + d
    os.mkdir(path)
    
    # Save the solution in a file
    namefile = '/info_alldataset.txt'

    with open(path + namefile, 'w') as output:
        info_alldataset.to_csv(path + namefile, sep=',', index=False)

# %% [markdown]
# ## Plot

# %%
ms2kmh = 3.6

# Initialize the figure
width, height = 7, 5
fig, ax = plt.subplots(figsize=(width,height))

lin_color, log_color = 'gold', 'olive'

# For all df
for key, grp in info_alldataset.groupby(['LWR_flag','N. file']):
    tmp = grp.mean(numeric_only=True)
    nf = key[1]
    match key[0]:
        case 'Lin':
            ax.plot(nf, tmp['v0_scn']*ms2kmh, color = lin_color, marker="x")
        case 'Log':
            ax.plot(nf, tmp['v0_scn']*ms2kmh, color = log_color, marker="x")

# mean line
for key, grp in info_alldataset.groupby('LWR_flag'):
    tmp = grp.mean(numeric_only=True)
    
    xrange = [i for i in range(1,11)]
    yval = [tmp['v0_scn']*ms2kmh] * len(xrange) 
    match key:
        case 'Lin':
            ax.plot(xrange, yval, color = lin_color, label = key)
        case 'Log':
            ax.plot(xrange, yval, color = log_color,  label = key)

xlim = [0.75,10.25]
ax.set_xlim(xlim)
ax.set_xticks(range(1,11))
ylim = ax.get_ylim()

ax.set_xlabel(r"$data set$",fontsize=14)
ax.set_ylabel(r"$v_{0}\ [km/h]$",fontsize=14)
ax.set_title(fr"$Velocities\ v_{0}\ of\ the\ leading\ car$",fontsize=14)
ax.legend()

plt.show()

# %%
# Save figure
if flag_save:

    title = f"/v0_df{df_seen_str}_1"     
    fig.savefig(path+title+ext, bbox_inches='tight')
