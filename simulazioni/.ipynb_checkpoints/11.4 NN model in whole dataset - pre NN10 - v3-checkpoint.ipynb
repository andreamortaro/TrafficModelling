# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
from sklearn.model_selection import train_test_split
from datetime import datetime
import time

# Plotting
import matplotlib.pyplot as plt

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn_v2 import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2024-03-04 10:24:22.278433: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 10:24:22.278464: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 10:24:22.279383: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 10:24:22.285421: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-04 10:24:23.081128: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"

# %%
processed_flag = 'pre'
# load the data
_, dflist = load_dataset(dir_name, processed_flag)

# %% [markdown]
# ## Params

# %%
# Flags
plot_flag = False
flag_save = False
testing_flag = True

# %%
# params
DOE =[1,10,1] #Design of experiment

v0 = 30
NUM_ITER = 500
LEARNING_RATE_v0 = 0.5
test = 0.33
dataset = dflist

if testing_flag:
    NUM_ITER = 1
    test = 0.8
    dataset = dflist[7:9]

print(f"In this dataset we have {np.sum([d.shape[0] for d in dataset])} scenes")
# Out:
# In this dataset we have 79 scenes

# %% [markdown]
# ## NN: 1-10-1

# %%
info_nn10, model_trained = solve_nn_dataset(dataset, DOE, v0, processed_flag, NUM_ITER, LEARNING_RATE_v0,
                                           test, plot_flag)
# Out:
# ----------------------------------------------------------------------------------------------------
# Analyzing 1 dfs. NN structure: 1-10-1
# ****************************************************************************************************
# Analyzing 1/1 dfs.
# In DataFrame n.8 we have 79 scenes.
#     To train the model we use 15 scenes, the remaining 64 to test the model.
#
# Training step. (15 scenes)
# ====================================================================================================
# DataFrame n.8. Scene n.1/15
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [50.24,51.04]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/15:
#         * After LR finder: LR_NN=0.0005 with mse=10.056495224862738 at it=24
#         * v0 = 30
#         * MSE = 19.591144680767485
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.2/15
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [215.24,216.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 2/15:
#         * After LR finder: LR_NN=0.001 with mse=39.86479796910067 at it=24
#         * v0 = 30
#         * MSE = 50.943903856550996
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.3/15
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [243.44,244.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 3/15:
#         * After LR finder: LR_NN=0.001 with mse=27.37667801517452 at it=24
#         * v0 = 30
#         * MSE = 32.79289787414853
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.4/15
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [453.64,454.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 4/15:
#         * After LR finder: LR_NN=1e-05 with mse=0.5030905634345689 at it=24
#         * v0 = 30
#         * MSE = 0.5341040084813089
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.5/15
# ----------------------------------------------------------------------------------------------------
# We have 14 time intervals inside [366.64,369.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 5/15:
#         * After LR finder: LR_NN=1e-05 with mse=196.15523417344224 at it=24
#         * v0 = 30
#         * MSE = 197.9668068744702
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.6/15
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [28.44,29.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 6/15:
#         * After LR finder: LR_NN=1e-05 with mse=11.789800293277107 at it=24
#         * v0 = 30
#         * MSE = 38.71746276322142
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.7/15
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [545.44,545.84]
# ----------------------------------------------------------------------------------------------------
#         For scene 7/15:
#         * After LR finder: LR_NN=5e-05 with mse=14.981120555096512 at it=24
#         * v0 = 30
#         * MSE = 16.101134849926733
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.8/15
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [278.64,279.64]
# ----------------------------------------------------------------------------------------------------
#         For scene 8/15:
#         * After LR finder: LR_NN=1e-05 with mse=1.8933165057348949 at it=24
#         * v0 = 30
#         * MSE = 26.58804162273311
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.9/15
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [48.04,48.84]
# ----------------------------------------------------------------------------------------------------
#         For scene 9/15:
#         * After LR finder: LR_NN=5e-05 with mse=13.181451878285387 at it=24
#         * v0 = 30
#         * MSE = 33.654498863980194
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.10/15
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside [283.84,285.04]
# ----------------------------------------------------------------------------------------------------
#         For scene 10/15:
#         * After LR finder: LR_NN=0.001 with mse=8.194044865333845 at it=24
#         * v0 = 30
#         * MSE = 36.92436491298333
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.11/15
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [276.64,277.64]
# ----------------------------------------------------------------------------------------------------
#         For scene 11/15:
#         * After LR finder: LR_NN=0.001 with mse=17.384046618144097 at it=24
#         * v0 = 30
#         * MSE = 70.68698602834627
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.12/15
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [102.24,103.04]
# ----------------------------------------------------------------------------------------------------
#         For scene 12/15:
#         * After LR finder: LR_NN=0.0001 with mse=12.08874588234202 at it=24
#         * v0 = 30
#         * MSE = 31.23911288296722
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.13/15
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [290.84,291.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 13/15:
#         * After LR finder: LR_NN=0.01 with mse=27.33348221187629 at it=24
#         * v0 = 30
#         * MSE = 19.016665465580797
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.14/15
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [178.44,179.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 14/15:
#         * After LR finder: LR_NN=0.0001 with mse=35.395552514363224 at it=24
#         * v0 = 30
#         * MSE = 99.8901900715731
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.15/15
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [536.64,537.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 15/15:
#         * After LR finder: LR_NN=0.01 with mse=24.79727609134858 at it=24
#         * v0 = 30
#         * MSE = 24.79727609134858
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 46.62963938980527
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (64 scenes)
# ====================================================================================================
# DataFrame n.8. Scene n.1/64
#         For scene 1/64:
#         * MSE = 3.081579006540791
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.2/64
#         For scene 2/64:
#         * MSE = 12.484352847646303
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.3/64
#         For scene 3/64:
#         * MSE = 15.074432252150597
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.4/64
#         For scene 4/64:
#         * MSE = 9.448970080554902
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.5/64
#         For scene 5/64:
#         * MSE = 12.099967478259225
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.6/64
#         For scene 6/64:
#         * MSE = 10.10549810924657
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.7/64
#         For scene 7/64:
#         * MSE = 14.463951540234307
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.8/64
#         For scene 8/64:
#         * MSE = 7.9081912903685625
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.9/64
#         For scene 9/64:
#         * MSE = 0.34437191694333497
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.10/64
#         For scene 10/64:
#         * MSE = 6.9242221644086435
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.11/64
#         For scene 11/64:
#         * MSE = 3.122506956380605
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.12/64
#         For scene 12/64:
#         * MSE = 10.1982946465669
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.13/64
#         For scene 13/64:
#         * MSE = 4.389217205378553
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.14/64
#         For scene 14/64:
#         * MSE = 8.845383486929293
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.15/64
#         For scene 15/64:
#         * MSE = 4.872728151699436
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.16/64
#         For scene 16/64:
#         * MSE = 10.857726228991071
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.17/64
#         For scene 17/64:
#         * MSE = 6.339563190301199
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.18/64
#         For scene 18/64:
#         * MSE = 9.926950282462178
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.19/64
#         For scene 19/64:
#         * MSE = 13.547777843030117
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.20/64
#         For scene 20/64:
#         * MSE = 6.390008624066556
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.21/64
#         For scene 21/64:
#         * MSE = 10.642606718455314
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.22/64
#         For scene 22/64:
#         * MSE = 4.313594729771443
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.23/64
#         For scene 23/64:
#         * MSE = 19.69488808202515
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.24/64
#         For scene 24/64:
#         * MSE = 2.7215738809666346
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.25/64
#         For scene 25/64:
#         * MSE = 6.024468626057119
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.26/64
#         For scene 26/64:
#         * MSE = 11.052699583220546
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.27/64
#         For scene 27/64:
#         * MSE = 9.228538117174699
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.28/64
#         For scene 28/64:
#         * MSE = 11.807651535453282
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.29/64
#         For scene 29/64:
#         * MSE = 6.803672118359805
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.30/64
#         For scene 30/64:
#         * MSE = 11.427991063309692
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.31/64
#         For scene 31/64:
#         * MSE = 7.033834483229258
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.32/64
#         For scene 32/64:
#         * MSE = 9.136152393162298
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.33/64
#         For scene 33/64:
#         * MSE = 14.759089923558323
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.34/64
#         For scene 34/64:
#         * MSE = 5.155928939420828
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.35/64
#         For scene 35/64:
#         * MSE = 4.302388136785212
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.36/64
#         For scene 36/64:
#         * MSE = 9.90700520039783
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.37/64
#         For scene 37/64:
#         * MSE = 2.5207174201862497
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.38/64
#         For scene 38/64:
#         * MSE = 1.7186491478625823
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.39/64
#         For scene 39/64:
#         * MSE = 11.470543333594186
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.40/64
#         For scene 40/64:
#         * MSE = 0.9196495618447084
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.41/64
#         For scene 41/64:
#         * MSE = 8.797265222169502
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.42/64
#         For scene 42/64:
#         * MSE = 10.03268500569493
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.43/64
#         For scene 43/64:
#         * MSE = 5.441091556745367
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.44/64
#         For scene 44/64:
#         * MSE = 10.821501069122862
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.45/64
#         For scene 45/64:
#         * MSE = 9.489950997239625
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.46/64
#         For scene 46/64:
#         * MSE = 6.008902786367531
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.47/64
#         For scene 47/64:
#         * MSE = 8.814743031989451
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.48/64
#         For scene 48/64:
#         * MSE = 8.10787032408406
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.49/64
#         For scene 49/64:
#         * MSE = 7.563498798355884
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.50/64
#         For scene 50/64:
#         * MSE = 5.314095915390429
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.51/64
#         For scene 51/64:
#         * MSE = 8.334761206118912
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.52/64
#         For scene 52/64:
#         * MSE = 9.839297432111893
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.53/64
#         For scene 53/64:
#         * MSE = 8.879176226937187
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.54/64
#         For scene 54/64:
#         * MSE = 13.46542168695405
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.55/64
#         For scene 55/64:
#         * MSE = 12.002468353344401
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.56/64
#         For scene 56/64:
#         * MSE = 9.059069103878528
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.57/64
#         For scene 57/64:
#         * MSE = 14.984958086650934
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.58/64
#         For scene 58/64:
#         * MSE = 1.6843073967344473
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.59/64
#         For scene 59/64:
#         * MSE = 3.5098304273938545
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.60/64
#         For scene 60/64:
#         * MSE = 4.580024301116679
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.61/64
#         For scene 61/64:
#         * MSE = 9.769099823161982
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.62/64
#         For scene 62/64:
#         * MSE = 9.93375226963079
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.63/64
#         For scene 63/64:
#         * MSE = 2.0928555340654755
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.64/64
#         For scene 64/64:
#         * MSE = 11.888380532313798
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 8.304411615383858
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 46.62963938980527
#           * MSE test: 8.304411615383858
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -

# %% [markdown]
# ## Illustration NN10 velocity dependence on consecutive distance

# %%
cd = np.linspace(0.01,1,100) # distances
tmp = model_trained(cd, training=False) # velocities predicted
vv = tmp/np.max(tmp) # velocities normalized
dd = 1/cd # densities

# %%
vv
# Out:
# <tf.Tensor: shape=(100, 1), dtype=float32, numpy=
# array([[10.713557 ],
#        [ 9.394198 ],
#        [ 8.352375 ],
#        [ 7.531603 ],
#        [ 6.883759 ],
#        [ 6.3693795],
#        [ 5.9569936],
#        [ 5.6220355],
#        [ 5.345623 ],
#        [ 5.113417 ],
#        [ 4.914617 ],
#        [ 4.741144 ],
#        [ 4.5869775],
#        [ 4.447647 ],
#        [ 4.319844 ],
#        [ 4.201115 ],
#        [ 4.089652 ],
#        [ 3.984113 ],
#        [ 3.8835065],
#        [ 3.787097 ],
#        [ 3.6943362],
#        [ 3.6048152],
#        [ 3.5182257],
#        [ 3.4343345],
#        [ 3.3529608],
#        [ 3.2739673],
#        [ 3.1972404],
#        [ 3.1226923],
#        [ 3.050248 ],
#        [ 2.9798412],
#        [ 2.9114194],
#        [ 2.8449304],
#        [ 2.780329 ],
#        [ 2.7175725],
#        [ 2.656618 ],
#        [ 2.5974264],
#        [ 2.5399597],
#        [ 2.4841785],
#        [ 2.4300458],
#        [ 2.3775237],
#        [ 2.3265762],
#        [ 2.2771657],
#        [ 2.2292554],
#        [ 2.1828098],
#        [ 2.137792 ],
#        [ 2.094166 ],
#        [ 2.051897 ],
#        [ 2.0109491],
#        [ 1.9712867],
#        [ 1.9328759],
#        [ 1.8956823],
#        [ 1.8596717],
#        [ 1.8248113],
#        [ 1.791067 ],
#        [ 1.7584081],
#        [ 1.726801 ],
#        [ 1.696215 ],
#        [ 1.6666192],
#        [ 1.6379837],
#        [ 1.610278 ],
#        [ 1.5834739],
#        [ 1.5575424],
#        [ 1.532456 ],
#        [ 1.5081877],
#        [ 1.4847103],
#        [ 1.4619981],
#        [ 1.4400262],
#        [ 1.4187697],
#        [ 1.3982046],
#        [ 1.3783073],
#        [ 1.3590552],
#        [ 1.3404263],
#        [ 1.3223991],
#        [ 1.3049526],
#        [ 1.2880666],
#        [ 1.2717215],
#        [ 1.2558981],
#        [ 1.2405776],
#        [ 1.2257426],
#        [ 1.2113757],
#        [ 1.1974596],
#        [ 1.1839782],
#        [ 1.1709158],
#        [ 1.1582574],
#        [ 1.1459877],
#        [ 1.134093 ],
#        [ 1.1225594],
#        [ 1.1113733],
#        [ 1.1005219],
#        [ 1.0899932],
#        [ 1.0797746],
#        [ 1.069855 ],
#        [ 1.0602233],
#        [ 1.0508685],
#        [ 1.0417802],
#        [ 1.0329486],
#        [ 1.0243638],
#        [ 1.0160167],
#        [ 1.0078982],
#        [ 1.       ]], dtype=float32)>

# %%
# Initialize the fig
nrow, ncol = 1, 2
width, height = 4.5, 4.5 # single subplot
fig, ax = plt.subplots(nrow,ncol,figsize=(width*ncol*.75,height*.75))

# AX 0
ax[0].plot(cd, vv)

ax[0].grid(color='grey', linestyle='-', linewidth=0.1)
# ax[0].set_title(fr"$NN10\ velocity$", fontsize=18)
ax[0].set_xlabel(fr"$distances$", fontsize=15)
ax[0].set_ylabel(fr"$velocity$", fontsize=15)

# AX 1
ax[1].plot(dd, vv)

ax[1].grid(color='grey', linestyle='-', linewidth=0.1)
# ax[1].set_title(fr"$NN10\ velocity$", fontsize=18)
ax[1].set_xlabel(fr"$\rho$", fontsize=15)
ax[1].set_ylabel(fr"$velocity$", fontsize=15)

fig.tight_layout()

plt.suptitle(fr"$NN10\ velocity$", fontsize=16,y=1.05);
plt.show()

# %% [markdown]
# ## Prepare the out dir

# %%
# Create the directory..
if flag_save:
    
    df_seen = [df['N. file'][0] for df in dataset]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}_{NUM_ITER}it-PRE-nn{DOE[1]}-v3")
    
    path = 'out/' + d
    os.mkdir(path)
    
    # Save the solution in a file
    namefile = '/info_nn10.txt'

    with open(path + namefile, 'w') as output:
        info_nn10.to_csv(path + namefile, sep=',', index=False)
        
    # Save model in a file
    namefile_model = '/model_nn10.keras'
    model_trained.compile(optimizer='SGD', loss='MAE')
    model_trained.save(path + namefile_model)  # The file needs to end with the .keras extension
