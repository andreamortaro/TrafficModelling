# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
from sklearn.model_selection import train_test_split
from datetime import datetime
import time

# Plotting
import matplotlib.pyplot as plt

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn_v2 import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2024-03-04 16:12:26.637323: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 16:12:26.637356: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 16:12:26.638186: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 16:12:26.643538: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-04 16:12:27.410317: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"

# %%
processed_flag = 'pre'
# load the data
_, dflist = load_dataset(dir_name, processed_flag)

# %% [markdown]
# ## Params

# %%
# Flags
plot_flag = False
flag_save = True
testing_flag = True

# %%
# params
DOE =[1,10,1] #Design of experiment

v0 = 30
NUM_ITER = 500
LEARNING_RATE_v0 = 0.5
test = 0.33
dataset = dflist

if testing_flag:
    NUM_ITER = 1
    test = 0.8
    dataset = dflist[8:9]

print(f"In this dataset we have {np.sum([d.shape[0] for d in dataset])} scenes")
# Out:
# In this dataset we have 33 scenes

# %% [markdown]
# ## NN: 1-10-1

# %%
info_nn10, model_trained = solve_nn_dataset(dataset, DOE, v0, processed_flag, NUM_ITER, LEARNING_RATE_v0,
                                           test, plot_flag)
# Out:
# ----------------------------------------------------------------------------------------------------
# Analyzing 1 dfs. NN structure: 1-10-1
# ****************************************************************************************************
# Analyzing 1/1 dfs.
# In DataFrame n.9 we have 33 scenes.
#     To train the model we use 6 scenes, the remaining 27 to test the model.
#
# Training step. (6 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/6
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside [197.60,198.80]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/6:
#         * After LR finder: LR_NN=0.01 with mse=151.43622414862097 at it=24
#         * v0 = 30
#         * MSE = 44.57105686583569
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [205.80,206.20]
# ----------------------------------------------------------------------------------------------------
#         For scene 2/6:
#         * After LR finder: LR_NN=0.0001 with mse=1.3226106245906555 at it=24
#         * v0 = 30
#         * MSE = 8.353985007827257
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/6
# ----------------------------------------------------------------------------------------------------
# We have 7 time intervals inside [117.00,118.40]
# ----------------------------------------------------------------------------------------------------
#         For scene 3/6:
#         * After LR finder: LR_NN=0.0005 with mse=7.337768635545362 at it=24
#         * v0 = 30
#         * MSE = 255.11235585445976
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.4/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [140.00,140.40]
# ----------------------------------------------------------------------------------------------------
#         For scene 4/6:
#         * After LR finder: LR_NN=1e-05 with mse=2.1972736009046523 at it=24
#         * v0 = 30
#         * MSE = 20.42870422619516
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.5/6
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside [161.60,162.80]
# ----------------------------------------------------------------------------------------------------
#         For scene 5/6:
#         * After LR finder: LR_NN=0.0005 with mse=20.276227198092123 at it=24
#         * v0 = 30
#         * MSE = 88.5046128545198
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.6/6
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [117.80,118.40]
# ----------------------------------------------------------------------------------------------------
#         For scene 6/6:
#         * After LR finder: LR_NN=0.0001 with mse=7.41479639010118 at it=24
#         * v0 = 30
#         * MSE = 65.4598711604104
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 80.40509766154135
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (27 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/27
#         For scene 1/27:
#         * MSE = 13.487447811699914
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/27
#         For scene 2/27:
#         * MSE = 5.36249062433871
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/27
#         For scene 3/27:
#         * MSE = 12.763530638349643
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.4/27
#         For scene 4/27:
#         * MSE = 15.891603519739716
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.5/27
#         For scene 5/27:
#         * MSE = 11.7550015791126
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.6/27
#         For scene 6/27:
#         * MSE = 9.97878779711038
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.7/27
#         For scene 7/27:
#         * MSE = 4.611151146168089
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.8/27
#         For scene 8/27:
#         * MSE = 4.274425285792444
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.9/27
#         For scene 9/27:
#         * MSE = 11.112455762890278
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.10/27
#         For scene 10/27:
#         * MSE = 16.032029637481017
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.11/27
#         For scene 11/27:
#         * MSE = 5.638265602297923
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.12/27
#         For scene 12/27:
#         * MSE = 11.6223407329715
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.13/27
#         For scene 13/27:
#         * MSE = 8.972369985296165
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.14/27
#         For scene 14/27:
#         * MSE = 15.861960120404426
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.15/27
#         For scene 15/27:
#         * MSE = 10.499485405859405
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.16/27
#         For scene 16/27:
#         * MSE = 15.500508203913496
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.17/27
#         For scene 17/27:
#         * MSE = 15.279034383307351
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.18/27
#         For scene 18/27:
#         * MSE = 6.949682519573876
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.19/27
#         For scene 19/27:
#         * MSE = 11.225591995561702
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.20/27
#         For scene 20/27:
#         * MSE = 11.273752697819077
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.21/27
#         For scene 21/27:
#         * MSE = 13.010143039616429
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.22/27
#         For scene 22/27:
#         * MSE = 7.250868315822332
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.23/27
#         For scene 23/27:
#         * MSE = 13.134323238739931
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.24/27
#         For scene 24/27:
#         * MSE = 2.9452033268249527
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.25/27
#         For scene 25/27:
#         * MSE = 8.411999345102403
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.26/27
#         For scene 26/27:
#         * MSE = 13.988151759224694
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.27/27
#         For scene 27/27:
#         * MSE = 19.268870837633003
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 10.96672130787598
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 80.40509766154135
#           * MSE test: 10.96672130787598
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -

# %% [markdown]
# ## Illustration NN10 velocity dependence on consecutive distance

# %%
cd = np.linspace(0.01,1,100) # distances
tmp = model_trained(cd, training=False) # velocities predicted
vv = tmp/np.max(tmp) # velocities normalized
dd = 1/cd # densities

# %%
vv
# Out:
# <tf.Tensor: shape=(100, 1), dtype=float32, numpy=
# array([[-2.7366922 ],
#        [-2.426481  ],
#        [-2.1386645 ],
#        [-1.8718464 ],
#        [-1.6246935 ],
#        [-1.395939  ],
#        [-1.184381  ],
#        [-0.98888046],
#        [-0.80836326],
#        [-0.6418134 ],
#        [-0.48827705],
#        [-0.34685564],
#        [-0.2167083 ],
#        [-0.0970438 ],
#        [ 0.01287633],
#        [ 0.11374339],
#        [ 0.20620352],
#        [ 0.29085854],
#        [ 0.36827135],
#        [ 0.43896547],
#        [ 0.5034279 ],
#        [ 0.5621136 ],
#        [ 0.61544394],
#        [ 0.6638118 ],
#        [ 0.707581  ],
#        [ 0.7470908 ],
#        [ 0.7826557 ],
#        [ 0.8145675 ],
#        [ 0.8430972 ],
#        [ 0.8684957 ],
#        [ 0.8909967 ],
#        [ 0.91081643],
#        [ 0.9281545 ],
#        [ 0.9431978 ],
#        [ 0.95611817],
#        [ 0.9670759 ],
#        [ 0.9762191 ],
#        [ 0.9836849 ],
#        [ 0.9896005 ],
#        [ 0.99408436],
#        [ 0.99724597],
#        [ 0.99918646],
#        [ 1.        ],
#        [ 0.99977404],
#        [ 0.9985891 ],
#        [ 0.9965202 ],
#        [ 0.99363774],
#        [ 0.99000615],
#        [ 0.98568404],
#        [ 0.98072815],
#        [ 0.97518945],
#        [ 0.9691162 ],
#        [ 0.9625533 ],
#        [ 0.9555405 ],
#        [ 0.94811714],
#        [ 0.94031805],
#        [ 0.9321767 ],
#        [ 0.923724  ],
#        [ 0.9149878 ],
#        [ 0.9059948 ],
#        [ 0.8967692 ],
#        [ 0.88733435],
#        [ 0.8777115 ],
#        [ 0.86791956],
#        [ 0.8579773 ],
#        [ 0.84790164],
#        [ 0.83770895],
#        [ 0.8274132 ],
#        [ 0.8170282 ],
#        [ 0.80656683],
#        [ 0.7960408 ],
#        [ 0.78546095],
#        [ 0.77483755],
#        [ 0.76418066],
#        [ 0.75349796],
#        [ 0.7427987 ],
#        [ 0.73208994],
#        [ 0.7213791 ],
#        [ 0.71067196],
#        [ 0.69997555],
#        [ 0.68929523],
#        [ 0.67863625],
#        [ 0.66800314],
#        [ 0.65740097],
#        [ 0.6468338 ],
#        [ 0.6363052 ],
#        [ 0.6258192 ],
#        [ 0.6153789 ],
#        [ 0.60498786],
#        [ 0.59464806],
#        [ 0.5843629 ],
#        [ 0.5741344 ],
#        [ 0.5639648 ],
#        [ 0.5538567 ],
#        [ 0.54381174],
#        [ 0.5338315 ],
#        [ 0.52391744],
#        [ 0.5140716 ],
#        [ 0.50429463],
#        [ 0.49458846]], dtype=float32)>

# %%
# Initialize the fig
nrow, ncol = 1, 2
width, height = 4.5, 4.5 # single subplot
fig, ax = plt.subplots(nrow,ncol,figsize=(width*ncol*.75,height*.75))

# AX 0
ax[0].plot(cd, vv)

ax[0].grid(color='grey', linestyle='-', linewidth=0.1)
# ax[0].set_title(fr"$NN10\ velocity$", fontsize=18)
ax[0].set_xlabel(fr"$distances$", fontsize=15)
ax[0].set_ylabel(fr"$velocity$", fontsize=15)

# AX 1
ax[1].plot(dd, vv)

ax[1].grid(color='grey', linestyle='-', linewidth=0.1)
# ax[1].set_title(fr"$NN10\ velocity$", fontsize=18)
ax[1].set_xlabel(fr"$\rho$", fontsize=15)
ax[1].set_ylabel(fr"$velocity$", fontsize=15)

fig.tight_layout()

plt.suptitle(fr"$NN10\ velocity$", fontsize=16,y=1.05);
plt.show()

# %% [markdown]
# ## Prepare the out dir

# %%
# Create the directory..
if flag_save:
    
    df_seen = [df['N. file'][0] for df in dataset]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}_{NUM_ITER}it-PRE-nn{DOE[1]}-v2")
    
    path = 'out/' + d
    os.mkdir(path)
    
    # Save the solution in a file
    namefile = '/info_nn10.txt'

    with open(path + namefile, 'w') as output:
        info_nn10.to_csv(path + namefile, sep=',', index=False)
        
    # Save model in a file
    namefile_model = '/model_nn10.keras'
    model_trained.compile(optimizer='SGD', loss='MAE')
    model_trained.save(path + namefile_model)  # The file needs to end with the .keras extension
