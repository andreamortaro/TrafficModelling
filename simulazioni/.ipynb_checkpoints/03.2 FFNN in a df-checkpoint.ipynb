# %% [markdown]
# # Solving the NN driven model in a DF

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-12-08 18:32:22.148215: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
merged_df, dflist = load_dataset(dir_name, 'post')

# %% [markdown]
# ## Solve the NN model in a df

# %%
# Create the dataset using scene
df = dflist[8]
len(df)
# Out:
# 9

# %%
## FOR NN
v0 = 30
NUM_ITER=500
LEARNING_RATE_v0 = 0.5
test=0.33

# %%
# Create the model
DOE =[[1,2,1]] #Design of experiment
model = create_model(DOE[0])

# %%
info_df, model_trained = solve_nn_df(df, model, v0, NUM_ITER, LEARNING_RATE_v0, test)
# Out:
# In DataFrame n.9 we have 9 scenes.
#     To train the model we use 6 scenes, the remaining 3 to test the model.
#
# Training step. (6 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/6
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [5.40,6.00]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/6:
#         * After LR finder: LR_NN=0.0005 with mse=35.54486477222214 at it=24
#         * v0 = 29.08110708015713
#         * MSE = 1.4222347265856239
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [205.80,206.20]
# ----------------------------------------------------------------------------------------------------
#         For scene 2/6:
#         * After LR finder: LR_NN=0.001 with mse=1.3637921930640486 at it=24
#         * v0 = 23.15865117600692
#         * MSE = 0.33404442297039344
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/6
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside [37.80,39.00]
# ----------------------------------------------------------------------------------------------------
#         For scene 3/6:
#         * After LR finder: LR_NN=0.001 with mse=42.6081350126324 at it=24
#         * v0 = 23.639051069298045
#         * MSE = 0.9810170421549947
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.4/6
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside [117.80,118.40]
# ----------------------------------------------------------------------------------------------------
#         For scene 4/6:
#         * After LR finder: LR_NN=0.001 with mse=7.652387827126962 at it=24
#         * v0 = 32.94782563350112
#         * MSE = 0.512434327199566
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.5/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [44.40,44.80]
# ----------------------------------------------------------------------------------------------------
#         For scene 5/6:
#         * After LR finder: LR_NN=0.0005 with mse=5.811496174353444 at it=24
#         * v0 = 18.016106720508315
#         * MSE = 0.18127745014354282
#         * iterations = 500
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.6/6
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [120.20,120.60]
# ----------------------------------------------------------------------------------------------------
#         For scene 6/6:
#         * After LR finder: LR_NN=0.0005 with mse=1.8424410221152911 at it=24
#         * v0 = 27.34899072691536
#         * MSE = 0.40920370239962894
#         * iterations = 400
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 0.640035278575625
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (3 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/3
#         For scene 1/3:
#         * MSE = 10.177804843121676
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/3
#         For scene 2/3:
#         * MSE = 9.309680817778915
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/3
#         For scene 3/3:
#         * MSE = 11.115348939469378
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 10.200944866789989
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 0.640035278575625
#           * MSE test: 10.200944866789989
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
