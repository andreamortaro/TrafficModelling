# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import sys
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
from sklearn.model_selection import train_test_split
from datetime import datetime
import time

# Plotting
import matplotlib.pyplot as plt

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_model_nn_v2 import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2024-03-03 15:33:24.452587: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-03 15:33:24.452621: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-03 15:33:24.453707: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-03 15:33:24.459815: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-03 15:33:25.222811: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"

# %%
processed_flag = 'post'
# load the data
_, dflist = load_dataset(dir_name, processed_flag)

# %%
dataset = dflist

# %%
for d in dataset:
    print(len(d))
    for cd_scn in d["cons_dis"]:
        tmp = np.min(cd_scn)
        print(tmp)
# Out:
# 28
# 0.06398973564331811
# 6.650638651027037
# 21.867868119293895
# 7.045585406922143
# 1.8249018808631305
# 11.809448577059499
# 5.686216435036691
# 28.19418223864483
# 25.44823587276452
# 12.540488539264956
# 8.508026009559998
# 17.69822349053316
# 3.8678455123532345
# 15.187441423235612
# 4.755003664057959
# 0.04046246166983991
# 5.493849856081994
# 1.468028334995548
# 12.312884415489918
# 11.923130502152038
# 0.6231039447087596
# 5.871459805313563
# 6.268101680066984
# 7.089880913477089
# 6.3068009413061645
# 0.17182906282188526
# 5.430570457430619
# 12.026956703245816
# 18
# 15.336319185212645
# 1.9473097108887316
# 4.770275458583356
# 19.590731779160336
# 0.31660363334373187
# 19.550415897563663
# 19.44108065008476
# 23.53594731028231
# 0.10401042016907525
# 10.465366519441439
# 21.203205872183744
# 0.3767804600500284
# 2.552181382613604
# 2.2437828775204665
# 11.0676552647315
# 15.871357003429651
# 6.258434121566573
# 9.018666604630212
# 55
# 16.64999277085782
# 15.526464891753001
# 1.1717516510194628
# 4.02817253881453
# 3.8492730354923737
# 20.31281112799232
# 21.24506130250984
# 11.077800354505811
# 9.72778834048782
# 31.38836875196931
# 9.629461839956377
# 1.0314439568624607
# 12.690654866533237
# 8.323610267794088
# 0.34372427679407735
# 9.60311383712093
# 10.886629439045933
# 16.25578939864174
# 0.03400474638272044
# 14.30453318434568
# 6.2150496062072875
# 0.9338297775907733
# 14.833058580289247
# 7.180610741263891
# 17.83793873894828
# 11.144434172917315
# 16.070550748653574
# 1.1128249274825635
# 0.42099593060626717
# 16.123429083627784
# 13.172970077914982
# 10.531616833642254
# 10.477999648488506
# 29.190435502565194
# 18.82357344001462
# 7.686772340949467
# 11.94092436644872
# 18.708773870560947
# 22.18338191707562
# 22.418097651337007
# 1.9459510869424577
# 9.870878737415723
# 0.2972449305911766
# 7.290521270054171
# 7.697561336433466
# 8.239488865291293
# 0.6197762659275554
# 3.7926928764795065
# 12.190610954301683
# 1.0081852588134694
# 8.298252628789001
# 9.543898746880359
# 0.1379994550840422
# 0.49802155122289093
# 0.03603585603846682
# 30
# 6.774111694160979
# 7.440417654459765
# 0.24399360963199968
# 0.49202034031363695
# 27.260738355693306
# 14.730709933024343
# 0.16240360034847612
# 7.893669587584526
# 2.943453011909753
# 15.313411720046119
# 0.5121700611563966
# 0.1903685526691561
# 10.556041431369877
# 23.476615001449375
# 10.978269874754446
# 15.527901947104482
# 7.420555809016221
# 2.152158229119337
# 2.008853438521598
# 19.821478836524243
# 4.648755894947001
# 3.0237112394883496
# 0.6903898693804393
# 3.267904913691538
# 5.15765386335211
# 4.380486546596302
# 0.6380741804372008
# 3.5072459982651196
# 5.16023915652125
# 6.953597493198572
# 14
# 5.281547877410674
# 21.93960530699688
# 0.3818275746869091
# 9.848720159409623
# 4.1722256828803665
# 8.166731728499286
# 12.418173946568565
# 4.480707509139663
# 23.017756288408084
# 2.973616851562255
# 2.865558556423043
# 19.99496419083117
# 25.439809944822045
# 4.1722256828803665
# 3
# 11.265801266437158
# 2.7178126971763987
# 1.3337841823080865
# 8
# 3.2725094987324326
# 0.02397386236092558
# 12.787591210611623
# 17.58953911954859
# 6.892838432478257
# 16.6995712756874
# 10.360282563110374
# 0.9272694469807305
# 21
# 0.7208501158316025
# 5.768212633418152
# 5.3156063631461805
# 3.7145124784143775
# 6.856713469714606
# 0.7760262098728177
# 0.4137370110812455
# 0.8298920937064835
# 4.020826381504939
# 7.3415654282067635
# 3.0211692061243554
# 0.2912057167688573
# 3.5421507289017313
# 22.106265501439832
# 1.0561854705298401
# 0.16659708878851376
# 28.71564147477941
# 15.728554776502733
# 14.736032760799766
# 7.112580463318565
# 0.01454846373347607
# 9
# 0.9203168773941144
# 0.5012702078579423
# 4.909951705238683
# 11.810555650062831
# 11.953879680099085
# 15.266867751575006
# 22.910359893447755
# 1.742710407698162
# 16.2464941623482
# 22
# 8.185272418447951
# 1.3941465229237693
# 10.51611044008969
# 1.2519673557709012
# 2.8420385733720934
# 2.087944897585942
# 16.84531890899318
# 4.320061487635748
# 5.910697701679602
# 0.7080367970028121
# 13.772028072218525
# 16.92117620991777
# 12.585213044290484
# 3.831273141238043
# 0.11553838683138906
# 7.032889481146356
# 10.533239782237104
# 4.4356152067037655
# 3.8005883526897435
# 2.087944897585942
# 0.2577309024503762
# 0.8660401442852717

# %% [markdown]
# ## Params

# %%
# Flags
plot_flag = False
flag_save = False
testing_flag = True

# %%
# params
DOE =[1,10,1] #Design of experiment

v0 = 30
NUM_ITER = 500
LEARNING_RATE_v0 = 0.5
test = 0.33
dataset = dflist

if testing_flag:
    NUM_ITER = 1
    test = 0.8
    dataset = dflist[7:9]

print(f"In this dataset we have {np.sum([d.shape[0] for d in dataset])} scenes")
# Out:
# In this dataset we have 30 scenes

# %% [markdown]
# ## NN: 1-10-1

# %%
info_nn10, model_trained = solve_nn_dataset(dataset, DOE, v0, processed_flag, NUM_ITER, LEARNING_RATE_v0,
                                           test, plot_flag)
# Out:
# ----------------------------------------------------------------------------------------------------
# Analyzing 2 dfs. NN structure: 1-10-1
# ****************************************************************************************************
# Analyzing 1/2 dfs.
# In DataFrame n.8 we have 21 scenes.
#     To train the model we use 4 scenes, the remaining 17 to test the model.
#
# Training step. (4 scenes)
# ====================================================================================================
# DataFrame n.8. Scene n.1/4
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [239.84,240.24]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/4:
#         * After LR finder: LR_NN=0.0005 with mse=4.149980871253268 at it=24
#         * v0 = 30
#         * MSE = 16.765793054904247
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.2/4
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside [350.64,351.64]
# ----------------------------------------------------------------------------------------------------
#         For scene 2/4:
#         * After LR finder: LR_NN=0.001 with mse=10.579860498671957 at it=24
#         * v0 = 30
#         * MSE = 71.13315594976491
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.3/4
# ----------------------------------------------------------------------------------------------------
# We have 7 time intervals inside [593.04,594.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 3/4:
#         * After LR finder: LR_NN=0.0005 with mse=30.130680842955798 at it=24
#         * v0 = 30
#         * MSE = 139.25771152238823
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.4/4
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside [222.64,223.44]
# ----------------------------------------------------------------------------------------------------
#         For scene 4/4:
#         * After LR finder: LR_NN=1e-05 with mse=24.844799800594213 at it=24
#         * v0 = 30
#         * MSE = 32.8189137356537
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 64.99389356567778
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (17 scenes)
# ====================================================================================================
# DataFrame n.8. Scene n.1/17
#         For scene 1/17:
#         * MSE = 5.144509631433441
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.2/17
#         For scene 2/17:
#         * MSE = 1.8241460960656857
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.3/17
#         For scene 3/17:
#         * MSE = 4.246088858067183
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.4/17
#         For scene 4/17:
#         * MSE = 3.0246754395610154
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.5/17
#         For scene 5/17:
#         * MSE = 0.7706623401144012
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.6/17
#         For scene 6/17:
#         * MSE = 5.692000967205492
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.7/17
#         For scene 7/17:
#         * MSE = 4.01517357507198
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.8/17
#         For scene 8/17:
#         * MSE = 5.223235143163727
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.9/17
#         For scene 9/17:
#         * MSE = 0.6151047091591872
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.10/17
#         For scene 10/17:
#         * MSE = 3.304780823578044
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.11/17
#         For scene 11/17:
#         * MSE = 1.611880822027219
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.12/17
#         For scene 12/17:
#         * MSE = 4.424351584967254
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.13/17
#         For scene 13/17:
#         * MSE = 0.4239259884428061
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.14/17
#         For scene 14/17:
#         * MSE = 3.4765282143383907
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.15/17
#         For scene 15/17:
#         * MSE = 4.273791415775481
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.16/17
#         For scene 16/17:
#         * MSE = 4.2193738585462714
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.8. Scene n.17/17
#         For scene 17/17:
#         * MSE = 6.821084418224554
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 3.4771361109260077
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 64.99389356567778
#           * MSE test: 3.4771361109260077
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#
#
#
# Analyzing 2/2 dfs.
# In DataFrame n.9 we have 9 scenes.
#     To train the model we use 1 scenes, the remaining 8 to test the model.
#
# Training step. (1 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/1
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside [120.20,120.60]
# ----------------------------------------------------------------------------------------------------
#         For scene 1/1:
#         * After LR finder: LR_NN=0.0001 with mse=1.6426145883553538 at it=24
#         * v0 = 30
#         * MSE = 4.824888725648746
#         * iterations = 1
# ----------------------------------------------------------------------------------------------------
#
#
# MSE train: 4.824888725648746
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
# Testing step. (8 scenes)
# ====================================================================================================
# DataFrame n.9. Scene n.1/8
#         For scene 1/8:
#         * MSE = 5.504525290128112
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.2/8
#         For scene 2/8:
#         * MSE = 6.945499047410171
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.3/8
#         For scene 3/8:
#         * MSE = 2.9760810367769337
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.4/8
#         For scene 4/8:
#         * MSE = 8.151681468984345
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.5/8
#         For scene 5/8:
#         * MSE = 0.5611125810613455
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.6/8
#         For scene 6/8:
#         * MSE = 5.653896849264922
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.7/8
#         For scene 7/8:
#         * MSE = 2.6461500786741428
# ----------------------------------------------------------------------------------------------------
#
#
# DataFrame n.9. Scene n.8/8
#         For scene 8/8:
#         * MSE = 4.117609742475254
# ----------------------------------------------------------------------------------------------------
#
#
# MSE test: 4.569569511846903
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -
#
#     Summing up:
#           * MSE train: 4.824888725648746
#           * MSE test: 4.569569511846903
#
# - -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -

# %% [markdown]
# ## Illustration NN10 velocity dependence on consecutive distance

# %%
cd = np.linspace(0.01,1,100) # distances
tmp = model_trained(cd, training=False) # velocities predicted
vv = tmp/np.max(tmp) # velocities normalized
dd = 1/cd # densities

# %%
# Initialize the fig
nrow, ncol = 1, 2
width, height = 4.5, 4.5 # single subplot
fig, ax = plt.subplots(nrow,ncol,figsize=(width*ncol*.75,height*.75))

# AX 0
ax[0].plot(cd, vv)

ax[0].grid(color='grey', linestyle='-', linewidth=0.1)
# ax[0].set_title(fr"$NN10\ velocity$", fontsize=18)
ax[0].set_xlabel(fr"$distances$", fontsize=15)
ax[0].set_ylabel(fr"$velocity$", fontsize=15)

# AX 1
ax[1].plot(dd, vv)

ax[1].grid(color='grey', linestyle='-', linewidth=0.1)
# ax[1].set_title(fr"$NN10\ velocity$", fontsize=18)
ax[1].set_xlabel(fr"$\rho$", fontsize=15)
ax[1].set_ylabel(fr"$velocity$", fontsize=15)

fig.tight_layout()

plt.suptitle(fr"$NN10\ velocity$", fontsize=16,y=1.05);
plt.show()

# %% [markdown]
# ## Prepare the out dir

# %%
# Create the directory..
if flag_save:
    
    df_seen = [df['N. file'][0] for df in dataset]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}_{NUM_ITER}it-PRE-nn{DOE[1]}")
    
    path = 'out/' + d
    os.mkdir(path)
    
    # Save the solution in a file
    namefile = '/info_nn10.txt'

    with open(path + namefile, 'w') as output:
        info_nn10.to_csv(path + namefile, sep=',', index=False)
        
    # Save model in a file
    namefile_model = '/model_nn10.keras'
    model_trained.compile(optimizer='SGD', loss='MAE')
    model_trained.save(path + namefile_model)  # The file needs to end with the .keras extension
