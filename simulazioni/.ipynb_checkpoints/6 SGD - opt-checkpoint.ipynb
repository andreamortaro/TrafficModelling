# %% [markdown]
# # Writing a training loop from scratch
# https://www.tensorflow.org/guide/keras/writing_a_training_loop_from_scratch

# %% [markdown]
# ## Import libraries

# %%
# Python libraries
import os
import pandas as pd # for data manipulation
import numpy as np # for data manipulation
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.full.myfun_models import *
from ipynb.fs.full.myfun_nn import *
from ipynb.fs.defs.myfun_plot import *
# Out:
# 2023-08-27 18:06:29.696636: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
merged_df, dflist = load_dataset(dir_name, 'post')

# %% [markdown]
# ## Create the model NN

# %%
# Create the model
DOE =[[1,2,1]] #Design of experiment
model = create_model(DOE[0])

# %% [markdown]
# ### What do trainable variables and trainable weights mean?

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-Layer-1 (Dense)      (None, 2)                 4
#
#  Output-Layer (Dense)        (None, 1)                 3
#
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables), len(model.trainable_weights)
# Out:
# (4, 4)

# %%
for var in model.trainable_variables:
    print(f"{var.name}:\t {var.numpy().flatten()}")
# Out:
# Hidden-Layer-1/kernel:0:	 [-0.42171264 -0.7367747 ]
# Hidden-Layer-1/bias:0:	 [-0.24405456 -0.39395976]
# Output-Layer/kernel:0:	 [-0.9308872   0.68041825]
# Output-Layer/bias:0:	 [-0.9853182]

# %% [markdown]
# ## Training loop

# %%
NUM_EPOCHS = 100
deltat = 0.05
nprint = 50

# %%
# Create the dataset using scene
df = dflist[0]
scn_list = seq2scn(df)
scn_train, scn_test = train_test_split(scn_list, test_size=0.8, random_state=40)

# %%
len(scn_train)
# Out:
# 5

# %%
## FOR NN MODEL

# Optimizer
LEARNING_RATE = 0.01
optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE)

# Instantiate a loss function.
loss_fn = tf.keras.losses.MeanSquaredError()

# %%
def solve_scn(scn, v0):
    
    """
    t_list, x_list, v_list = solve_scn(scn)
    """
    
    x_list, t_list, v_list = [[i] for i in scn['Xarr'][:,0]], [scn['Tarr'][0]], []
    N = scn['N. vehicles']
    
    X_arr, y_arr = create_data_ann_scene(scn)

    for i in range(0,len(tstamps)-1):

        ## STEP 1: Create the dataset and train the nn model
        X, y = X_arr[:,i], y_arr[:,i]

        with tf.GradientTape(persistent=True) as tape:

            # Create tensor that you will watch
            x_tensor = tf.convert_to_tensor(X, dtype=tf.float64)
            tape.watch(x_tensor)

            y_pred = model(X, training=True) # forward pass
            loss_value = loss_fn(y_true = y, y_pred = y_pred) # loss function

        # Compute gradients
        trainable_vars = model.trainable_variables
        grads = tape.gradient(loss_value, trainable_vars)

        # Update weights
        optimizer.apply_gradients(zip(grads, trainable_vars))

#         print_grads(model, grads) # plot the last grads wrt trainable vars

        # Store the prediction
        v_list.append(np.append(y_pred.numpy().flatten().tolist(),v0).tolist())

        ## STEP 2: Solve the ODE sys in this time interval
        x0 = [l[-1] for l in np.vstack(x_list).tolist()]  # last values computed
        t0, tend = scn['Tarr'][i], scn['Tarr'][i+1]
        v_ann = v_list[i]
        tspan_ann, sol_ann = odesolver_ann(x0, v_ann, t0, tend, deltat)

        ## STEP 3: Update x_ann_list, t_ann_list
        x_ann = sol_ann.tolist()
        t_ann = tspan_ann[1:] # avoid the first recording

        # add sol to the correct veh
        for j in range(0,N):
            tmp = x_ann[j][1:] # avoid the first recording
            x_list[j] = np.concatenate([x_list[j],tmp])
        t_list = np.concatenate([t_list,t_ann]).tolist()
#             print("--"*50)

    return t_list, x_list, v_list

# %%
# def solve_scn_wrapped(v0):

#     """
#     t_list_matched, x_list_matched = solve_scn_wrapped(v0)
#     """

#     t_list, x_list, _ = solve_scn(scn, v0)
#     _, x_list_matched = match_timestamps_scene(t_list, x_list)
#     return x_list_matched

# %%
## FOR OPTIMIZING v0
loss_objective = tf.keras.losses.MeanSquaredError()
LEARNING_RATE_v0 = 0.5

# %%
v0 = 30
fmt = '{0:.02f}'

for step, scn in enumerate(scn_train):
    print("=="*50)
    
    tstamps = scn['Tarr']
    
    print(f"\nStep n. {step} - Scene n. {scn.name}, time interval:\
    [{fmt.format(tstamps[0])},{fmt.format(tstamps[-1])}]")
    

    for epoch in range(NUM_EPOCHS+1):
        
        t_list, x_list, _ = solve_scn(scn, v0)
        _, x_list_matched = match_timestamps_scene(t_list, x_list)

        with tf.GradientTape(persistent=True) as tape:

            trajs_true_tensor = tf.convert_to_tensor(scn['Xarr'], dtype=tf.float64)

            # Create tensor that you will watch
            trajs_pred_tensor = tf.convert_to_tensor(x_list_matched, dtype=tf.float64)
            tape.watch(trajs_pred_tensor)

            loss_val = loss_objective(y_true = trajs_true_tensor, y_pred = trajs_pred_tensor)

        # Compute gradients
        grads = tape.gradient(loss_val, trajs_pred_tensor)
        
        # Update weights
        g = grads[-1].numpy()[1:].mean() # I'm watching at a mean velocity..
        v0 = v0 - LEARNING_RATE_v0*g
        
        
        if epoch % nprint == 0:
            print("--"*50)
            print(f"Epoch n.{epoch}")

            # plot function
            t_ann_matched, trajs_ann_matched = match_timestamps_scene(t_list, x_list)
            tscale = 1+(tstamps[-1]-tstamps[0])/20000
            title = f"{step} - Scene n. {scn.name}, at epoch n.{epoch}"
            plot_scn(scn, trajs_ann_matched, title, xbal=0.01, ybal=0.05, scale=tscale)

            print(f"\n\
            Loss: {loss_val}\n\
            gradiente per v0: {grads[-1].numpy()[1:].mean()}\n\
            v0 updated: {v0}")
            print("--"*50)

    print("=="*50)
# Out:
# ====================================================================================================
#
# Step n. 0 - Scene n. 18, time interval:    [431.84,432.24]
# ----------------------------------------------------------------------------------------------------
# Epoch n.0
#             Loss: 47.902400367312175
#             gradiente per v0: -0.005610775998142178
#             v0 updated: 30.00280538799907
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.50
#             Loss: 1.2532574942918135
#             gradiente per v0: -0.0010300542285190395
#             v0 updated: 30.06922585365408
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.100
#             Loss: 0.48773837276646076
#             gradiente per v0: -0.00018910249036392657
#             v0 updated: 30.08141965386285
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
#
# Step n. 1 - Scene n. 24, time interval:    [500.64,501.04]
# ----------------------------------------------------------------------------------------------------
# Epoch n.0
#             Loss: 16.43339093718946
#             gradiente per v0: 1.1813366819126558
#             v0 updated: 29.49075131290652
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.50
#             Loss: 0.5334522012985203
#             gradiente per v0: 0.21687567733308316
#             v0 updated: 15.506066746497849
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.100
#             Loss: 0.048667882270323815
#             gradiente per v0: 0.039815118025867624
#             v0 updated: 12.938688636545452
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
#
# Step n. 2 - Scene n. 5, time interval:    [148.04,148.44]
# ----------------------------------------------------------------------------------------------------
# Epoch n.0
#             Loss: 8.27907662088196
#             gradiente per v0: -0.9788645318449134
#             v0 updated: 13.428120902467908
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.50
#             Loss: 0.7074269480227774
#             gradiente per v0: -0.17970483064750437
#             v0 updated: 25.015936569828288
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.100
#             Loss: 0.5199975169412027
#             gradiente per v0: -0.03299110868503084
#             v0 updated: 27.14328553828558
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
#
# Step n. 3 - Scene n. 7, time interval:    [164.04,164.64]
# ----------------------------------------------------------------------------------------------------
# Epoch n.0
#             Loss: 3.083025598157157
#             gradiente per v0: -0.3526377011604593
#             v0 updated: 27.31960438886581
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.50
#             Loss: 0.9575219693276159
#             gradiente per v0: -0.06473898716886516
#             v0 updated: 31.494135741745367
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.100
#             Loss: 0.9079981850379054
#             gradiente per v0: -0.011885106005253629
#             v0 updated: 32.260517018620405
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
#
# Step n. 4 - Scene n. 6, time interval:    [161.64,162.04]
# ----------------------------------------------------------------------------------------------------
# Epoch n.0
#             Loss: 0.371248480933352
#             gradiente per v0: -0.16341989275904073
#             v0 updated: 32.342226964999924
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.50
#             Loss: 0.27977185161556395
#             gradiente per v0: -0.03000143860286641
#             v0 updated: 34.276794550267844
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Epoch n.100
#             Loss: 0.28233687168309546
#             gradiente per v0: -0.005507813663570005
#             v0 updated: 34.631952111887536
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
