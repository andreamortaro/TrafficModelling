# %%
## Libraries
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from datetime import datetime

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.defs.myfun_models import *
# Out:
# 2023-09-09 17:55:27.413300: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow/Keras: 2.11.0
# sklearn: 1.3.0

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"

# %% [markdown]
# ## Solve Lin/Log models in a df

# %%
flag_save = False

# %%
# Pre
flag_processed = 'pre'
_, dflist = load_dataset(dir_name, flag_processed)

# Compute
info_alldataset_pre = solve_TD_LWR_dataset(dflist, TD_LWR_model, v0=30, L=5, deltat=0.001, tol=1e-8, pplot=False)
info_alldataset_pre['processed'] = [flag_processed] * info_alldataset_pre.shape[0]
# Out:
# ====================================================================================================
# df n.1 - Scene n.0/110
# ----------------------------------------------------------------------------------------------------
# Scene n.0.
#     Initial mse: 1.8484278632480775
#
# After optimizing, new params: v0 = 32.52400440779791, L = 2.114480066289242
#
# Initial mse: 0.08923681999214601
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [2.24,2.84]
# Time interval n.0: [2.24, 2.44]
# Time interval n.1: [2.44, 2.64]
# Time interval n.2: [2.64, 2.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.1/110
# ----------------------------------------------------------------------------------------------------
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.0000000000000D+00
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7490000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7540000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  lsoda--  trouble from intdy. itask = i1, tout = r1
#       in above message,  i1 =         1
#       in above message,  r1 =  0.7540000000000D+01
# Scene n.1.
#     Initial mse: 1261.8942976565756
#
# After optimizing, new params: v0 = 30.0, L = 5.0
#
# Initial mse: 1261.8942976565756
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [7.44,7.84]
# Time interval n.0: [7.44, 7.64]
# Time interval n.1: [7.64, 7.84]
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.0000000000000D+00
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7490000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7540000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  lsoda--  trouble from intdy. itask = i1, tout = r1
#       in above message,  i1 =         1
#       in above message,  r1 =  0.7540000000000D+01
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.0000000000000D+00
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7490000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7540000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  lsoda--  trouble from intdy. itask = i1, tout = r1
#       in above message,  i1 =         1
#       in above message,  r1 =  0.7540000000000D+01
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.0000000000000D+00
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7490000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7540000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  lsoda--  trouble from intdy. itask = i1, tout = r1
#       in above message,  i1 =         1
#       in above message,  r1 =  0.7540000000000D+01
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.0000000000000D+00
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7490000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7540000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  lsoda--  trouble from intdy. itask = i1, tout = r1
#       in above message,  i1 =         1
#       in above message,  r1 =  0.7540000000000D+01
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.0000000000000D+00
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7490000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  intdy--  t (=r1) illegal
#       in above message,  r1 =  0.7540000000000D+01
#       t not in interval tcur - hu (= r1) to tcur (=r2)
#       in above,  r1 =  0.7440000000000D+01   r2 =  0.7440000000000D+01
#  lsoda--  trouble from intdy. itask = i1, tout = r1
#       in above message,  i1 =         1
#       in above message,  r1 =  0.7540000000000D+01
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.2/110
# ----------------------------------------------------------------------------------------------------
# Scene n.2.
#     Initial mse: 0.8851070099224433
#
# After optimizing, new params: v0 = 27.026376656007596, L = 2.0
#
# Initial mse: 0.3781524661950974
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [16.44,16.84]
# Time interval n.0: [16.44, 16.64]
# Time interval n.1: [16.64, 16.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.3/110
# ----------------------------------------------------------------------------------------------------
# Scene n.3.
#     Initial mse: 6.410282913945186
#
# Optimization not succeed
#
# Initial mse: 6.410282913945186
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [33.44,34.04]
# Time interval n.0: [33.44, 33.64]
# Time interval n.1: [33.64, 33.84]
# Time interval n.2: [33.84, 34.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.4/110
# ----------------------------------------------------------------------------------------------------
# Scene n.4.
#     Initial mse: 4.540249157509551
#
# After optimizing, new params: v0 = 29.109447823737298, L = 2.0
#
# Initial mse: 1.2403403910365984
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [37.44,38.24]
# Time interval n.0: [37.44, 37.64]
# Time interval n.1: [37.64, 37.84]
# Time interval n.2: [37.84, 38.04]
# Time interval n.3: [38.04, 38.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.5/110
# ----------------------------------------------------------------------------------------------------
# Scene n.5.
#     Initial mse: 0.46771931455901206
#
# After optimizing, new params: v0 = 29.381091902483103, L = 2.477765008828755
#
# Initial mse: 0.09748761209364668
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [44.24,44.84]
# Time interval n.0: [44.24, 44.44]
# Time interval n.1: [44.44, 44.64]
# Time interval n.2: [44.64, 44.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.6/110
# ----------------------------------------------------------------------------------------------------
# Scene n.6.
#     Initial mse: 49.71483725078565
#
# After optimizing, new params: v0 = 37.53647314336948, L = 2.0
#
# Initial mse: 2.20998181197924
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [52.84,53.84]
# Time interval n.0: [52.84, 53.04]
# Time interval n.1: [53.04, 53.24]
# Time interval n.2: [53.24, 53.44]
# Time interval n.3: [53.44, 53.64]
# Time interval n.4: [53.64, 53.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.7/110
# ----------------------------------------------------------------------------------------------------
# Scene n.7.
#     Initial mse: 7.9902177142039434
#
# After optimizing, new params: v0 = 35.206408938583806, L = 2.0
#
# Initial mse: 1.6983931537277375
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [54.84,55.24]
# Time interval n.0: [54.84, 55.04]
# Time interval n.1: [55.04, 55.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.8/110
# ----------------------------------------------------------------------------------------------------
# Scene n.8.
#     Initial mse: 6.303283638283937
#
# After optimizing, new params: v0 = 35.77304683466431, L = 5.204177387835342
#
# Initial mse: 0.204852275320685
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [56.84,57.64]
# Time interval n.0: [56.84, 57.04]
# Time interval n.1: [57.04, 57.24]
# Time interval n.2: [57.24, 57.44]
# Time interval n.3: [57.44, 57.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.9/110
# ----------------------------------------------------------------------------------------------------
# Scene n.9.
#     Initial mse: 10.352987744344647
#
# After optimizing, new params: v0 = 30.838193667034858, L = 2.0
#
# Initial mse: 3.9253064213455766
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [60.04,60.84]
# Time interval n.0: [60.04, 60.24]
# Time interval n.1: [60.24, 60.44]
# Time interval n.2: [60.44, 60.64]
# Time interval n.3: [60.64, 60.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.10/110
# ----------------------------------------------------------------------------------------------------
# Scene n.10.
#     Initial mse: 40.34098200245325
#
# After optimizing, new params: v0 = 33.225824240451374, L = 2.0
#
# Initial mse: 9.494867811863477
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [80.64,81.64]
# Time interval n.0: [80.64, 80.84]
# Time interval n.1: [80.84, 81.04]
# Time interval n.2: [81.04, 81.24]
# Time interval n.3: [81.24, 81.44]
# Time interval n.4: [81.44, 81.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.11/110
# ----------------------------------------------------------------------------------------------------
# Scene n.11.
#     Initial mse: 1.2514452360389705
# myfun/myfun_models.ipynb:34: RuntimeWarning: divide by zero encountered in double_scalars
#   "source": [
# /home/andrea/anaconda3/envs/tesi/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# myfun/myfun_models.ipynb:34: RuntimeWarning: divide by zero encountered in double_scalars
#   "source": [
# /home/andrea/anaconda3/envs/tesi/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# myfun/myfun_models.ipynb:34: RuntimeWarning: divide by zero encountered in double_scalars
#   "source": [
# /home/andrea/anaconda3/envs/tesi/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# myfun/myfun_models.ipynb:34: RuntimeWarning: divide by zero encountered in double_scalars
#   "source": [
# /home/andrea/anaconda3/envs/tesi/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# myfun/myfun_models.ipynb:34: RuntimeWarning: divide by zero encountered in double_scalars
#   "source": [
# /home/andrea/anaconda3/envs/tesi/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# myfun/myfun_models.ipynb:34: RuntimeWarning: divide by zero encountered in double_scalars
#   "source": [
# /home/andrea/anaconda3/envs/tesi/lib/python3.10/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Illegal input detected (internal error). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# After optimizing, new params: v0 = 31.870900673893235, L = 2.0
#
# Initial mse: 0.0781014810317048
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [87.84,88.44]
# Time interval n.0: [87.84, 88.04]
# Time interval n.1: [88.04, 88.24]
# Time interval n.2: [88.24, 88.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.12/110
# ----------------------------------------------------------------------------------------------------
# Scene n.12.
#     Initial mse: 48.46848947067742
#
# After optimizing, new params: v0 = 36.097254101326364, L = 2.0
#
# Initial mse: 4.353355823701282
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [89.04,90.04]
# Time interval n.0: [89.04, 89.24]
# Time interval n.1: [89.24, 89.44]
# Time interval n.2: [89.44, 89.64]
# Time interval n.3: [89.64, 89.84]
# Time interval n.4: [89.84, 90.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.13/110
# ----------------------------------------------------------------------------------------------------
# Scene n.13.
#     Initial mse: 11.931848477288082
#
# After optimizing, new params: v0 = 38.866333237338175, L = 3.71213827058902
#
# Initial mse: 0.737435674637835
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [90.84,91.44]
# Time interval n.0: [90.84, 91.04]
# Time interval n.1: [91.04, 91.24]
# Time interval n.2: [91.24, 91.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.14/110
# ----------------------------------------------------------------------------------------------------
# Scene n.14.
#     Initial mse: 7.633544570370187
#
# After optimizing, new params: v0 = 35.83655396363328, L = 3.014053362242379
#
# Initial mse: 0.45941758430225427
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [109.24,109.84]
# Time interval n.0: [109.24, 109.44]
# Time interval n.1: [109.44, 109.64]
# Time interval n.2: [109.64, 109.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.15/110
# ----------------------------------------------------------------------------------------------------
# Scene n.15.
#     Initial mse: 14.37354270668447
#
# After optimizing, new params: v0 = 35.85019782721561, L = 4.169665070117759
#
# Initial mse: 1.7957907740021606
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [116.04,117.04]
# Time interval n.0: [116.04, 116.24]
# Time interval n.1: [116.24, 116.44]
# Time interval n.2: [116.44, 116.64]
# Time interval n.3: [116.64, 116.84]
# Time interval n.4: [116.84, 117.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.16/110
# ----------------------------------------------------------------------------------------------------
# Scene n.16.
#     Initial mse: 6.293309451924774
#
# After optimizing, new params: v0 = 33.63142750895717, L = 2.0
#
# Initial mse: 0.16130196309125328
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [120.84,121.44]
# Time interval n.0: [120.84, 121.04]
# Time interval n.1: [121.04, 121.24]
# Time interval n.2: [121.24, 121.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.17/110
# ----------------------------------------------------------------------------------------------------
# Scene n.17.
#     Initial mse: 4.530405680300599
#
# After optimizing, new params: v0 = 32.42468355027913, L = 2.933533611724878
#
# Initial mse: 1.1342047863341538
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [130.64,131.44]
# Time interval n.0: [130.64, 130.84]
# Time interval n.1: [130.84, 131.04]
# Time interval n.2: [131.04, 131.24]
# Time interval n.3: [131.24, 131.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.18/110
# ----------------------------------------------------------------------------------------------------
# Scene n.18.
#     Initial mse: 2.120356986057722
#
# After optimizing, new params: v0 = 35.07766450237389, L = 7.1679858602313065
#
# Initial mse: 0.07753248573861385
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [140.64,141.24]
# Time interval n.0: [140.64, 140.84]
# Time interval n.1: [140.84, 141.04]
# Time interval n.2: [141.04, 141.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.19/110
# ----------------------------------------------------------------------------------------------------
# Scene n.19.
#     Initial mse: 1.617524487960676
#
# After optimizing, new params: v0 = 31.34185038674486, L = 2.0
#
# Initial mse: 0.44764679390453505
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [142.04,142.44]
# Time interval n.0: [142.04, 142.24]
# Time interval n.1: [142.24, 142.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.20/110
# ----------------------------------------------------------------------------------------------------
# Scene n.20.
#     Initial mse: 1.961085932513847
#
# After optimizing, new params: v0 = 27.75612534621232, L = 2.0
#
# Initial mse: 0.6949743688830705
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [146.24,146.64]
# Time interval n.0: [146.24, 146.44]
# Time interval n.1: [146.44, 146.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.21/110
# ----------------------------------------------------------------------------------------------------
# Scene n.21.
#     Initial mse: 0.1557644384912437
#
# After optimizing, new params: v0 = 29.44817239498593, L = 4.637822223789947
#
# Initial mse: 0.10897494860388439
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [159.84,160.64]
# Time interval n.0: [159.84, 160.04]
# Time interval n.1: [160.04, 160.24]
# Time interval n.2: [160.24, 160.44]
# Time interval n.3: [160.44, 160.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.22/110
# ----------------------------------------------------------------------------------------------------
# Scene n.22.
#     Initial mse: 9.997519383641109
# After optimizing, new params: v0 = 39.638773293490445, L = 2.0
#
# Initial mse: 0.5153182154847543
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [193.24,193.64]
# Time interval n.0: [193.24, 193.44]
# Time interval n.1: [193.44, 193.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.23/110
# ----------------------------------------------------------------------------------------------------
# Scene n.23.
#     Initial mse: 28.84899614329661
#
# After optimizing, new params: v0 = 39.50654505478782, L = 2.0
#
# Initial mse: 2.339943026210147
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [194.84,195.44]
# Time interval n.0: [194.84, 195.04]
# Time interval n.1: [195.04, 195.24]
# Time interval n.2: [195.24, 195.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.24/110
# ----------------------------------------------------------------------------------------------------
# Scene n.24.
#     Initial mse: 9.293247625291958
#
# After optimizing, new params: v0 = 30.146187141918723, L = 2.0
#
# Initial mse: 4.6824739429273725
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [199.44,199.84]
# Time interval n.0: [199.44, 199.64]
# Time interval n.1: [199.64, 199.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.25/110
# ----------------------------------------------------------------------------------------------------
# Scene n.25.
#     Initial mse: 9.573079978496448
#
# After optimizing, new params: v0 = 33.14761347093611, L = 2.0
#
# Initial mse: 1.213830379416546
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [200.44,201.24]
# Time interval n.0: [200.44, 200.64]
# Time interval n.1: [200.64, 200.84]
# Time interval n.2: [200.84, 201.04]
# Time interval n.3: [201.04, 201.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.26/110
# ----------------------------------------------------------------------------------------------------
# Scene n.26.
#     Initial mse: 0.9963161348808423
#
# After optimizing, new params: v0 = 31.743776872240197, L = 3.2439411180914974
#
# Initial mse: 0.09295500559222786
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [209.64,210.24]
# Time interval n.0: [209.64, 209.84]
# Time interval n.1: [209.84, 210.04]
# Time interval n.2: [210.04, 210.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.27/110
# ----------------------------------------------------------------------------------------------------
# Scene n.27.
#     Initial mse: 23.344049172542505
#
# After optimizing, new params: v0 = 36.93413512635473, L = 2.0
#
# Initial mse: 4.115417045039656
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [219.64,220.24]
# Time interval n.0: [219.64, 219.84]
# Time interval n.1: [219.84, 220.04]
# Time interval n.2: [220.04, 220.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.28/110
# ----------------------------------------------------------------------------------------------------
# Scene n.28.
#     Initial mse: 4.673561373883178
#
# After optimizing, new params: v0 = 33.99359605164736, L = 2.0
#
# Initial mse: 0.3026610708176851
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [230.04,230.64]
# Time interval n.0: [230.04, 230.24]
# Time interval n.1: [230.24, 230.44]
# Time interval n.2: [230.44, 230.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.29/110
# ----------------------------------------------------------------------------------------------------
# Scene n.29.
#     Initial mse: 19.28607992325156
#
# After optimizing, new params: v0 = 31.899554990209708, L = 2.0
#
# Initial mse: 9.653255699267055
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [239.44,240.24]
# Time interval n.0: [239.44, 239.64]
# Time interval n.1: [239.64, 239.84]
# Time interval n.2: [239.84, 240.04]
# Time interval n.3: [240.04, 240.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.30/110
# ----------------------------------------------------------------------------------------------------
# Scene n.30.
#     Initial mse: 17.54239818224042
#
# After optimizing, new params: v0 = 37.393473698444595, L = 2.0
#
# Initial mse: 0.9459649553864469
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [249.84,250.44]
# Time interval n.0: [249.84, 250.04]
# Time interval n.1: [250.04, 250.24]
# Time interval n.2: [250.24, 250.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.31/110
# ----------------------------------------------------------------------------------------------------
# Scene n.31.
#     Initial mse: 6.631637184597324
#
# After optimizing, new params: v0 = 35.83788996124426, L = 5.518803563336819
#
# Initial mse: 0.16442617015647748
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [251.44,252.24]
# Time interval n.0: [251.44, 251.64]
# Time interval n.1: [251.64, 251.84]
# Time interval n.2: [251.84, 252.04]
# Time interval n.3: [252.04, 252.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.32/110
# ----------------------------------------------------------------------------------------------------
# Scene n.32.
#     Initial mse: 46.67083872327658
#
# After optimizing, new params: v0 = 32.90336842329405, L = 2.0
# Initial mse: 3.1318505385733606
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 10 time intervals inside     [261.64,263.64]
# Time interval n.0: [261.64, 261.84]
# Time interval n.1: [261.84, 262.04]
# Time interval n.2: [262.04, 262.24]
# Time interval n.3: [262.24, 262.44]
# Time interval n.4: [262.44, 262.64]
# Time interval n.5: [262.64, 262.84]
# Time interval n.6: [262.84, 263.04]
# Time interval n.7: [263.04, 263.24]
# Time interval n.8: [263.24, 263.44]
# Time interval n.9: [263.44, 263.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.33/110
# ----------------------------------------------------------------------------------------------------
# Scene n.33.
#     Initial mse: 20.736053694831234
#
# After optimizing, new params: v0 = 38.18724340726684, L = 2.0
#
# Initial mse: 0.9537948294434111
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [271.04,271.64]
# Time interval n.0: [271.04, 271.24]
# Time interval n.1: [271.24, 271.44]
# Time interval n.2: [271.44, 271.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.34/110
# ----------------------------------------------------------------------------------------------------
# Scene n.34.
#     Initial mse: 9.415152251753966
#
# After optimizing, new params: v0 = 35.7302334662587, L = 3.252916184007797
#
# Initial mse: 0.291412453039885
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [272.24,273.04]
# Time interval n.0: [272.24, 272.44]
# Time interval n.1: [272.44, 272.64]
# Time interval n.2: [272.64, 272.84]
# Time interval n.3: [272.84, 273.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.35/110
# ----------------------------------------------------------------------------------------------------
# Scene n.35.
#     Initial mse: 28.673082523431166
#
# After optimizing, new params: v0 = 36.24403064055086, L = 2.0
#
# Initial mse: 4.220035122774406
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [291.64,292.64]
# Time interval n.0: [291.64, 291.84]
# Time interval n.1: [291.84, 292.04]
# Time interval n.2: [292.04, 292.24]
# Time interval n.3: [292.24, 292.44]
# Time interval n.4: [292.44, 292.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.36/110
# ----------------------------------------------------------------------------------------------------
# Scene n.36.
#     Initial mse: 1.5347082489738764
#
# After optimizing, new params: v0 = 32.48663094356551, L = 11.225672131623503
#
# Initial mse: 0.936655726007416
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [294.64,295.24]
# Time interval n.0: [294.64, 294.84]
# Time interval n.1: [294.84, 295.04]
# Time interval n.2: [295.04, 295.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.37/110
# ----------------------------------------------------------------------------------------------------
# Scene n.37.
#     Initial mse: 10.814916121077056
#
# After optimizing, new params: v0 = 31.965206681123302, L = 2.0
#
# Initial mse: 0.3953347217621449
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [296.44,297.24]
# Time interval n.0: [296.44, 296.64]
# Time interval n.1: [296.64, 296.84]
# Time interval n.2: [296.84, 297.04]
# Time interval n.3: [297.04, 297.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.38/110
# ----------------------------------------------------------------------------------------------------
# Scene n.38.
#     Initial mse: 6.923707777599996
#
# After optimizing, new params: v0 = 33.73178617510866, L = 3.1230953876936587
#
# Initial mse: 0.7178316088051198
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [298.04,298.84]
# Time interval n.0: [298.04, 298.24]
# Time interval n.1: [298.24, 298.44]
# Time interval n.2: [298.44, 298.64]
# Time interval n.3: [298.64, 298.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.39/110
# ----------------------------------------------------------------------------------------------------
# Scene n.39.
#     Initial mse: 15.809556391133441
#
# Optimization not succeed
#
# Initial mse: 15.809556391133441
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [301.44,302.44]
# Time interval n.0: [301.44, 301.64]
# Time interval n.1: [301.64, 301.84]
# Time interval n.2: [301.84, 302.04]
# Time interval n.3: [302.04, 302.24]
# Time interval n.4: [302.24, 302.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.40/110
# ----------------------------------------------------------------------------------------------------
# Scene n.40.
#     Initial mse: 2.6322981948852777
#
# After optimizing, new params: v0 = 30.47526193222766, L = 2.0
#
# Initial mse: 0.6722711474757608
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [307.24,307.64]
# Time interval n.0: [307.24, 307.44]
# Time interval n.1: [307.44, 307.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.41/110
# ----------------------------------------------------------------------------------------------------
# Scene n.41.
#     Initial mse: 6.655277202419956
#
# After optimizing, new params: v0 = 33.05545790131121, L = 2.0
#
# Initial mse: 2.542744215873029
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [310.84,311.24]
# Time interval n.0: [310.84, 311.04]
# Time interval n.1: [311.04, 311.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.42/110
# ----------------------------------------------------------------------------------------------------
# Scene n.42.
#     Initial mse: 12.551997766870603
#
# After optimizing, new params: v0 = 37.61467975654951, L = 2.250609076627537
#
# Initial mse: 0.16221765508411748
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [316.44,317.04]
# Time interval n.0: [316.44, 316.64]
# Time interval n.1: [316.64, 316.84]
# Time interval n.2: [316.84, 317.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ...
#     683     "        err_list.append(err)\n",
#     684     "\n",
#     685     "        if err < err_best:\n",
#     686     "            t_best, x_best, v_best = t_list, x_list, v_list\n",
#     687     "            it_best, err_best = it, err\n",
#     688     "        \n",
#     689     "        #update diff\n",
#     690     "        if it % 10 == 0:\n",
#     691     "             diff = abs(err_list[-1]-err_list[-10])\n",
#     692     "\n",
#     693     "        if it % PLOT_ITER == 0:\n",
#     694     "            print(f\"\\\n",
#     695     "            * err= {err}\\n\\\n",
#     696     "            * Learning rate NN = {optimizer.learning_rate.numpy()}\\n\\\n",
#     697     "            * diff = {diff}\")   \n",
#     698     "\n",
#     699     "            # plot function\n",
#     700     "            tscale = 1+(tstamps[-1]-tstamps[0])/10000\n",
#     701     "            title = f\"$df\\  n.\\ {scn['N. file']}\\ -\\ Scene\\ n.\\ {scn.name},\\ at\\ it={it}$\"\n",
#     702     "            plot_scn(scn, sol_ann_matched, title, xbal=0.01, ybal=0.05, scale=tscale)\n",
#     703     "            \n",
#     704     "#             print(\"==\"*50)\n",
#     705     "   \n",
#     706     "        #print(f\"it={it}, err={err}\")\n",
#     707     "        it += 1\n",
#     708     "\n",
#     709     "#     print(f\"it best = {it_best}, err = {err_best}\")\n",
#     710     "    \n",
#     711     "#     # plot function\n",
#     712     "#     _, sol_ann_matched = match_timestamps_scene(t_best, x_best)\n",
#     713     "#     tscale = 1+(tstamps[-1]-tstamps[0])/10000\n",
#     714     "#     title = f\"$Scene\\ n.\\ {scn.name},\\ at\\ it\\_best={it_best}$\"\n",
#     715     "#     plot_scn(scn, sol_ann_matched, title, xbal=0.01, ybal=0.05, scale=tscale)\n",
#     716     "#     print(\"==\"*50)\n",
#     717     "    \n",
#     718     "    return t_best, x_best, v_best, v0_scn, it"
#     719    ]
#     720   },
#     721   {
#     722    "cell_type": "markdown",
#     723    "id": "7e3e52f5",
#     724    "metadata": {},
#     725    "source": [
#     726     "### Solve the nn-driven model in the all the scenes in a df, and get v0 mean for each scene"
#     727    ]
#     728   },
#     729   {
#     730    "cell_type": "code",
#     731    "execution_count": null,
#     732    "id": "5245224a",
#     733    "metadata": {},
#     734    "outputs": [],
#     735    "source": [
#     736     "def lr_finder(model, scn, v0):\n",
#     737     "    \n",
#     738     "    \"\"\"\n",
#     739     "    lr_best = lr_finder(model)\n",
#     740     "    \"\"\"\n",
#     741     "\n",
#     742     "    X_arr, y_arr = create_data_ann_scene(scn)\n",
#     743     "    lr_range = [0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001]\n",
#     744     "    err_lr_best, lr_best = 1e9, None\n",
#     745     "\n",
#     746     "    for lr in lr_range:\n",
#     747     "\n",
#     748     "        mmodel = tf.keras.models.clone_model(model)\n",
#     749     "        optimizer = tf.keras.optimizers.SGD(learning_rate=lr)\n",
#     750     "        loss_fn = tf.keras.losses.MeanSquaredError()\n",
#     751     "\n",
#     752     "        for it in range(20):\n",
#     753     "            \n",
#     754     "            x_list, t_list, v_list = [[i] for i in scn['Xarr'][:,0]], [scn['Tarr'][0]], []\n",
#     755     "            t_list, x_list, v_list = solve_step(mmodel, scn, v0, -1, -2,\n",
#     756     "                                                lists = [t_list, x_list, v_list],\n",
#     757     "                                                nn_fun = [loss_fn, optimizer])\n",
#     758     "            _, sol_ann_matched = match_timestamps_scene(t_list, x_list)            \n",
#     759     "\n",
#     760     "        err = loss_fn(y_true=scn['Xarr'], y_pred = sol_ann_matched).numpy()  \n",
#     761     "\n",
#     762     "#         print(f\"For lr={lr} we have err={err}\")\n",
#     763     "        if err < err_lr_best:\n",
#     764     "            err_lr_best, lr_best, it_lr_best = err, lr, it\n",
#     765     "        \n",
#     766     "#         print(f\"--> err_best={err_lr_best}, lr_best={lr_best}\\n\")\n",
#     767     "\n",
#     768     "    return err_lr_best, lr_best, it_lr_best "
#     769    ]
#     770   },
#     771   {
#     772    "cell_type": "code",
#     773    "execution_count": null,
#     774    "id": "538d271f",
#     775    "metadata": {},
#     776    "outputs": [],
#     777    "source": [
#     778     "def SGD_v0(scn, x_list_matched, v0, LEARNING_RATE_v0):\n",
#     779     "    \n",
#     780     "    \"\"\"\n",
#     781     "    v0_upd, loss_val, grads, g = SGD_v0(scn, x_list_matched, v0, LEARNING_RATE_v0)\n",
#     782     "    \"\"\"\n",
#     783     "    \n",
#     784     "    loss_objective = tf.keras.losses.MeanSquaredError()\n",
#     785     "    \n",
#     786     "    with tf.GradientTape(persistent=True) as tape:\n",
#     787     "\n",
#     788     "        trajs_true_tensor = tf.convert_to_tensor(scn['Xarr'], dtype=tf.float64)\n",
#     789     "\n",
#     790     "        # Create tensor that you will watch\n",
#     791     "        trajs_pred_tensor = tf.convert_to_tensor(x_list_matched, dtype=tf.float64)\n",
#     792     "        tape.watch(trajs_pred_tensor)\n",
#     793     "\n",
#     794     "        loss_val = loss_objective(y_true = trajs_true_tensor, y_pred = trajs_pred_tensor)\n",
#     795     "\n",
#     796     "    # Compute gradients\n",
#     797     "    grads = tape.gradient(loss_val, trajs_pred_tensor)\n",
#     798     "\n",
#     799     "    # Update weights\n",
#     800     "    g = grads[-1].numpy()[1:].mean() # I'm watching at a mean velocity of the leader car..\n",
#     801     "    v0_upd = v0 - LEARNING_RATE_v0*g\n",
#     802     "    \n",
#     803     "    return v0_upd, loss_val, grads, g"
#     804    ]
#     805   },
#     806   {
#     807    "cell_type": "code",
#     808    "execution_count": null,
#     809    "id": "5d32dbce",
#     810    "metadata": {},
#     811    "outputs": [],
#     812    "source": [
#     813     "def solve_nn_df(df, model, v0, NUM_ITER, LEARNING_RATE_v0=0.5):\n",
#     814     "    \n",
#     815     "    \"\"\"\n",
#     816     "    Solve nn in a single df ang get info_df, which gives info about v0_scn_mean for each scene.\n",
#     817     "    \n",
#     818     "    info_df = solve_nn_df(df, model, v0_guess=30,\n",
#     819     "                          NUM_EPOCHS=10, LEARNING_RATE_NN=0.01, LEARNING_RATE_v0=0.5, flag_print=False)\n",
#     820     "    \"\"\"\n",
#     821     "    \n",
#     822     "    scn_list = seq2scn(df)\n",
#     823     "    info_scn, fmt = [], '{0:.02f}'\n",
#     824     "    loss_fn = tf.keras.losses.MeanSquaredError()\n",
#     825     "    \n",
#     826     "    for scn in scn_list:\n",
#     827     "                \n",
#     828     "        tstamps = scn['Tarr']\n",
#     829     "        err_lr_best, lr_best, it_lr_best = lr_finder(model, scn, v0)\n",
#     830     "       \n",
#     831     "        t_list, x_list, v_list, v0_scn, it = solve_nn_scn_custom(model, scn, v0,\n",
#     832     "                                                                    lr_best,\n",
#     833     "                                                                    LEARNING_RATE_v0,\n",
#     834     "                                                                    NUM_ITER, PLOT_ITER=NUM_ITER)\n",
#     835     "\n",
#     836     "        # Compute MAE for the solution computed\n",
#     837     "        _, sol_ann_matched = match_timestamps_scene(t_list, x_list)\n",
#     838     "        mae = loss_fn(y_true=scn['Xarr'], y_pred = sol_ann_matched).numpy()\n",
#     839     "        \n",
#     840     "        v0_scn_mean = np.array(v0_scn).mean()\n",
#     841     "\n",
#     842     "        info_scn.append([t_list, x_list, v_list, v0_scn, v0_scn_mean, scn.name, df['N. file'][0], it-1])\n",
#     843     "\n",
#     844     "        print(f\"\\\n",
#     845     "        For scene {scn.name}/{len(scn_list)}\\n\\\n",
#     846     "        * use LR_NN={lr_best} with err={err_lr_best} at it={it_lr_best}\\n\\\n",
#     847     "        * v0_scn_mean = {v0_scn_mean}\\n\\\n",
#     848     "        * MAE = {mae}\\n\")\n",
#     849     "        print(\"==\"*50)\n",
#     850     "        print(\"\\n\")\n",
#     851     "\n",
#     852     "    # to better handle, transposte info_df\n",
#     853     "    tmp = list(map(list, zip(*info_scn)))\n",
#     854     "\n",
#     855     "    info_df = pd.DataFrame({'t_list': tmp[0],\\\n",
#     856     "                            'x_list': tmp[1],\\\n",
#     857     "                            'v_list': tmp[2],\\\n",
#     858     "                            'v0_scn': tmp[3],\\\n",
#     859     "                            'v0_scn_mean': tmp[4],\\\n",
#     860     "                            'n_scn': tmp[5],\\\n",
#     861     "                            'N. file': tmp[6],\\\n",
#     862     "                            'iter': tmp[7]\n",
#     863     "                           })\n",
#     864     "  \n",
#     865     "    return info_df"
#     866    ]
#     867   },
#     868   {
#     869    "cell_type": "markdown",
#     870    "id": "2e1085ae",
#     871    "metadata": {},
#     872    "source": [
#     873     "### Solve NN driven model in each df of a dataset, and get v0 mean for each scn in each df"
#     874    ]
#     875   },
#     876   {
#     877    "cell_type": "code",
#     878    "execution_count": null,
#     879    "id": "ed2b6c6a",
#     880    "metadata": {},
#     881    "outputs": [],
#     882    "source": [
#     883     "def solve_nn_dataset(model, v0_guess, dataset, NUM_ITER=50, LEARNING_RATE_v0=0.5):\n",
#     884     "    \n",
#     885     "    \"\"\"\n",
#     886     "    v0_dflist = v0_dataset(model, v0_guess, dataset, NUM_EPOCHS, LEARNING_RATE_NN, LEARNING_RATE_v0, flag_print)\n",
#     887     "    \n",
#     888     "    For each df in dataset compute v0 for each scene in df. Return v0_dflist.\n",
#     889     "    \"\"\"\n",
#     890     "    \n",
#     891     "    start_time2 = time.time()\n",
#     892     "    tmp = []\n",
#     893     "    \n",
#     894     "    for step, df in enumerate(dataset):\n",
#     895     "        \n",
#     896     "        start_time1 = time.time()\n",
#     897     "\n",
#     898     "        print(\"==\"*30)\n",
#     899     "        \n",
#     900     "        print(\"**\"*50)\n",
#     901     "        print(f\"In df n.{df['N. file'][0]}/{len(dataset)} we have {len(df)} scenes\")\n",
#     902     "        print(\"**\"*50)\n",
#     903     "        \n",
#     904     "        info_df = solve_nn_df(df, model, v0_guess, NUM_ITER, LEARNING_RATE_v0)\n",
#     905     "\n",
#     906     "        tmp.append(info_df)\n",
#     907     "\n",
#     908     "        print(f\"For df={df['N. file'][0]} with {len(df)} scenes, time taken:\\\n",
#     909     "        {'{0:.02f}'.format(time.time() - start_time1)}\")\n",
#     910     "        print(\"==\"*30)\n",
#     911     "\n",
#     912     "        print(\"--\"*30)\n",
#     913     "\n",
#     914     "    time_taken=time.time() - start_time2\n",
#     915     "    print(f\"\\nTime taken for the computation: {'{0:.02f}'.format(time_taken)}\")\n",
#     916     "\n",
#     917     "    # To better handling info_dataset\n",
#     918     "    info_dataset = pd.concat(tmp, sort=False)\n",
#     919     "        \n",
#     920     "    return info_dataset"
#     921    ]
#     922   }
#     923  ],
#     924  "metadata": {
#     925   "kernelspec": {
#     926    "display_name": "Python 3 (ipykernel)",
#     927    "language": "python",
#     928    "name": "python3"
#     929   },
#     930   "language_info": {
#     931    "codemirror_mode": {
#     932     "name": "ipython",
#     933     "version": 3
#     934    },
#     935    "file_extension": ".py",
#     936    "mimetype": "text/x-python",
#     937    "name": "python",
#     938    "nbconvert_exporter": "python",
#     939    "pygments_lexer": "ipython3",
#     940    "version": "3.10.9"
#     941   }
#     942  },
#     943  "nbformat": 4,
#     944  "nbformat_minor": 5
#     945 }
#
# File ~/anaconda3/envs/tesi/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/anaconda3/envs/tesi/lib/python3.10/site-packages/sklearn/metrics/_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/anaconda3/envs/tesi/lib/python3.10/site-packages/sklearn/metrics/_regression.py:101, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      99 check_consistent_length(y_true, y_pred)
#     100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#     104     y_true = y_true.reshape((-1, 1))
#
# File ~/anaconda3/envs/tesi/lib/python3.10/site-packages/sklearn/utils/validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~/anaconda3/envs/tesi/lib/python3.10/site-packages/sklearn/utils/validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~/anaconda3/envs/tesi/lib/python3.10/site-packages/sklearn/utils/validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
# Pre
flag_processed = 'post'
_, dflist = load_dataset(dir_name, flag_processed)

# Compute
info_alldataset_post = solve_TD_LWR_dataset(dflist, TD_LWR_model, v0=30, L=5, deltat=0.05, tol=1e-8, pplot=False)
info_alldataset_post['processed'] = [flag_processed] * info_alldataset_post.shape[0]

# %%
info_alldataset

# %%
info_alldataset.groupby(['LWR_flag','N. file']).mean(numeric_only=True)

# %% [markdown]
# ## Prepare the out dir

# %%
# Create the directory..
if flag_save:
    
    ext = ".svg"
    
    df_seen = [df['N. file'][0] for df in dflist]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}-LINLOG-POST")
    
    path = 'out/' + d
    os.mkdir(path)
    
    # Save the solution in a file
    namefile = '/info_alldataset.txt'

    with open(path + namefile, 'w') as output:
        info_alldataset.to_csv(path + namefile, sep=',', index=False)

# %% [markdown]
# ## Plot

# %%
ms2kmh = 3.6

# Initialize the figure
width, height = 7, 5
fig, ax = plt.subplots(figsize=(width,height))

lin_color, log_color = 'gold', 'olive'

# For all df
for key, grp in info_alldataset.groupby(['LWR_flag','N. file']):
    tmp = grp.mean(numeric_only=True)
    nf = key[1]
    match key[0]:
        case 'Lin':
            ax.plot(nf, tmp['v0_scn']*ms2kmh, color = lin_color, marker="x")
        case 'Log':
            ax.plot(nf, tmp['v0_scn']*ms2kmh, color = log_color, marker="x")

# mean line
for key, grp in info_alldataset.groupby('LWR_flag'):
    tmp = grp.mean(numeric_only=True)
    
    xrange = [i for i in range(1,11)]
    yval = [tmp['v0_scn']*ms2kmh] * len(xrange) 
    match key:
        case 'Lin':
            ax.plot(xrange, yval, color = lin_color, label = key)
        case 'Log':
            ax.plot(xrange, yval, color = log_color,  label = key)

xlim = [0.75,10.25]
ax.set_xlim(xlim)
ax.set_xticks(range(1,11))
ylim = ax.get_ylim()

ax.set_xlabel(r"$data set$",fontsize=14)
ax.set_ylabel(r"$v_{0}\ [km/h]$",fontsize=14)
ax.set_title(fr"$Velocities\ v_{0}\ of\ the\ leading\ car$",fontsize=14)
ax.legend()

plt.show()

# %%
# Save figure
if flag_save:

    title = f"/v0_df{df_seen_str}_1"     
    fig.savefig(path+title+ext, bbox_inches='tight')
