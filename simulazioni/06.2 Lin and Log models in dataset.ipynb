# %%
## Libraries
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from datetime import datetime

# To enable LaTeX and select a font
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# Using ipynb import functions defined in other nb
sys.path.append("myfun/")
from ipynb.fs.defs.myfun_load_dataset import *
from ipynb.fs.defs.myfun_model_linlog import *
# Out:
# 2024-01-18 21:46:29.951276: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-18 21:46:29.951335: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-18 21:46:29.952406: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-18 21:46:29.958348: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-18 21:46:30.999571: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data Acquisition

# %%
# Load the dataset
par_dir = os.path.dirname(os.getcwd()) # parent dir
dir_name = par_dir + "/NN-interaction"
_, dflist = load_dataset(dir_name, 'pre')

# %% [markdown]
# ## Solve Lin/Log models in a df

# %%
flag_save = False

# %%
info_alldataset = solve_TD_LWR_dataset(dflist, TD_LWR_model, v0=30, L=5, deltat=0.05, tol=1e-8, pplot=True)
# Out:
# ====================================================================================================
# df n.1 - Scene n.0/109
# ----------------------------------------------------------------------------------------------------
# Scene n.0.
#     Optimizing parameters...
#     Initial mse: 1.8484278632480775
#
# After optimizing, new params: v0 = 32.52400440779791, L = 2.114480066289242
#
# mse: 0.08923681999214601
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [2.24,2.84]
# Time interval n.0: [2.24, 2.44]
# Time interval n.1: [2.44, 2.64]
# Time interval n.2: [2.64, 2.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.1/109
# ----------------------------------------------------------------------------------------------------
# Scene n.1.
#     Optimizing parameters...
#     Initial mse: 0.8851070099224433
#
# After optimizing, new params: v0 = 27.02637601556568, L = 2.0
#
# mse: 0.37815246620379805
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [16.44,16.84]
# Time interval n.0: [16.44, 16.64]
# Time interval n.1: [16.64, 16.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.2/109
# ----------------------------------------------------------------------------------------------------
# Scene n.2.
#     Optimizing parameters...
#     Initial mse: 6.410282913945186
#
# Optimization not succeed
#
# mse: 6.410282913945186
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [33.44,34.04]
# Time interval n.0: [33.44, 33.64]
# Time interval n.1: [33.64, 33.84]
# Time interval n.2: [33.84, 34.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.3/109
# ----------------------------------------------------------------------------------------------------
# Scene n.3.
#     Optimizing parameters...
#     Initial mse: 4.540249157509551
#
# After optimizing, new params: v0 = 29.109447823737298, L = 2.0
#
# mse: 1.2403403910365984
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [37.44,38.24]
# Time interval n.0: [37.44, 37.64]
# Time interval n.1: [37.64, 37.84]
# Time interval n.2: [37.84, 38.04]
# Time interval n.3: [38.04, 38.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.4/109
# ----------------------------------------------------------------------------------------------------
# Scene n.4.
#     Optimizing parameters...
#     Initial mse: 0.46771931455901206
#
# After optimizing, new params: v0 = 29.381091902483103, L = 2.477765008828755
#
# mse: 0.09748761209364668
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [44.24,44.84]
# Time interval n.0: [44.24, 44.44]
# Time interval n.1: [44.44, 44.64]
# Time interval n.2: [44.64, 44.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.5/109
# ----------------------------------------------------------------------------------------------------
# Scene n.5.
#     Optimizing parameters...
#     Initial mse: 49.71483725078565
#
# After optimizing, new params: v0 = 37.536470697145965, L = 2.0
#
# mse: 2.2099818119811845
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [52.84,53.84]
# Time interval n.0: [52.84, 53.04]
# Time interval n.1: [53.04, 53.24]
# Time interval n.2: [53.24, 53.44]
# Time interval n.3: [53.44, 53.64]
# Time interval n.4: [53.64, 53.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.6/109
# ----------------------------------------------------------------------------------------------------
# Scene n.6.
#     Optimizing parameters...
#     Initial mse: 7.9902177142039434
#
# After optimizing, new params: v0 = 35.206408938583806, L = 2.0
#
# mse: 1.6983931537277375
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [54.84,55.24]
# Time interval n.0: [54.84, 55.04]
# Time interval n.1: [55.04, 55.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.7/109
# ----------------------------------------------------------------------------------------------------
# Scene n.7.
#     Optimizing parameters...
#     Initial mse: 6.303283638283937
#
# After optimizing, new params: v0 = 35.77310724351254, L = 5.204236840393343
#
# mse: 0.20485227501894707
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [56.84,57.64]
# Time interval n.0: [56.84, 57.04]
# Time interval n.1: [57.04, 57.24]
# Time interval n.2: [57.24, 57.44]
# Time interval n.3: [57.44, 57.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.8/109
# ----------------------------------------------------------------------------------------------------
# Scene n.8.
#     Optimizing parameters...
#     Initial mse: 10.352987744344647
#
# After optimizing, new params: v0 = 30.838193667034858, L = 2.0
#
# mse: 3.9253064213455766
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [60.04,60.84]
# Time interval n.0: [60.04, 60.24]
# Time interval n.1: [60.24, 60.44]
# Time interval n.2: [60.44, 60.64]
# Time interval n.3: [60.64, 60.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.9/109
# ----------------------------------------------------------------------------------------------------
# Scene n.9.
#     Optimizing parameters...
#     Initial mse: 40.34098200245325
#
# After optimizing, new params: v0 = 33.225824240451374, L = 2.0
#
# mse: 9.494867811863477
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [80.64,81.64]
# Time interval n.0: [80.64, 80.84]
# Time interval n.1: [80.84, 81.04]
# Time interval n.2: [81.04, 81.24]
# Time interval n.3: [81.24, 81.44]
# Time interval n.4: [81.44, 81.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.10/109
# ----------------------------------------------------------------------------------------------------
# Scene n.10.
#     Optimizing parameters...
#     Initial mse: 1.2514452360389705
#
# After optimizing, new params: v0 = 31.870900673893235, L = 2.0
# mse: 0.0781014810317048
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [87.84,88.44]
# Time interval n.0: [87.84, 88.04]
# Time interval n.1: [88.04, 88.24]
# Time interval n.2: [88.24, 88.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.11/109
# ----------------------------------------------------------------------------------------------------
# Scene n.11.
#     Optimizing parameters...
#     Initial mse: 48.46848947067742
#
# After optimizing, new params: v0 = 36.097254101326364, L = 2.0
#
# mse: 4.353355823701282
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [89.04,90.04]
# Time interval n.0: [89.04, 89.24]
# Time interval n.1: [89.24, 89.44]
# Time interval n.2: [89.44, 89.64]
# Time interval n.3: [89.64, 89.84]
# Time interval n.4: [89.84, 90.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.12/109
# ----------------------------------------------------------------------------------------------------
# Scene n.12.
#     Optimizing parameters...
#     Initial mse: 11.931848477288082
#
# After optimizing, new params: v0 = 38.866333237338175, L = 3.71213827058902
#
# mse: 0.737435674637835
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [90.84,91.44]
# Time interval n.0: [90.84, 91.04]
# Time interval n.1: [91.04, 91.24]
# Time interval n.2: [91.24, 91.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.13/109
# ----------------------------------------------------------------------------------------------------
# Scene n.13.
#     Optimizing parameters...
#     Initial mse: 7.633544570370187
#
# After optimizing, new params: v0 = 35.83665706338813, L = 3.0140800294955676
#
# mse: 0.459417581377555
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [109.24,109.84]
# Time interval n.0: [109.24, 109.44]
# Time interval n.1: [109.44, 109.64]
# Time interval n.2: [109.64, 109.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.14/109
# ----------------------------------------------------------------------------------------------------
# Scene n.14.
#     Optimizing parameters...
#     Initial mse: 14.37354270668447
#
# After optimizing, new params: v0 = 35.85019782721561, L = 4.169665070117759
#
# mse: 1.7957907740021606
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [116.04,117.04]
# Time interval n.0: [116.04, 116.24]
# Time interval n.1: [116.24, 116.44]
# Time interval n.2: [116.44, 116.64]
# Time interval n.3: [116.64, 116.84]
# Time interval n.4: [116.84, 117.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.15/109
# ----------------------------------------------------------------------------------------------------
# Scene n.15.
#     Optimizing parameters...
#     Initial mse: 6.293309451924774
#
# After optimizing, new params: v0 = 33.63142750895717, L = 2.0
#
# mse: 0.16130196309125328
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [120.84,121.44]
# Time interval n.0: [120.84, 121.04]
# Time interval n.1: [121.04, 121.24]
# Time interval n.2: [121.24, 121.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.16/109
# ----------------------------------------------------------------------------------------------------
# Scene n.16.
#     Optimizing parameters...
#     Initial mse: 4.530405680300599
#
# After optimizing, new params: v0 = 32.42468355027913, L = 2.933533611724878
#
# mse: 1.1342047863341538
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [130.64,131.44]
# Time interval n.0: [130.64, 130.84]
# Time interval n.1: [130.84, 131.04]
# Time interval n.2: [131.04, 131.24]
# Time interval n.3: [131.24, 131.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.17/109
# ----------------------------------------------------------------------------------------------------
# Scene n.17.
#     Optimizing parameters...
#     Initial mse: 2.120356986057722
#
# After optimizing, new params: v0 = 35.07766450237389, L = 7.1679858602313065
#
# mse: 0.07753248573861385
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [140.64,141.24]
# Time interval n.0: [140.64, 140.84]
# Time interval n.1: [140.84, 141.04]
# Time interval n.2: [141.04, 141.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.18/109
# ----------------------------------------------------------------------------------------------------
# Scene n.18.
#     Optimizing parameters...
#     Initial mse: 1.617524487960676
#
# After optimizing, new params: v0 = 31.34185038674486, L = 2.0
#
# mse: 0.44764679390453505
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [142.04,142.44]
# Time interval n.0: [142.04, 142.24]
# Time interval n.1: [142.24, 142.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.19/109
# ----------------------------------------------------------------------------------------------------
# Scene n.19.
#     Optimizing parameters...
#     Initial mse: 1.961085932513847
#
# After optimizing, new params: v0 = 27.75612534621232, L = 2.0
#
# mse: 0.6949743688830705
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [146.24,146.64]
# Time interval n.0: [146.24, 146.44]
# Time interval n.1: [146.44, 146.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.20/109
# ----------------------------------------------------------------------------------------------------
# Scene n.20.
#     Optimizing parameters...
#     Initial mse: 0.1557644384912437
#
# After optimizing, new params: v0 = 29.44817239498593, L = 4.637822223789947
#
# mse: 0.10897494860388439
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [159.84,160.64]
# Time interval n.0: [159.84, 160.04]
# Time interval n.1: [160.04, 160.24]
# Time interval n.2: [160.24, 160.44]
# Time interval n.3: [160.44, 160.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.21/109
# ----------------------------------------------------------------------------------------------------
# Scene n.21.
#     Optimizing parameters...
#     Initial mse: 9.997519383641109
#
# After optimizing, new params: v0 = 39.638773293490445, L = 2.0
#
# mse: 0.5153182154847543
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [193.24,193.64]
# Time interval n.0: [193.24, 193.44]
# Time interval n.1: [193.44, 193.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.22/109
# ----------------------------------------------------------------------------------------------------
# Scene n.22.
#     Optimizing parameters...
#     Initial mse: 28.84899614329661
#
# After optimizing, new params: v0 = 39.506361004913096, L = 2.0
#
# mse: 2.3399430259088785
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [194.84,195.44]
# Time interval n.0: [194.84, 195.04]
# Time interval n.1: [195.04, 195.24]
# Time interval n.2: [195.24, 195.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.23/109
# ----------------------------------------------------------------------------------------------------
# Scene n.23.
#     Optimizing parameters...
#     Initial mse: 9.293247625291958
# After optimizing, new params: v0 = 30.146187141918723, L = 2.0
#
# mse: 4.6824739429273725
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [199.44,199.84]
# Time interval n.0: [199.44, 199.64]
# Time interval n.1: [199.64, 199.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.24/109
# ----------------------------------------------------------------------------------------------------
# Scene n.24.
#     Optimizing parameters...
#     Initial mse: 9.573079978496448
#
# After optimizing, new params: v0 = 33.14761347093611, L = 2.0
#
# mse: 1.213830379416546
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [200.44,201.24]
# Time interval n.0: [200.44, 200.64]
# Time interval n.1: [200.64, 200.84]
# Time interval n.2: [200.84, 201.04]
# Time interval n.3: [201.04, 201.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.25/109
# ----------------------------------------------------------------------------------------------------
# Scene n.25.
#     Optimizing parameters...
#     Initial mse: 0.9963161348808423
#
# After optimizing, new params: v0 = 31.743776872240197, L = 3.2439411180914974
#
# mse: 0.09295500559222786
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [209.64,210.24]
# Time interval n.0: [209.64, 209.84]
# Time interval n.1: [209.84, 210.04]
# Time interval n.2: [210.04, 210.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.26/109
# ----------------------------------------------------------------------------------------------------
# Scene n.26.
#     Optimizing parameters...
#     Initial mse: 23.344049172542505
#
# After optimizing, new params: v0 = 36.93413512635473, L = 2.0
#
# mse: 4.115417045039656
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [219.64,220.24]
# Time interval n.0: [219.64, 219.84]
# Time interval n.1: [219.84, 220.04]
# Time interval n.2: [220.04, 220.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.27/109
# ----------------------------------------------------------------------------------------------------
# Scene n.27.
#     Optimizing parameters...
#     Initial mse: 4.673561373883178
#
# After optimizing, new params: v0 = 33.99359605164736, L = 2.0
#
# mse: 0.3026610708176851
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [230.04,230.64]
# Time interval n.0: [230.04, 230.24]
# Time interval n.1: [230.24, 230.44]
# Time interval n.2: [230.44, 230.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.28/109
# ----------------------------------------------------------------------------------------------------
# Scene n.28.
#     Optimizing parameters...
#     Initial mse: 19.28607992325156
#
# After optimizing, new params: v0 = 31.899554990209708, L = 2.0
#
# mse: 9.653255699267055
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [239.44,240.24]
# Time interval n.0: [239.44, 239.64]
# Time interval n.1: [239.64, 239.84]
# Time interval n.2: [239.84, 240.04]
# Time interval n.3: [240.04, 240.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.29/109
# ----------------------------------------------------------------------------------------------------
# Scene n.29.
#     Optimizing parameters...
#     Initial mse: 17.54239818224042
#
# After optimizing, new params: v0 = 37.393473698444595, L = 2.0
#
# mse: 0.9459649553864469
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [249.84,250.44]
# Time interval n.0: [249.84, 250.04]
# Time interval n.1: [250.04, 250.24]
# Time interval n.2: [250.24, 250.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.30/109
# ----------------------------------------------------------------------------------------------------
# Scene n.30.
#     Optimizing parameters...
#     Initial mse: 6.631637184597324
#
# After optimizing, new params: v0 = 35.83788996124426, L = 5.518803563336819
#
# mse: 0.16442617015647748
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [251.44,252.24]
# Time interval n.0: [251.44, 251.64]
# Time interval n.1: [251.64, 251.84]
# Time interval n.2: [251.84, 252.04]
# Time interval n.3: [252.04, 252.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.31/109
# ----------------------------------------------------------------------------------------------------
# Scene n.31.
#     Optimizing parameters...
#     Initial mse: 46.67083872327658
#
# After optimizing, new params: v0 = 32.90336842329405, L = 2.0
#
# mse: 3.1318505385733606
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 10 time intervals inside     [261.64,263.64]
# Time interval n.0: [261.64, 261.84]
# Time interval n.1: [261.84, 262.04]
# Time interval n.2: [262.04, 262.24]
# Time interval n.3: [262.24, 262.44]
# Time interval n.4: [262.44, 262.64]
# Time interval n.5: [262.64, 262.84]
# Time interval n.6: [262.84, 263.04]
# Time interval n.7: [263.04, 263.24]
# Time interval n.8: [263.24, 263.44]
# Time interval n.9: [263.44, 263.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.32/109
# ----------------------------------------------------------------------------------------------------
# Scene n.32.
#     Optimizing parameters...
#     Initial mse: 20.736053694831234
#
# After optimizing, new params: v0 = 38.18724340726684, L = 2.0
#
# mse: 0.9537948294434111
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [271.04,271.64]
# Time interval n.0: [271.04, 271.24]
# Time interval n.1: [271.24, 271.44]
# Time interval n.2: [271.44, 271.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.33/109
# ----------------------------------------------------------------------------------------------------
# Scene n.33.
#     Optimizing parameters...
#     Initial mse: 9.415152251753966
#
# After optimizing, new params: v0 = 35.730161437297504, L = 3.252955744802207
#
# mse: 0.29141245330602206
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [272.24,273.04]
# Time interval n.0: [272.24, 272.44]
# Time interval n.1: [272.44, 272.64]
# Time interval n.2: [272.64, 272.84]
# Time interval n.3: [272.84, 273.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.34/109
# ----------------------------------------------------------------------------------------------------
# Scene n.34.
#     Optimizing parameters...
#     Initial mse: 28.673082523431166
#
# After optimizing, new params: v0 = 36.24403064055086, L = 2.0
#
# mse: 4.220035122774406
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [291.64,292.64]
# Time interval n.0: [291.64, 291.84]
# Time interval n.1: [291.84, 292.04]
# Time interval n.2: [292.04, 292.24]
# Time interval n.3: [292.24, 292.44]
# Time interval n.4: [292.44, 292.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.35/109
# ----------------------------------------------------------------------------------------------------
# Scene n.35.
#     Optimizing parameters...
#     Initial mse: 1.5347082489738764
# After optimizing, new params: v0 = 32.48663094356551, L = 11.225672131623503
#
# mse: 0.936655726007416
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [294.64,295.24]
# Time interval n.0: [294.64, 294.84]
# Time interval n.1: [294.84, 295.04]
# Time interval n.2: [295.04, 295.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.36/109
# ----------------------------------------------------------------------------------------------------
# Scene n.36.
#     Optimizing parameters...
#     Initial mse: 10.814916121077056
#
# After optimizing, new params: v0 = 31.965206681123302, L = 2.0
#
# mse: 0.3953347217621449
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [296.44,297.24]
# Time interval n.0: [296.44, 296.64]
# Time interval n.1: [296.64, 296.84]
# Time interval n.2: [296.84, 297.04]
# Time interval n.3: [297.04, 297.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.37/109
# ----------------------------------------------------------------------------------------------------
# Scene n.37.
#     Optimizing parameters...
#     Initial mse: 6.923707777599996
#
# After optimizing, new params: v0 = 33.73178617510866, L = 3.1230953876936587
#
# mse: 0.7178316088051198
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [298.04,298.84]
# Time interval n.0: [298.04, 298.24]
# Time interval n.1: [298.24, 298.44]
# Time interval n.2: [298.44, 298.64]
# Time interval n.3: [298.64, 298.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.38/109
# ----------------------------------------------------------------------------------------------------
# Scene n.38.
#     Optimizing parameters...
#     Initial mse: 15.809556391133441
#
# Optimization not succeed
#
# mse: 15.809556391133441
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 5 time intervals inside     [301.44,302.44]
# Time interval n.0: [301.44, 301.64]
# Time interval n.1: [301.64, 301.84]
# Time interval n.2: [301.84, 302.04]
# Time interval n.3: [302.04, 302.24]
# Time interval n.4: [302.24, 302.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.39/109
# ----------------------------------------------------------------------------------------------------
# Scene n.39.
#     Optimizing parameters...
#     Initial mse: 2.6322981948852777
#
# After optimizing, new params: v0 = 30.47526193222766, L = 2.0
#
# mse: 0.6722711474757608
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [307.24,307.64]
# Time interval n.0: [307.24, 307.44]
# Time interval n.1: [307.44, 307.64]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.40/109
# ----------------------------------------------------------------------------------------------------
# Scene n.40.
#     Optimizing parameters...
#     Initial mse: 6.655277202419956
#
# After optimizing, new params: v0 = 33.05545790131121, L = 2.0
#
# mse: 2.542744215873029
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [310.84,311.24]
# Time interval n.0: [310.84, 311.04]
# Time interval n.1: [311.04, 311.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.41/109
# ----------------------------------------------------------------------------------------------------
# Scene n.41.
#     Optimizing parameters...
#     Initial mse: 12.551997766870603
#
# After optimizing, new params: v0 = 37.61467975654951, L = 2.250609076627537
#
# mse: 0.16221765508411748
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [316.44,317.04]
# Time interval n.0: [316.44, 316.64]
# Time interval n.1: [316.64, 316.84]
# Time interval n.2: [316.84, 317.04]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.42/109
# ----------------------------------------------------------------------------------------------------
# Scene n.42.
#     Optimizing parameters...
#     Initial mse: 55.059349752266336
#
# After optimizing, new params: v0 = 35.50882996025917, L = 2.0
#
# mse: 4.3755128115152315
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [317.64,318.84]
# Time interval n.0: [317.64, 317.84]
# Time interval n.1: [317.84, 318.04]
# Time interval n.2: [318.04, 318.24]
# Time interval n.3: [318.24, 318.44]
# Time interval n.4: [318.44, 318.64]
# Time interval n.5: [318.64, 318.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.43/109
# ----------------------------------------------------------------------------------------------------
# Scene n.43.
#     Optimizing parameters...
#     Initial mse: 9.257029645085808
#
# After optimizing, new params: v0 = 33.27055457019136, L = 2.0
#
# mse: 2.4284351277207987
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [320.44,321.24]
# Time interval n.0: [320.44, 320.64]
# Time interval n.1: [320.64, 320.84]
# Time interval n.2: [320.84, 321.04]
# Time interval n.3: [321.04, 321.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.44/109
# ----------------------------------------------------------------------------------------------------
# Scene n.44.
#     Optimizing parameters...
#     Initial mse: 43.10078480617605
#
# After optimizing, new params: v0 = 31.10977489160754, L = 2.0
#
# mse: 5.680033880832106
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 10 time intervals inside     [324.44,326.44]
# Time interval n.0: [324.44, 324.64]
# Time interval n.1: [324.64, 324.84]
# Time interval n.2: [324.84, 325.04]
# Time interval n.3: [325.04, 325.24]
# Time interval n.4: [325.24, 325.44]
# Time interval n.5: [325.44, 325.64]
# Time interval n.6: [325.64, 325.84]
# Time interval n.7: [325.84, 326.04]
# Time interval n.8: [326.04, 326.24]
# Time interval n.9: [326.24, 326.44]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.45/109
# ----------------------------------------------------------------------------------------------------
# Scene n.45.
#     Optimizing parameters...
#     Initial mse: 66.94651651469147
# After optimizing, new params: v0 = 30.937404387287877, L = 2.0
#
# mse: 21.412486304108995
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 8 time intervals inside     [332.24,333.84]
# Time interval n.0: [332.24, 332.44]
# Time interval n.1: [332.44, 332.64]
# Time interval n.2: [332.64, 332.84]
# Time interval n.3: [332.84, 333.04]
# Time interval n.4: [333.04, 333.24]
# Time interval n.5: [333.24, 333.44]
# Time interval n.6: [333.44, 333.64]
# Time interval n.7: [333.64, 333.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.46/109
# ----------------------------------------------------------------------------------------------------
# Scene n.46.
#     Optimizing parameters...
#     Initial mse: 5.17400088172339
#
# After optimizing, new params: v0 = 31.957264410925614, L = 2.0
#
# mse: 0.9573610522774012
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [335.24,335.84]
# Time interval n.0: [335.24, 335.44]
# Time interval n.1: [335.44, 335.64]
# Time interval n.2: [335.64, 335.84]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.47/109
# ----------------------------------------------------------------------------------------------------
# Scene n.47.
#     Optimizing parameters...
#     Initial mse: 9.859221584411433
#
# After optimizing, new params: v0 = 34.66015234833001, L = 2.9975750405235653
#
# mse: 0.8758448268700931
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [344.44,345.24]
# Time interval n.0: [344.44, 344.64]
# Time interval n.1: [344.64, 344.84]
# Time interval n.2: [344.84, 345.04]
# Time interval n.3: [345.04, 345.24]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.1 - Scene n.48/109
# ----------------------------------------------------------------------------------------------------
# Scene n.48.
#     Optimizing parameters...
#     Initial mse: 6.724578679060274
#
# After optimizing, new params: v0 = 32.53297287083639, L = 2.0
#
# mse: 0.9598306436370189
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [349.64,350.44]
# Time interval n.0: [349.64, 349.84]
# Time interval n.1: [349.84, 350.04]
# Time interval n.2: [350.04, 350.24]
# ...
# Time interval n.2: [201.92, 202.12]
# Time interval n.3: [202.12, 202.32]
# Time interval n.4: [202.32, 202.52]
# Time interval n.5: [202.52, 202.72]
# Time interval n.6: [202.72, 202.92]
# Time interval n.7: [202.92, 203.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.58/74
# ----------------------------------------------------------------------------------------------------
# Scene n.58.
#     Optimizing parameters...
#     Initial mse: 18.26977797303874
#
# After optimizing, new params: v0 = 23.18192723308052, L = 7.939666868233707
#
# mse: 0.9779712875183203
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [210.12,210.52]
# Time interval n.0: [210.12, 210.32]
# Time interval n.1: [210.32, 210.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.59/74
# ----------------------------------------------------------------------------------------------------
# Scene n.59.
#     Optimizing parameters...
#     Initial mse: 10.356157504680972
#
# After optimizing, new params: v0 = 25.47181671984447, L = 5.7184989398649675
#
# mse: 5.3240492485998985
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [236.52,237.12]
# Time interval n.0: [236.52, 236.72]
# Time interval n.1: [236.72, 236.92]
# Time interval n.2: [236.92, 237.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.60/74
# ----------------------------------------------------------------------------------------------------
# Scene n.60.
#     Optimizing parameters...
#     Initial mse: 2.0516803070239136
#
# After optimizing, new params: v0 = 24.258256191327117, L = 3.3707379680494083
#
# mse: 0.6661577174434643
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [237.72,238.12]
# Time interval n.0: [237.72, 237.92]
# Time interval n.1: [237.92, 238.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.61/74
# ----------------------------------------------------------------------------------------------------
# Scene n.61.
#     Optimizing parameters...
#     Initial mse: 244.88069214354906
#
# After optimizing, new params: v0 = 6.032483503124516, L = 2.0
#
# mse: 2.4898201498290358
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [317.32,318.52]
# Time interval n.0: [317.32, 317.52]
# Time interval n.1: [317.52, 317.72]
# Time interval n.2: [317.72, 317.92]
# Time interval n.3: [317.92, 318.12]
# Time interval n.4: [318.12, 318.32]
# Time interval n.5: [318.32, 318.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.62/74
# ----------------------------------------------------------------------------------------------------
# Scene n.62.
#     Optimizing parameters...
#     Initial mse: 45.19838879712788
#
# After optimizing, new params: v0 = 24.568619109670742, L = 8.490162858750324
# mse: 1.604974760814524
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [321.12,321.92]
# Time interval n.0: [321.12, 321.32]
# Time interval n.1: [321.32, 321.52]
# Time interval n.2: [321.52, 321.72]
# Time interval n.3: [321.72, 321.92]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.63/74
# ----------------------------------------------------------------------------------------------------
# Scene n.63.
#     Optimizing parameters...
#     Initial mse: 168.46977533303397
#
# After optimizing, new params: v0 = 13.966790335742116, L = 9.69350149531198
#
# mse: 0.25427932848979745
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 4 time intervals inside     [323.12,323.92]
# Time interval n.0: [323.12, 323.32]
# Time interval n.1: [323.32, 323.52]
# Time interval n.2: [323.52, 323.72]
# Time interval n.3: [323.72, 323.92]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.64/74
# ----------------------------------------------------------------------------------------------------
# Scene n.64.
#     Optimizing parameters...
#     Initial mse: 41.65899868781642
#
# After optimizing, new params: v0 = 17.928592538139636, L = 7.20822823020009
#
# mse: 2.5451536118349725
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [337.72,338.32]
# Time interval n.0: [337.72, 337.92]
# Time interval n.1: [337.92, 338.12]
# Time interval n.2: [338.12, 338.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.65/74
# ----------------------------------------------------------------------------------------------------
# Scene n.65.
#     Optimizing parameters...
#     Initial mse: 6.821548351907007
#
# After optimizing, new params: v0 = 20.38682001028099, L = 4.211674175100402
#
# mse: 0.3210351640605309
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [369.32,369.92]
# Time interval n.0: [369.32, 369.52]
# Time interval n.1: [369.52, 369.72]
# Time interval n.2: [369.72, 369.92]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.66/74
# ----------------------------------------------------------------------------------------------------
# Scene n.66.
#     Optimizing parameters...
#     Initial mse: 146.4006707576339
#
# After optimizing, new params: v0 = 20.763377256471518, L = 9.548757379661842
#
# mse: 23.28639588634821
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 6 time intervals inside     [370.92,372.12]
# Time interval n.0: [370.92, 371.12]
# Time interval n.1: [371.12, 371.32]
# Time interval n.2: [371.32, 371.52]
# Time interval n.3: [371.52, 371.72]
# Time interval n.4: [371.72, 371.92]
# Time interval n.5: [371.92, 372.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.67/74
# ----------------------------------------------------------------------------------------------------
# Scene n.67.
#     Optimizing parameters...
#     Initial mse: 75.95812699378176
#
# After optimizing, new params: v0 = 9.257987382969224, L = 5.033476166486411
#
# mse: 4.974237702375393
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [376.92,377.52]
# Time interval n.0: [376.92, 377.12]
# Time interval n.1: [377.12, 377.32]
# Time interval n.2: [377.32, 377.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.68/74
# ----------------------------------------------------------------------------------------------------
# Scene n.68.
#     Optimizing parameters...
#     Initial mse: 15.442135835757227
#
# After optimizing, new params: v0 = 21.973083118478897, L = 5.642554429105938
#
# mse: 2.134055174567237
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [433.52,434.12]
# Time interval n.0: [433.52, 433.72]
# Time interval n.1: [433.72, 433.92]
# Time interval n.2: [433.92, 434.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.69/74
# ----------------------------------------------------------------------------------------------------
# Scene n.69.
#     Optimizing parameters...
#     Initial mse: 10.139662390419195
#
# After optimizing, new params: v0 = 20.56286430419721, L = 6.1520825096478795
#
# mse: 2.9835945058596445
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [483.92,484.32]
# Time interval n.0: [483.92, 484.12]
# Time interval n.1: [484.12, 484.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.70/74
# ----------------------------------------------------------------------------------------------------
# Scene n.70.
#     Optimizing parameters...
#     Initial mse: 42.3012885383888
#
# After optimizing, new params: v0 = 16.684510877586114, L = 7.865349910037533
#
# mse: 5.0022766768423494
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [531.72,532.32]
# Time interval n.0: [531.72, 531.92]
# Time interval n.1: [531.92, 532.12]
# Time interval n.2: [532.12, 532.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.71/74
# ----------------------------------------------------------------------------------------------------
# Scene n.71.
#     Optimizing parameters...
#     Initial mse: 15.733763987435255
#
# After optimizing, new params: v0 = 16.839221798957855, L = 2.052634105849496
#
# mse: 7.514003863347618
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 3 time intervals inside     [202.52,203.12]
# Time interval n.0: [202.52, 202.72]
# Time interval n.1: [202.72, 202.92]
# Time interval n.2: [202.92, 203.12]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.72/74
# ----------------------------------------------------------------------------------------------------
# Scene n.72.
#     Optimizing parameters...
#     Initial mse: 16.802571166470077
# After optimizing, new params: v0 = 9.26979690580215, L = 2.0
#
# mse: 3.9688695440688044
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [342.92,343.32]
# Time interval n.0: [342.92, 343.12]
# Time interval n.1: [343.12, 343.32]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# ====================================================================================================
# df n.10 - Scene n.73/74
# ----------------------------------------------------------------------------------------------------
# Scene n.73.
#     Optimizing parameters...
#     Initial mse: 24.035641589682346
#
# After optimizing, new params: v0 = 10.227469808552783, L = 2.7775467522912285
#
# mse: 2.649504881985356
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# We have 2 time intervals inside     [441.12,441.52]
# Time interval n.0: [441.12, 441.32]
# Time interval n.1: [441.32, 441.52]
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================

# %%
info_alldataset.groupby(['LWR_flag','N. file']).mean(numeric_only=True).T
# Out:
# LWR_flag        Lin                                                         \
# N. file          1          2          3          4          5          6
# v0_scn    30.879678  22.995422  31.422500  24.517194  29.137418  23.633085
# L_scn      2.803242   4.578451   3.686626   4.328019   2.871606   4.250591
# n_scn     54.000000  34.000000  44.500000  34.000000  32.500000  25.500000
#
# LWR_flag                                                    Log             \
# N. file          7          8          9          10         1          2
# v0_scn    28.900355  23.864296  26.292151  22.213881  28.090171  21.088288
# L_scn      3.920488   6.100698   3.422784   4.450371   7.721689   7.913829
# n_scn     14.500000  39.000000  16.000000  36.500000  54.000000  34.000000
#
# LWR_flag                                                                    \
# N. file          3          4          5          6          7          8
# v0_scn    27.848009  22.280553  27.153626  22.066125  26.451247  21.910546
# L_scn      8.869658   8.854229   7.595487   7.229299   7.724031   9.384782
# n_scn     44.500000  34.000000  32.500000  25.500000  14.500000  39.000000
#
# LWR_flag
# N. file          9          10
# v0_scn    24.500039  20.840591
# L_scn      7.492782   7.206939
# n_scn     16.000000  36.500000

# %% [markdown]
# ## Prepare the out dir

# %%
# Create the directory..
if flag_save:
    
    ext = ".svg"
    
    df_seen = [df['N. file'][0] for df in dflist]
    df_seen_str = '-'.join(str(x) for x in df_seen)
    
    # Create directory where to save the image
    now = datetime.now() 
    d = now.strftime(f"%Y-%m-%d_%H-%M-%S_df{df_seen_str}-PRE-LINLOG")
    
    path = 'out/' + d
    os.mkdir(path)
    
    # Save the solution in a file
    namefile = '/info_alldataset.txt'

    with open(path + namefile, 'w') as output:
        info_alldataset.to_csv(path + namefile, sep=',', index=False)

# %% [markdown]
# ## Plot

# %%
ms2kmh = 3.6

# Initialize the figure
width, height = 7, 5
fig, ax = plt.subplots(figsize=(width,height))

lin_color, log_color = 'gold', 'olive'

# For all df
for key, grp in info_alldataset.groupby(['LWR_flag','N. file']):
    tmp = grp.mean(numeric_only=True)
    nf = key[1]
    match key[0]:
        case 'Lin':
            ax.plot(nf, tmp['v0_scn']*ms2kmh, color = lin_color, marker="x")
        case 'Log':
            ax.plot(nf, tmp['v0_scn']*ms2kmh, color = log_color, marker="x")

# mean line
for key, grp in info_alldataset.groupby('LWR_flag'):
    tmp = grp.mean(numeric_only=True)
    
    xrange = [i for i in range(1,11)]
    yval = [tmp['v0_scn']*ms2kmh] * len(xrange) 
    match key:
        case 'Lin':
            ax.plot(xrange, yval, color = lin_color, label = key)
        case 'Log':
            ax.plot(xrange, yval, color = log_color,  label = key)

xlim = [0.75,10.25]
ax.set_xlim(xlim)
ax.set_xticks(range(1,11))
ylim = ax.get_ylim()

ax.set_xlabel(r"$data set$",fontsize=14)
ax.set_ylabel(r"$v_{0}\ [km/h]$",fontsize=14)
ax.set_title(fr"$Velocities\ v_{0}\ of\ the\ leading\ car$",fontsize=14)
ax.grid(color='grey', linestyle='-', linewidth=0.5);
ax.legend()

plt.show()

# %%
# Save figure
if flag_save:

    title = f"/v0_df{df_seen_str}_1"     
    fig.savefig(path+title+ext, bbox_inches='tight')
